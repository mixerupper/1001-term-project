# %%
import pandas as pd
import numpy as np
import os
import sys
nb_dir = os.path.split(os.getcwd())[0]
if nb_dir not in sys.path:
    sys.path.append(nb_dir)
from header import *

# %%
data_root = 'C:/Users/c/Documents/dsga1001/1001-term-project/data/'

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn import preprocessing

from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold

from sklearn.metrics import roc_curve, auc

import matplotlib.pyplot as plt

# %% [markdown]
# ## Import

# %%
q3mergeddata = pd.read_csv(data_root + '02-build/clean/2019q3/2019q3merged.csv')

# %%
q3mergeddata.sic.value_counts()
# Out:
# 2834.0    362
# 6022.0    178
# 6798.0    173
# 7372.0    116
# 2836.0     93
# 1311.0     91
# 3841.0     86
# 6021.0     73
# 7389.0     72
# 3674.0     70
# 6035.0     56
# 5812.0     43
# 6331.0     43
# 7374.0     42
# 6770.0     41
# 6282.0     35
# 3714.0     30
# 7370.0     28
# 3663.0     27
# 3845.0     27
# 7373.0     25
# 1389.0     25
# 4911.0     22
# 7011.0     22
# 6500.0     22
# 4813.0     20
# 8731.0     20
# 4922.0     20
# 3826.0     20
# 8071.0     20
#          ...
# 3341.0      1
# 2024.0      1
# 2520.0      1
# 3716.0      1
# 2011.0      1
# 3715.0      1
# 6399.0      1
# 4950.0      1
# 6792.0      1
# 2761.0      1
# 6799.0      1
# 3080.0      1
# 8011.0      1
# 3910.0      1
# 4210.0      1
# 3330.0      1
# 3050.0      1
# 3652.0      1
# 3790.0      1
# 7330.0      1
# 3555.0      1
# 3211.0      1
# 3448.0      1
# 8111.0      1
# 2200.0      1
# 3579.0      1
# 3822.0      1
# 4013.0      1
# 3942.0      1
# 6159.0      1
# ...

# %%
q3mergeddata['sic_new']=''
q3mergeddata.head()
# Out:
#    Unnamed: 0                  adsh                       company_name  \
# 0           0  0000002178-19-000086     ADAMS RESOURCES & ENERGY, INC.
# 1           1  0000002488-19-000104         ADVANCED MICRO DEVICES INC
# 2           2  0000002969-19-000042  AIR PRODUCTS & CHEMICALS INC /DE/
# 3           3  0000003499-19-000017                     ALEXANDERS INC
# 4           4  0000003545-19-000100                          ALICO INC
#
#     dyrqt                filed   cik     sic ticker country      period  \
# 0  201902  2019-08-07 00:00:00  2178  5172.0     ae      US  2019-06-30
# 1  201902  2019-07-31 00:00:00  2488  3674.0    amd      US  2019-06-30
# 2  201902  2019-07-25 00:00:00  2969  2810.0    apd      US  2019-06-30
# 3  201902  2019-07-29 00:00:00  3499  6798.0    alx      US  2019-06-30
# 4  201902  2019-08-06 00:00:00  3545   100.0   alco      US  2019-06-30
#
#     ...     TotalLiabilities  TreasuryStockShares  TreasuryStockValue  \
# ...

# %% [markdown]
# ## Create dummy variable

# %%
for i in range(len(q3mergeddata)):
    if 0<q3mergeddata.sic[i]<=999:
        q3mergeddata.sic_new[i]='Agriculture, Forestry, And Fishing'
    if 1000<=q3mergeddata.sic[i]<=1499:
        q3mergeddata.sic_new[i]='Mining'
    if 1500<=q3mergeddata.sic[i]<=1799:
        q3mergeddata.sic_new[i]='Construction'
    if 2000<=q3mergeddata.sic[i]<=3999:
        q3mergeddata.sic_new[i]='Manufacturing'
    if 4000<=q3mergeddata.sic[i]<=4999:
        q3mergeddata.sic_new[i]='Transportation, Communications, Electric, Gas, And Sanitary Services'
    if 5000<=q3mergeddata.sic[i]<=5199:
        q3mergeddata.sic_new[i]='Wholesale Trade'
    if 5200<=q3mergeddata.sic[i]<=5999:
        q3mergeddata.sic_new[i]='Retail Trade'
    if 6000<=q3mergeddata.sic[i]<=6799:
        q3mergeddata.sic_new[i]='Finance, Insurance, And Real Estate'
    if 7000<=q3mergeddata.sic[i]<=8999:
        q3mergeddata.sic_new[i]='Services'
    if 9000<=q3mergeddata.sic[i]<=9999:
        q3mergeddata.sic_new[i]='Public Administration'
# Out:
# C:\Users\c\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\c\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\c\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
q3_dummy=pd.get_dummies(q3mergeddata['sic_new'])

# %%
q3=pd.concat([q3mergeddata,q3_dummy],axis=1)

# %%
q3.head()
# Out:
#    Unnamed: 0                  adsh                       company_name  \
# 0           0  0000002178-19-000086     ADAMS RESOURCES & ENERGY, INC.
# 1           1  0000002488-19-000104         ADVANCED MICRO DEVICES INC
# 2           2  0000002969-19-000042  AIR PRODUCTS & CHEMICALS INC /DE/
# 3           3  0000003499-19-000017                     ALEXANDERS INC
# 4           4  0000003545-19-000100                          ALICO INC
#
#     dyrqt                filed   cik     sic ticker country      period  \
# 0  201902  2019-08-07 00:00:00  2178  5172.0     ae      US  2019-06-30
# 1  201902  2019-07-31 00:00:00  2488  3674.0    amd      US  2019-06-30
# 2  201902  2019-07-25 00:00:00  2969  2810.0    apd      US  2019-06-30
# 3  201902  2019-07-29 00:00:00  3499  6798.0    alx      US  2019-06-30
# 4  201902  2019-08-06 00:00:00  3545   100.0   alco      US  2019-06-30
#
#         ...                                     sic_new  \
# ...

# %%
df.isnull().any()
# Out:
# Unnamed: 0                                                                                          False
# adsh                                                                                                False
# company_name                                                                                        False
# dyrqt                                                                                               False
# filed                                                                                               False
# cik                                                                                                 False
# sic                                                                                                 False
# ticker                                                                                              False
# country                                                                                             False
# ...

# %% [markdown]
# ## Adjust columns

# %%
q3=q3.drop(['sic_new'],axis=1)

# %%
cols = q3.columns.tolist()

# %%
cols=cols[:-13]+cols[-9:]+cols[-13:-9]

# %%
q3=q3[cols]

# %% [markdown]
# ## Save

# %%
q3.to_csv(data_root+'02-build/clean/2019q3/2019q3_dummy.csv', encoding='gbk')

# %%
test=pd.read_csv(data_root+'02-build/clean/2019q3/2019q3_dummy.csv')
test.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                  adsh  \
# 0           0             0  0000002178-19-000086
# 1           1             1  0000002488-19-000104
# 2           2             2  0000002969-19-000042
# 3           3             3  0000003499-19-000017
# 4           4             4  0000003545-19-000100
#
#                         company_name   dyrqt                filed   cik  \
# 0     ADAMS RESOURCES & ENERGY, INC.  201902  2019-08-07 00:00:00  2178
# 1         ADVANCED MICRO DEVICES INC  201902  2019-07-31 00:00:00  2488
# 2  AIR PRODUCTS & CHEMICALS INC /DE/  201902  2019-07-25 00:00:00  2969
# 3                     ALEXANDERS INC  201902  2019-07-29 00:00:00  3499
# 4                          ALICO INC  201902  2019-08-06 00:00:00  3545
#
#       sic ticker country    ...    Manufacturing  Mining  Retail Trade  \
# 0  5172.0     ae      US    ...                0       0             0
# 1  3674.0    amd      US    ...                1       0             0
# ...
