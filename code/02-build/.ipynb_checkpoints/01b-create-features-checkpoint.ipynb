# %% [markdown]
# # Program Header

# %%
import pandas as pd
import numpy as np
import os
import sys
nb_dir = os.path.split(os.getcwd())[0]
if nb_dir not in sys.path:
    sys.path.append(nb_dir)
from header import *

# %%
data_root = initialize_data_root("AY")

# %%
import difflib
import jellyfish

# %% [markdown]
# # Table of contents
# 1. [Import](#Import)
# 2. [Create Tag Map](#CreateTagMap)
# 5. [Save](#Save)

# %% [markdown]
# ## Import <a name="Import"></a>

# %%
raw_sec_data = pd.read_csv(data_root+'02-build/clean/2019q3/sec_data_long.csv')

# %% [markdown]
# ## Create Tag Map <a name="CreateTagMap"></a>

# %%
sec_data = raw_sec_data.copy()

# %% [markdown]
# Let's split the tags into groups that definitely don't belong together using `qtrs`, `uom`.

# %%
tag_counts = sec_data.groupby(['qtrs', 'uom'])['tag'].count()

# %%
tag_counts
# Out:
# qtrs  uom
# 0     USD       247914
#       pure         495
#       shares     29659
# 1     USD       172817
#       pure        1200
#       shares     13467
# Name: tag, dtype: int64

# %% [markdown]
# We will use the `difflib` package to bucket tags together, starting from the most popular tags and working down to the least popular.

# %%
def create_tag_map(raw_tags):
    sorted_raw_tags = list(raw_tags.value_counts().index)
    
    tag_map = {}
    for raw_tag in sorted_raw_tags:
        available_tag_buckets = list(tag_map.keys())
        if len(available_tag_buckets) == 0:
            tag_map[raw_tag] = [raw_tag]
            print("Initialized tag map")
        else:
            matches = difflib.get_close_matches(raw_tag, available_tag_buckets)
            if len(matches) == 0:
                tag_map[raw_tag] = [raw_tag]
                print("Created new clean tag: "+raw_tag)
            else:
                clean_tag = matches[0]
                tag_map[clean_tag].append(raw_tag)
                print("Added "+raw_tag+" to "+clean_tag+".")
                
    return(tag_map)

# %%
list_of_maps = [{},{},{},{},{},{},{},{},{}]
unique_qtr = sec_data.qtrs.unique()
unique_uom = sec_data.uom.unique()
i = 0

for qtr in unique_qtr:
    for uom in unique_uom:
        raw_tags = sec_data.query("(qtrs == @qtr)&(uom == @uom)")['tag']
        list_of_maps[i] = create_tag_map(raw_tags)
        i+=1
# Out:
# Initialized tag map
# Created new clean tag: LiabilitiesAndStockholdersEquity
# Created new clean tag: RetainedEarningsAccumulatedDeficit
# Added StockholdersEquity to LiabilitiesAndStockholdersEquity.
# Created new clean tag: CashAndCashEquivalentsAtCarryingValue
# Created new clean tag: Liabilities
# Created new clean tag: CommonStockValue
# Created new clean tag: PropertyPlantAndEquipmentNet
# Added AssetsCurrent to Assets.
# Added LiabilitiesCurrent to Liabilities.
# Added CommonStockParOrStatedValuePerShare to CommonStockValue.
# Created new clean tag: AccumulatedOtherComprehensiveIncomeLossNetOfTax
# Created new clean tag: OperatingLeaseRightOfUseAsset
# Added OperatingLeaseLiability to OperatingLeaseRightOfUseAsset.
# Created new clean tag: AccountsPayableCurrent
# Created new clean tag: OtherAssetsNoncurrent
# Added AccountsReceivableNetCurrent to AccountsPayableCurrent.
# Created new clean tag: AdditionalPaidInCapital
# Created new clean tag: Goodwill
# Created new clean tag: PreferredStockParOrStatedValuePerShare
# Created new clean tag: CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalents
# Added OperatingLeaseLiabilityCurrent to OperatingLeaseRightOfUseAsset.
# Created new clean tag: OperatingLeaseLiabilityNoncurrent
# Created new clean tag: AccumulatedDepreciationDepletionAndAmortizationPropertyPlantAndEquipment
# Added OtherLiabilitiesNoncurrent to OtherAssetsNoncurrent.
# Created new clean tag: InventoryNet
# Added PrepaidExpenseAndOtherAssetsCurrent to OtherAssetsNoncurrent.
# Added AdditionalPaidInCapitalCommonStock to AdditionalPaidInCapital.
# Added AccruedLiabilitiesCurrent to AccountsPayableCurrent.
# Added PropertyPlantAndEquipmentGross to PropertyPlantAndEquipmentNet.
# Created new clean tag: IntangibleAssetsNetExcludingGoodwill
# Created new clean tag: StockholdersEquityIncludingPortionAttributableToNoncontrollingInterest
# Added LesseeOperatingLeaseLiabilityPaymentsDue to OperatingLeaseLiabilityNoncurrent.
# Created new clean tag: FiniteLivedIntangibleAssetsAccumulatedAmortization
# Added FiniteLivedIntangibleAssetsNet to FiniteLivedIntangibleAssetsAccumulatedAmortization.
# Created new clean tag: EmployeeRelatedLiabilitiesCurrent
# Added PreferredStockValue to PreferredStockParOrStatedValuePerShare.
# Added LongTermDebtNoncurrent to OtherAssetsNoncurrent.
# Created new clean tag: AllowanceForDoubtfulAccountsReceivableCurrent
# Created new clean tag: TreasuryStockValue
# Created new clean tag: LongTermDebt
# Added OtherAssetsCurrent to OtherAssetsNoncurrent.
# Added OtherAccruedLiabilitiesCurrent to EmployeeRelatedLiabilitiesCurrent.
# Created new clean tag: MinorityInterest
# Created new clean tag: ContractWithCustomerLiabilityCurrent
# Added FiniteLivedIntangibleAssetsGross to FiniteLivedIntangibleAssetsAccumulatedAmortization.
# Added LongTermDebtCurrent to LongTermDebt.
# Added OtherLiabilitiesCurrent to EmployeeRelatedLiabilitiesCurrent.
# Created new clean tag: FinanceLeaseLiability
# Created new clean tag: PrepaidExpenseCurrent
# Added OtherAssets to Assets.
# Added AccountsPayableAndAccruedLiabilitiesCurrent to AccountsPayableCurrent.
# Created new clean tag: AvailableForSaleSecuritiesDebtSecurities
# Added ContractWithCustomerLiability to ContractWithCustomerLiabilityCurrent.
# Added DeferredTaxLiabilitiesNoncurrent to OperatingLeaseLiabilityNoncurrent.
# Added AvailableForSaleDebtSecuritiesAmortizedCostBasis to AvailableForSaleSecuritiesDebtSecurities.
# Added FinanceLeaseLiabilityCurrent to FinanceLeaseLiability.
# Added FinanceLeaseLiabilityNoncurrent to OperatingLeaseLiabilityNoncurrent.
# Added FinanceLeaseRightOfUseAsset to OperatingLeaseRightOfUseAsset.
# Created new clean tag: DebtInstrumentCarryingAmount
# Created new clean tag: DeferredIncomeTaxLiabilitiesNet
# Added InterestPayableCurrent to AccountsPayableCurrent.
# Added CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalentsIncludingDisposalGroupAndDiscontinuedOperations to CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalents.
# Created new clean tag: Cash
# Created new clean tag: InventoryFinishedGoodsNetOfReserves
# Created new clean tag: AccruedIncomeTaxesCurrent
# Created new clean tag: UnrecognizedTaxBenefits
# Added LiabilitiesNoncurrent to Liabilities.
# Added InventoryFinishedGoods to InventoryFinishedGoodsNetOfReserves.
# Added DueToRelatedPartiesCurrent to EmployeeRelatedLiabilitiesCurrent.
# Added DeferredIncomeTaxAssetsNet to DeferredIncomeTaxLiabilitiesNet.
# Added OtherLiabilities to Liabilities.
# Added ContractWithCustomerLiabilityNoncurrent to ContractWithCustomerLiabilityCurrent.
# Created new clean tag: DeferredTaxAssetsValuationAllowance
# Created new clean tag: DeferredFinanceCostsNet
# Added InventoryWorkInProcessNetOfReserves to InventoryFinishedGoodsNetOfReserves.
# Added RestrictedCashAndCashEquivalents to CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalents.
# Created new clean tag: EquityMethodInvestments
# Added InventoryRawMaterialsNetOfReserves to InventoryFinishedGoodsNetOfReserves.
# Added AllowanceForDoubtfulAccountsReceivable to AllowanceForDoubtfulAccountsReceivableCurrent.
# Created new clean tag: ShortTermBorrowings
# Created new clean tag: LongTermDebtAndCapitalLeaseObligations
# Added TaxesPayableCurrent to AccountsPayableCurrent.
# Added DerivativeLiabilities to Liabilities.
# Created new clean tag: InventoryWorkInProcess
# Added AccruedProfessionalFeesCurrent to AccruedIncomeTaxesCurrent.
# Created new clean tag: IncomeTaxesReceivable
# Created new clean tag: LoansAndLeasesReceivableAllowance
# Added DeferredRevenueCurrent to PrepaidExpenseCurrent.
# Added LoansAndLeasesReceivableNetReportedAmount to LoansAndLeasesReceivableAllowance.
# Added InventoryRawMaterials to InventoryNet.
# Added ShortTermInvestments to EquityMethodInvestments.
# Added ContractWithCustomerAssetNet to ContractWithCustomerLiabilityCurrent.
# Created new clean tag: Deposits
# Added RestrictedCashAndCashEquivalentsAtCarryingValue to CashAndCashEquivalentsAtCarryingValue.
# Created new clean tag: RestrictedCash
# Added AccountsReceivableNet to AccountsPayableCurrent.
# Created new clean tag: ReceivablesNetCurrent
# Added NotesPayableCurrent to AccountsPayableCurrent.
# Added DeferredTaxAssetsNet to DeferredFinanceCostsNet.
# Created new clean tag: ShareBasedCompensationArrangementByShareBasedPaymentAwardOptionsOutstandingIntrinsicValue
# Created new clean tag: LineOfCredit
# Created new clean tag: InterestPayableCurrentAndNoncurrent
# Added IntangibleAssetsGrossExcludingGoodwill to IntangibleAssetsNetExcludingGoodwill.
# Added AccountsPayableAndAccruedLiabilitiesCurrentAndNoncurrent to InterestPayableCurrentAndNoncurrent.
# Added ContractWithCustomerAssetNetCurrent to ContractWithCustomerLiabilityCurrent.
# Created new clean tag: DerivativeAssets
# Added InventoryValuationReserves to InventoryFinishedGoodsNetOfReserves.
# Added DeferredTaxAssetsNetNoncurrent to OtherAssetsNoncurrent.
# Added AssetsNoncurrent to OtherAssetsNoncurrent.
# Created new clean tag: CashAndDueFromBanks
# Added LongTermDebtAndCapitalLeaseObligationsCurrent to LongTermDebtAndCapitalLeaseObligations.
# Created new clean tag: DerivativeFairValueOfDerivativeAsset
# Added DerivativeFairValueOfDerivativeLiability to DerivativeFairValueOfDerivativeAsset.
# Created new clean tag: InvestmentsInAffiliatesSubsidiariesAssociatesAndJointVentures
# Added DerivativeLiabilitiesCurrent to EmployeeRelatedLiabilitiesCurrent.
# Created new clean tag: Land
# Added AccountsReceivableGrossCurrent to AccountsPayableCurrent.
# Added DebtInstrumentUnamortizedDiscount to DebtInstrumentCarryingAmount.
# Added InterestReceivable to IncomeTaxesReceivable.
# Created new clean tag: OperatingLeasesFutureMinimumPaymentsDueCurrent
# Added DeferredTaxAssetsGross to DeferredTaxAssetsValuationAllowance.
# Added LoansAndLeasesReceivableGrossCarryingAmount to LoansAndLeasesReceivableAllowance.
# Added AvailableForSaleSecurities to AvailableForSaleSecuritiesDebtSecurities.
# Created new clean tag: EquitySecuritiesFvNi
# Created new clean tag: InterestBearingDepositsInBanks
# Added DeferredTaxAssetsLiabilitiesNet to DeferredIncomeTaxLiabilitiesNet.
# Added DividendsPayableCurrentAndNoncurrent to InterestPayableCurrentAndNoncurrent.
# Added HeldToMaturitySecurities to EquitySecuritiesFvNi.
# Added DebtCurrent to ReceivablesNetCurrent.
# Created new clean tag: NotesPayable
# Created new clean tag: StockRepurchaseProgramRemainingAuthorizedRepurchaseAmount1
# Added HeldToMaturitySecuritiesFairValue to EquitySecuritiesFvNi.
# Created new clean tag: PensionAndOtherPostretirementDefinedBenefitPlansLiabilitiesNoncurrent
# Added AccountsPayableRelatedPartiesCurrent to AccountsPayableCurrent.
# Added DeferredTaxLiabilities to DeferredIncomeTaxLiabilitiesNet.
# Created new clean tag: MachineryAndEquipmentGross
# Added LongTermDebtFairValue to LongTermDebt.
# Added NoninterestBearingDepositLiabilities to InterestBearingDepositsInBanks.
# Created new clean tag: ConstructionInProgressGross
# Added AccountsPayableTradeCurrent to AccountsPayableCurrent.
# Added PrepaidExpenseAndOtherAssets to PrepaidExpenseCurrent.
# Created new clean tag: AssetRetirementObligationsNoncurrent
# Created new clean tag: AccruedLiabilitiesAndOtherLiabilities
# Added Investments to EquityMethodInvestments.
# Created new clean tag: DebtInstrumentUnamortizedDiscountPremiumAndDebtIssuanceCostsNet
# Created new clean tag: BankOwnedLifeInsurance
# Created new clean tag: RealEstateInvestmentPropertyNet
# Added IntangibleAssetsNetIncludingGoodwill to IntangibleAssetsNetExcludingGoodwill.
# Added RestrictedCashCurrent to RestrictedCash.
# Added IndefiniteLivedIntangibleAssetsExcludingGoodwill to IntangibleAssetsNetExcludingGoodwill.
# Added RestrictedCashAndCashEquivalentsNoncurrent to CashAndCashEquivalentsAtCarryingValue.
# Created new clean tag: EmployeeServiceShareBasedCompensationNonvestedAwardsTotalCompensationCostNotYetRecognized
# Added AvailableForSaleSecuritiesAmortizedCost to AvailableForSaleSecuritiesDebtSecurities.
# Added ConvertibleNotesPayableCurrent to AccountsPayableCurrent.
# Created new clean tag: FinancingReceivableAllowanceForCreditLosses
# Created new clean tag: RevenueRemainingPerformanceObligation
# Added InventoryGross to InventoryWorkInProcess.
# Added LinesOfCreditCurrent to LineOfCredit.
# Created new clean tag: NotesPayableRelatedPartiesClassifiedCurrent
# Created new clean tag: UnamortizedDebtIssuanceExpense
# Created new clean tag: MarketableSecuritiesCurrent
# Added DeferredTaxAssetsLiabilitiesNetNoncurrent to DeferredIncomeTaxLiabilitiesNet.
# Added LoansAndLeasesReceivableNetOfDeferredIncome to LoansAndLeasesReceivableAllowance.
# Added OtherReceivablesNetCurrent to ReceivablesNetCurrent.
# Created new clean tag: SharePrice
# Created new clean tag: DeferredRevenue
# Added RestrictedCashNoncurrent to RestrictedCash.
# Added InterestBearingDepositLiabilities to InterestBearingDepositsInBanks.
# Created new clean tag: ProductWarrantyAccrual
# Added AvailableForSaleSecuritiesDebtSecuritiesCurrent to AvailableForSaleSecuritiesDebtSecurities.
# Added RealEstateInvestmentPropertyAccumulatedDepreciation to RealEstateInvestmentPropertyNet.
# Added AccruedIncomeTaxesNoncurrent to AccruedIncomeTaxesCurrent.
# Added DividendsPayableCurrent to AccountsPayableCurrent.
# Added AccruedSalariesCurrent to AccruedIncomeTaxesCurrent.
# Added AccumulatedOtherComprehensiveIncomeLossForeignCurrencyTranslationAdjustmentNetOfTax to AccumulatedOtherComprehensiveIncomeLossNetOfTax.
# Added LongTermInvestments to LongTermDebt.
# Added DebtInstrumentFaceAmount to DebtInstrumentCarryingAmount.
# Created new clean tag: RestructuringReserve
# Created new clean tag: BuildingsAndImprovementsGross
# Added DebtAndCapitalLeaseObligations to LongTermDebtAndCapitalLeaseObligations.
# Added CashEquivalentsAtCarryingValue to CashAndCashEquivalentsAtCarryingValue.
# Created new clean tag: ClassOfWarrantOrRightExercisePriceOfWarrantsOrRights1
# Created new clean tag: AssetsFairValueDisclosure
# Created new clean tag: AssetsOfDisposalGroupIncludingDiscontinuedOperationCurrent
# Created new clean tag: LesseeOperatingLeaseLiabilityPaymentsDueNextTwelveMonths
# Added DerivativeLiabilitiesNoncurrent to OperatingLeaseLiabilityNoncurrent.
# Created new clean tag: DeferredRentCreditNoncurrent
# Added CommonStockValueOutstanding to CommonStockValue.
# Added RealEstateInvestmentPropertyAtCost to RealEstateInvestmentPropertyNet.
# Added PrepaidTaxes to PrepaidExpenseCurrent.
# Added DepositsAssetsNoncurrent to OtherAssetsNoncurrent.
# Added NotesReceivableNet to ReceivablesNetCurrent.
# Created new clean tag: LineOfCreditFacilityMaximumBorrowingCapacity
# Created new clean tag: FurnitureAndFixturesGross
# Created new clean tag: FederalHomeLoanBankStock
# Added DerivativeNotionalAmount to DerivativeAssets.
# Added DueToRelatedPartiesCurrentAndNoncurrent to InterestPayableCurrentAndNoncurrent.
# Added FinancingReceivableAllowanceForCreditLossesIndividuallyEvaluatedForImpairment1 to FinancingReceivableAllowanceForCreditLosses.
# Added DeferredIncomeTaxLiabilities to DeferredIncomeTaxLiabilitiesNet.
# Added ProductWarrantyAccrualClassifiedCurrent to ProductWarrantyAccrual.
# Added DueFromRelatedPartiesCurrent to EmployeeRelatedLiabilitiesCurrent.
# Created new clean tag: OtherReceivables
# Added DeferredRevenueNoncurrent to DeferredRentCreditNoncurrent.
# Added CapitalLeaseObligationsCurrent to LongTermDebtAndCapitalLeaseObligations.
# Created new clean tag: RedeemableNoncontrollingInterestEquityCarryingAmount
# Added LongTermNotesPayable to NotesPayable.
# Created new clean tag: CapitalizedContractCostNet
# Added LiabilitiesFairValueDisclosure to AssetsFairValueDisclosure.
# Created new clean tag: NoncurrentAssets
# Created new clean tag: DebtLongtermAndShorttermCombinedAmount
# Added MarketableSecurities to MarketableSecuritiesCurrent.
# Added CommonStockNoParValue to CommonStockValue.
# Created new clean tag: UnrecognizedTaxBenefitsThatWouldImpactEffectiveTaxRate
# Added LiabilitiesOfDisposalGroupIncludingDiscontinuedOperationCurrent to AssetsOfDisposalGroupIncludingDiscontinuedOperationCurrent.
# Added CapitalLeaseObligationsNoncurrent to AssetRetirementObligationsNoncurrent.
# Added CashCashEquivalentsAndShortTermInvestments to CashAndCashEquivalentsAtCarryingValue.
# Created new clean tag: LoansReceivableHeldForSaleNetNotPartOfDisposalGroup
# Added LoansAndLeasesReceivableDeferredIncome to LoansAndLeasesReceivableAllowance.
# Added OtherAssetsMiscellaneousNoncurrent to OtherAssetsNoncurrent.
# Added OtherPrepaidExpenseCurrent to PrepaidExpenseCurrent.
# Added TimeDeposits to Deposits.
# Added AccountsAndOtherReceivablesNetCurrent to ReceivablesNetCurrent.
# Created new clean tag: TemporaryEquityCarryingAmountAttributableToParent
# Created new clean tag: InventoryRawMaterialsAndSupplies
# Created new clean tag: SecuritiesSoldUnderAgreementsToRepurchase
# Added DefinedBenefitPensionPlanLiabilitiesNoncurrent to PensionAndOtherPostretirementDefinedBenefitPlansLiabilitiesNoncurrent.
# Created new clean tag: DerivativeAssetFairValueGrossLiability
# Created new clean tag: SecuredDebt
# Added AssetRetirementObligation to AssetRetirementObligationsNoncurrent.
# Added UnbilledReceivablesCurrent to ReceivablesNetCurrent.
# Added DerivativeAssetsCurrent to DerivativeAssets.
# Added AccrualForTaxesOtherThanIncomeTaxesCurrent to AccruedIncomeTaxesCurrent.
# Added DeferredFinanceCostsNoncurrentNet to DeferredFinanceCostsNet.
# Added LongTermDebtAndCapitalLeaseObligationsIncludingCurrentMaturities to LongTermDebtAndCapitalLeaseObligations.
# Added AccruedLiabilitiesCurrentAndNoncurrent to InterestPayableCurrentAndNoncurrent.
# Added AccumulatedOtherComprehensiveIncomeLossDefinedBenefitPensionAndOtherPostretirementPlansNetOfTax to AccumulatedOtherComprehensiveIncomeLossNetOfTax.
# Created new clean tag: LossContingencyAccrualAtCarryingValue
# Created new clean tag: BusinessCombinationContingentConsiderationLiabilityCurrent
# Created new clean tag: DerivativeCollateralRightToReclaimCash
# Added TreasuryStockCommonValue to TreasuryStockValue.
# Added AccruedEmployeeBenefitsCurrent to EmployeeRelatedLiabilitiesCurrent.
# Created new clean tag: DepositsSavingsDeposits
# Added AccountsPayableAndOtherAccruedLiabilitiesCurrent to AccountsPayableCurrent.
# Created new clean tag: AccrualForEnvironmentalLossContingencies
# Added DebtInstrumentFairValue to DebtInstrumentCarryingAmount.
# Created new clean tag: ContractualObligation
# Added LeaseholdImprovementsGross to BuildingsAndImprovementsGross.
# Added OtherInvestments to EquityMethodInvestments.
# Added RestructuringReserveCurrent to RestructuringReserve.
# Added LongTermLineOfCredit to LineOfCredit.
# Added OtherIntangibleAssetsNet to IntangibleAssetsNetExcludingGoodwill.
# Added CapitalLeaseObligations to LongTermDebtAndCapitalLeaseObligations.
# Added InvestmentBuildingAndBuildingImprovements to BuildingsAndImprovementsGross.
# Added NotesAndLoansReceivableNetCurrent to ReceivablesNetCurrent.
# Created new clean tag: AccruedInvestmentIncomeReceivable
# Added InvestmentsFairValueDisclosure to AssetsFairValueDisclosure.
# Added PrepaidInsurance to PrepaidExpenseCurrent.
# Created new clean tag: CumulativeEffectOfNewAccountingPrincipleInPeriodOfAdoption
# Added PrepaidExpenseCurrentAndNoncurrent to PrepaidExpenseCurrent.
# Created new clean tag: CommitmentsAndContingencies
# Added AccountsReceivableRelatedPartiesCurrent to NotesPayableRelatedPartiesClassifiedCurrent.
# Added BusinessCombinationContingentConsiderationLiabilityNoncurrent to BusinessCombinationContingentConsiderationLiabilityCurrent.
# Created new clean tag: PartnersCapital
# Added AccountsPayableCurrentAndNoncurrent to InterestPayableCurrentAndNoncurrent.
# Created new clean tag: ConvertibleLongTermNotesPayable
# Added SubordinatedDebt to SecuredDebt.
# Added SecurityDeposit to SecuredDebt.
# Added PropertyPlantAndEquipmentOther to PropertyPlantAndEquipmentNet.
# Added ConvertibleNotesPayable to ConvertibleLongTermNotesPayable.
# Added AccruedRoyaltiesCurrent to AccruedIncomeTaxesCurrent.
# Created new clean tag: LiabilityForUncertainTaxPositionsNoncurrent
# Created new clean tag: EquitySecuritiesWithoutReadilyDeterminableFairValueAmount
# Created new clean tag: LiabilitiesOtherThanLongtermDebtNoncurrent
# Added DeferredCompensationLiabilityClassifiedNoncurrent to DeferredIncomeTaxLiabilitiesNet.
# Added AccumulatedOtherComprehensiveIncomeLossAvailableForSaleSecuritiesAdjustmentNetOfTax to AccumulatedOtherComprehensiveIncomeLossNetOfTax.
# Added IncomeTaxReceivable to IncomeTaxesReceivable.
# Created new clean tag: RealEstateAcquiredThroughForeclosure
# Added BusinessCombinationContingentConsiderationLiability to BusinessCombinationContingentConsiderationLiabilityCurrent.
# Added SalesAndExciseTaxPayableCurrent to AccountsPayableCurrent.
# Added CashAndCashEquivalentsFairValueDisclosure to CashAndCashEquivalentsAtCarryingValue.
# Added InventoryLIFOReserve to InventoryFinishedGoodsNetOfReserves.
# Added AccruedBonusesCurrent to AccruedIncomeTaxesCurrent.
# Created new clean tag: DueFromRelatedParties
# Added AdvancesFromFederalHomeLoanBanks to FederalHomeLoanBankStock.
# Added NotesReceivableGross to OtherReceivables.
# Created new clean tag: GoodwillImpairedAccumulatedImpairmentLoss
# Added AccruedMarketingCostsCurrent to AccruedIncomeTaxesCurrent.
# Added ContractWithCustomerAssetNetNoncurrent to ContractWithCustomerLiabilityCurrent.
# Created new clean tag: UnrecognizedTaxBenefitsIncomeTaxPenaltiesAndInterestAccrued
# Added DerivativeAssetsNoncurrent to OtherAssetsNoncurrent.
# Added CapitalizedComputerSoftwareNet to CapitalizedContractCostNet.
# Created new clean tag: FederalFundsSold
# Added ConvertibleDebtCurrent to ReceivablesNetCurrent.
# Added AssetRetirementObligationCurrent to AssetRetirementObligationsNoncurrent.
# Created new clean tag: TradingSecurities
# Created new clean tag: UnamortizedLoanCommitmentAndOriginationFeesAndUnamortizedDiscountsOrPremiums
# Added InventoryRawMaterialsAndSuppliesNetOfReserves to InventoryRawMaterialsAndSupplies.
# Added OtherLongTermDebt to LongTermDebt.
# Added PreferredStockNoParValue to PreferredStockParOrStatedValuePerShare.
# Added CapitalizedComputerSoftwareGross to CapitalizedContractCostNet.
# Created new clean tag: LiabilityForClaimsAndClaimsAdjustmentExpense
# Added NotesAndLoansReceivableNetNoncurrent to ReceivablesNetCurrent.
# Created new clean tag: PreferredStockValueOutstanding
# Added DeferredTaxAssetsOther to DeferredTaxAssetsValuationAllowance.
# Added DueToAffiliateCurrentAndNoncurrent to DeferredRentCreditNoncurrent.
# Added AccumulatedOtherComprehensiveIncomeLossCumulativeChangesInNetGainLossFromCashFlowHedgesEffectNetOfTax to AccumulatedOtherComprehensiveIncomeLossNetOfTax.
# Added AssetsOfDisposalGroupIncludingDiscontinuedOperation to AssetsOfDisposalGroupIncludingDiscontinuedOperationCurrent.
# Created new clean tag: AccountsPayableAndOtherAccruedLiabilities
# Added CashCashEquivalentsAndFederalFundsSold to CashAndCashEquivalentsAtCarryingValue.
# Added AccruedInsuranceCurrent to AccruedIncomeTaxesCurrent.
# Added StockRepurchaseProgramAuthorizedAmount1 to StockRepurchaseProgramRemainingAuthorizedRepurchaseAmount1.
# Added LoansPayableCurrent to AccountsPayableCurrent.
# Added DebtInstrumentUnamortizedDiscountCurrent to DebtInstrumentUnamortizedDiscountPremiumAndDebtIssuanceCostsNet.
# Added ConvertibleDebtNoncurrent to InterestPayableCurrentAndNoncurrent.
# Created new clean tag: UnbilledContractsReceivable
# Added NotesPayableRelatedPartiesNoncurrent to NotesPayableRelatedPartiesClassifiedCurrent.
# Added AccruedSalesCommissionCurrent to AccruedIncomeTaxesCurrent.
# Created new clean tag: ConvertibleDebt
# Created new clean tag: SeniorNotes
# Added OtherAccruedLiabilitiesNoncurrent to OtherAssetsNoncurrent.
# Added DeferredRentCreditCurrent to DeferredRentCreditNoncurrent.
# Created new clean tag: DueToAffiliateCurrent
# Created new clean tag: OtherCommitment
# Added EquitySecuritiesFvNiCost to EquitySecuritiesFvNi.
# Added EmployeeRelatedLiabilitiesCurrentAndNoncurrent to EmployeeRelatedLiabilitiesCurrent.
# Added DeferredCosts to DeferredFinanceCostsNet.
# Created new clean tag: DeferredPolicyAcquisitionCosts
# Added GoodwillGross to Goodwill.
# Created new clean tag: WarrantsAndRightsOutstanding
# Added DepositsMoneyMarketDeposits to DepositsSavingsDeposits.
# Added OtherSundryLiabilitiesCurrent to EmployeeRelatedLiabilitiesCurrent.
# Added TaxesPayableCurrentAndNoncurrent to InterestPayableCurrentAndNoncurrent.
# Added AssetsHeldForSaleNotPartOfDisposalGroupCurrent to LoansReceivableHeldForSaleNetNotPartOfDisposalGroup.
# Created new clean tag: UnearnedPremiums
# Added LiabilitiesOfDisposalGroupIncludingDiscontinuedOperation to AssetsOfDisposalGroupIncludingDiscontinuedOperationCurrent.
# Created new clean tag: MortgageLoansInProcessOfForeclosureAmount
# Added DerivativeCollateralObligationToReturnCash to DerivativeCollateralRightToReclaimCash.
# Added LoansReceivableHeldForSaleAmount to LoansReceivableHeldForSaleNetNotPartOfDisposalGroup.
# Added Capital to PartnersCapital.
# Created new clean tag: LongTermDebtMaturitiesRepaymentsOfPrincipalInNextTwelveMonths
# Added LimitedPartnersCapitalAccount to PartnersCapital.
# Created new clean tag: CustomerDepositsCurrent
# Added DueToRelatedPartiesNoncurrent to DueFromRelatedParties.
# Added DeferredRentReceivablesNet to DeferredIncomeTaxLiabilitiesNet.
# Added OtherRealEstateAndForeclosedAssets to RealEstateAcquiredThroughForeclosure.
# Added LineOfCreditFacilityRemainingBorrowingCapacity to LineOfCreditFacilityMaximumBorrowingCapacity.
# Added AccountsPayableOtherCurrent to AccountsPayableCurrent.
# Added GeneralPartnersCapitalAccount to PartnersCapital.
# Added MarketableSecuritiesNoncurrent to MarketableSecuritiesCurrent.
# Created new clean tag: SharesIssuedPricePerShare
# Added UnsecuredDebt to SecuredDebt.
# Added DepositsAssetsCurrent to CustomerDepositsCurrent.
# Created new clean tag: CashSurrenderValueOfLifeInsurance
# Added TemporaryEquityParOrStatedValuePerShare to PreferredStockParOrStatedValuePerShare.
# Added CapitalizedContractCostNetNoncurrent to CapitalizedContractCostNet.
# Added FederalHomeLoanBankAdvancesLongTerm to FederalHomeLoanBankStock.
# Added AccruedPayrollTaxesCurrent to AccruedIncomeTaxesCurrent.
# Added OtherPostretirementDefinedBenefitPlanLiabilitiesNoncurrent to PensionAndOtherPostretirementDefinedBenefitPlansLiabilitiesNoncurrent.
# Added AccruedVacationCurrent to AccruedIncomeTaxesCurrent.
# Added DepositAssets to Deposits.
# Created new clean tag: VariableInterestEntityConsolidatedCarryingAmountAssets
# Added OtherBorrowings to ShortTermBorrowings.
# Added AvailableForSaleSecuritiesCurrent to AvailableForSaleSecuritiesDebtSecurities.
# Created new clean tag: AccumulatedDistributionsInExcessOfNetIncome
# Added LandAndLandImprovements to BuildingsAndImprovementsGross.
# Added LoansPayable to NotesPayable.
# Created new clean tag: DefinedBenefitPlanAssetsForPlanBenefitsNoncurrent
# Added OtherAccruedLiabilitiesCurrentAndNoncurrent to InterestPayableCurrentAndNoncurrent.
# Created new clean tag: BelowMarketLeaseNet
# Added LoansReceivableFairValueDisclosure to AssetsFairValueDisclosure.
# Created new clean tag: PreferredStockLiquidationPreferenceValue
# Added AccruedIncomeTaxes to AccruedIncomeTaxesCurrent.
# Created new clean tag: OtherAssetsMiscellaneous
# Added LoansHeldForSaleFairValueDisclosure to AssetsFairValueDisclosure.
# Created new clean tag: ServicingAssetAtFairValueAmount
# Added DueFromAffiliateCurrent to DueToAffiliateCurrent.
# Added DebtInstrumentUnamortizedDiscountPremiumNet to DebtInstrumentUnamortizedDiscountPremiumAndDebtIssuanceCostsNet.
# Added LiabilityForUnpaidClaimsAndClaimsAdjustmentExpenseNet to LiabilityForClaimsAndClaimsAdjustmentExpense.
# Added AccountsAndNotesReceivableNet to LoansAndLeasesReceivableAllowance.
# Added DisposalGroupIncludingDiscontinuedOperationAssetsNoncurrent to AssetsOfDisposalGroupIncludingDiscontinuedOperationCurrent.
# Added TemporaryEquityCarryingAmountIncludingPortionAttributableToNoncontrollingInterests to StockholdersEquityIncludingPortionAttributableToNoncontrollingInterest.
# Created new clean tag: SecurityDepositLiability
# Added CapitalizedContractCostNetCurrent to CapitalizedContractCostNet.
# Added DepositsAssets to Deposits.
# Added AccountsNotesAndLoansReceivableNetCurrent to ReceivablesNetCurrent.
# Created new clean tag: EntityPublicFloat
# Added DevelopmentInProcess to InventoryWorkInProcess.
# Added RegulatoryLiabilityNoncurrent to OperatingLeaseLiabilityNoncurrent.
# Created new clean tag: OtherRealEstate
# Created new clean tag: CommercialPaper
# Added DeferredCostsCurrent to DeferredFinanceCostsNet.
# Added OtherInventorySupplies to InventoryRawMaterialsAndSupplies.
# Added RegulatoryAssetsNoncurrent to OtherAssetsNoncurrent.
# Created new clean tag: ShortTermBankLoansAndNotesPayable
# Added InventorySuppliesNetOfReserves to InventoryFinishedGoodsNetOfReserves.
# Added DeferredFinanceCostsCurrentNet to DeferredFinanceCostsNet.
# Created new clean tag: MoneyMarketFundsAtCarryingValue
# Added AccruedEnvironmentalLossContingenciesCurrent to AccrualForEnvironmentalLossContingencies.
# Created new clean tag: FairValueMeasurementWithUnobservableInputsReconciliationsRecurringBasisLiabilityValue
# Created new clean tag: GuaranteeObligationsCurrentCarryingValue
# Added LiabilitiesOfDisposalGroupIncludingDiscontinuedOperationNoncurrent to AssetsOfDisposalGroupIncludingDiscontinuedOperationCurrent.
# Added EscrowDeposit to Deposits.
# Added VariableInterestEntityConsolidatedCarryingAmountLiabilities to VariableInterestEntityConsolidatedCarryingAmountAssets.
# Added DueToOfficersOrStockholdersCurrent to DueToAffiliateCurrent.
# Created new clean tag: CommonStockDividendsPerShareDeclared
# Added RealEstateInvestments to RealEstateInvestmentPropertyNet.
# Created new clean tag: MortgageLoansOnRealEstateCommercialAndConsumerNet
# Created new clean tag: JuniorSubordinatedDebentureOwedToUnconsolidatedSubsidiaryTrust
# Added OtherLongTermInvestments to OtherCommitment.
# Created new clean tag: RealEstateHeldforsale
# Added InventoryNoncurrent to InventoryNet.
# Created new clean tag: PropertySubjectToOrAvailableForOperatingLeaseNet
# Created new clean tag: DebtSecuritiesAvailableForSaleRestricted
# Added OtherLongTermDebtNoncurrent to LiabilitiesOtherThanLongtermDebtNoncurrent.
# Added AccruedEnvironmentalLossContingenciesNoncurrent to AccrualForEnvironmentalLossContingencies.
# Added DueFromAffiliates to DueToAffiliateCurrent.
# Added NotesPayableRelatedPartiesCurrentAndNoncurrent to NotesPayableRelatedPartiesClassifiedCurrent.
# Added RestrictedInvestments to EquityMethodInvestments.
# Added AccountsPayableRelatedPartiesCurrentAndNoncurrent to InterestPayableCurrentAndNoncurrent.
# Added DeferredCompensationLiabilityCurrent to DeferredIncomeTaxLiabilitiesNet.
# Added AvailableForSaleSecuritiesDebtSecuritiesNoncurrent to AvailableForSaleSecuritiesDebtSecurities.
# Added SecuredLongTermDebt to LongTermDebt.
# Created new clean tag: BankOverdrafts
# Created new clean tag: LitigationReserveCurrent
# Added AssetsHeldInTrustNoncurrent to OtherAssetsNoncurrent.
# Added DeferredTaxLiabilitiesOther to DeferredIncomeTaxLiabilitiesNet.
# Created new clean tag: DeferredCompensationPlanAssets
# Added NoninterestBearingDepositLiabilitiesDomestic to InterestBearingDepositsInBanks.
# Added DebtInstrumentUnamortizedDiscountNoncurrent to DebtInstrumentUnamortizedDiscountPremiumAndDebtIssuanceCostsNet.
# Added BelowMarketLeaseAccumulatedAmortization to FiniteLivedIntangibleAssetsAccumulatedAmortization.
# Added ContractWithCustomerAssetGross to ContractWithCustomerLiabilityCurrent.
# Created new clean tag: DividendsPayableAmountPerShare
# Created new clean tag: ReinsuranceRecoverables
# Added DeferredCostsCurrentAndNoncurrent to InterestPayableCurrentAndNoncurrent.
# Added StandardProductWarrantyAccrual to ProductWarrantyAccrual.
# Created new clean tag: InvestmentOwnedAtFairValue
# Added LiabilityForUncertainTaxPositionsCurrent to LiabilityForUncertainTaxPositionsNoncurrent.
# Added SelfInsuranceReserveCurrent to LitigationReserveCurrent.
# Created new clean tag: CertificatesOfDepositAtCarryingValue
# Added TradingSecuritiesDebt to TradingSecurities.
# Created new clean tag: StockholdersEquityBeforeTreasuryStock
# Added AccountsReceivableRelatedParties to DueFromRelatedParties.
# Added CommonStockDividendsPerShareCashPaid to CommonStockDividendsPerShareDeclared.
# Added DeferredOfferingCosts to DeferredFinanceCostsNet.
# Created new clean tag: AdvancePaymentsByBorrowersForTaxesAndInsurance
# Added LongTermLoansPayable to ConvertibleLongTermNotesPayable.
# Added WorkersCompensationLiabilityCurrent to BusinessCombinationContingentConsiderationLiabilityCurrent.
# Added DeferredRentCredit to DeferredRentCreditNoncurrent.
# Added PropertyPlantAndEquipmentOtherNet to PropertyPlantAndEquipmentNet.
# Added RegulatoryLiabilityCurrent to EmployeeRelatedLiabilitiesCurrent.
# Added CommonStocksIncludingAdditionalPaidInCapital to AdditionalPaidInCapital.
# Created new clean tag: CapitalLeasedAssetsGross
# Added RegulatoryAssetsCurrent to OtherAssetsNoncurrent.
# Created new clean tag: TimeDepositsAtOrAboveFDICInsuranceLimit
# Created new clean tag: HeldToMaturitySecuritiesAmortizedCostBeforeOtherThanTemporaryImpairment
# Added InterestBearingDepositLiabilitiesDomestic to InterestBearingDepositsInBanks.
# Added ShareBasedCompensationArrangementByShareBasedPaymentAwardOptionsVestedAndExpectedToVestExercisableAggregateIntrinsicValue to ShareBasedCompensationArrangementByShareBasedPaymentAwardOptionsOutstandingIntrinsicValue.
# Added OtherAccountsPayableAndAccruedLiabilities to AccountsPayableAndOtherAccruedLiabilities.
# Added OtherShortTermBorrowings to ShortTermBorrowings.
# Added AccruedRentCurrent to AccruedIncomeTaxesCurrent.
# Added CashAndCashEquivalentsAtCarryingValueIncludingDiscontinuedOperations to CashAndCashEquivalentsAtCarryingValue.
# Added UnearnedESOPShares to UnearnedPremiums.
# Added CostMethodInvestments to EquityMethodInvestments.
# Created new clean tag: ProceedsFromIssuanceOfCommonStock
# Created new clean tag: DemandDepositAccounts
# Added AccumulatedAmortizationDeferredFinanceCosts to DeferredFinanceCostsNet.
# Added FixturesAndEquipmentGross to MachineryAndEquipmentGross.
# Added ContractWithCustomerRefundLiabilityCurrent to ContractWithCustomerLiabilityCurrent.
# Created new clean tag: ForeclosedAssets
# Created new clean tag: OffMarketLeaseUnfavorable
# Added RestructuringReserveNoncurrent to RestructuringReserve.
# Added InvestmentOwnedAtCost to InvestmentOwnedAtFairValue.
# Added AccountsReceivableNetNoncurrent to ReceivablesNetCurrent.
# Created new clean tag: ReceivablesFromBrokersDealersAndClearingOrganizations
# Added OtherShortTermInvestments to OtherCommitment.
# Added PropertySubjectToOrAvailableForOperatingLeaseAccumulatedDepreciation to PropertySubjectToOrAvailableForOperatingLeaseNet.
# Added SaleOfStockPricePerShare to SharesIssuedPricePerShare.
# Added PreferredStockLiquidationPreference to PreferredStockLiquidationPreferenceValue.
# Added InvestmentsAndOtherNoncurrentAssets to NoncurrentAssets.
# Added OtherReceivablesGrossCurrent to ReceivablesNetCurrent.
# Added AccruedExpensesAndOtherCurrentLiabilities to AccountsPayableAndOtherAccruedLiabilities.
# Created new clean tag: DefinedBenefitPlanFairValueOfPlanAssets
# Added DeferredCompensationLiabilityCurrentAndNoncurrent to InterestPayableCurrentAndNoncurrent.
# Added CapitalizedComputerSoftwareAccumulatedAmortization to FiniteLivedIntangibleAssetsAccumulatedAmortization.
# Created new clean tag: OilAndGasPropertySuccessfulEffortMethodNet
# Added DeferredTaxAssetsDeferredIncome to DeferredTaxAssetsValuationAllowance.
# Added SecuritiesPurchasedUnderAgreementsToResell to SecuritiesSoldUnderAgreementsToRepurchase.
# Added ProductWarrantyAccrualNoncurrent to ProductWarrantyAccrual.
# Added FederalHomeLoanBankStockAndFederalReserveBankStock to FederalHomeLoanBankStock.
# Added PayablesToBrokerDealersAndClearingOrganizations to ReceivablesFromBrokersDealersAndClearingOrganizations.
# Created new clean tag: RestrictedCashAndInvestmentsCurrent
# Created new clean tag: IndefiniteLivedTrademarks
# Created new clean tag: DebtIssuanceCostsLineOfCreditArrangementsNet
# Added PrepaidRent to PrepaidExpenseCurrent.
# Added PremiumsReceivableAtCarryingValue to CashAndCashEquivalentsAtCarryingValue.
# Created new clean tag: MembersEquity
# Created new clean tag: BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedAssets
# Added DueFromRelatedPartiesNoncurrent to DueFromRelatedParties.
# Added DeferredCostsLeasingNet to DeferredFinanceCostsNet.
# Added AccruedProfessionalFeesCurrentAndNoncurrent to InterestPayableCurrentAndNoncurrent.
# Added RestrictedCashAndInvestmentsNoncurrent to RestrictedCashAndInvestmentsCurrent.
# Added PropertySubjectToOrAvailableForOperatingLeaseGross to PropertySubjectToOrAvailableForOperatingLeaseNet.
# Created new clean tag: CashFDICInsuredAmount
# Added ProvedOilAndGasPropertySuccessfulEffortMethod to OilAndGasPropertySuccessfulEffortMethodNet.
# Added IncomeTaxesReceivableNoncurrent to IncomeTaxesReceivable.
# Added ReinsurancePayable to ReinsuranceRecoverables.
# Added ReinsuranceRecoverableForUnpaidClaimsAndClaimsAdjustments to LiabilityForClaimsAndClaimsAdjustmentExpense.
# Added ValueAddedTaxReceivableCurrent to ReceivablesNetCurrent.
# Added InterestReceivableCurrent to ReceivablesNetCurrent.
# Added AssetsHeldForSaleNotPartOfDisposalGroup to LoansReceivableHeldForSaleNetNotPartOfDisposalGroup.
# Added BilledContractReceivables to UnbilledContractsReceivable.
# Added LoansAndLeasesReceivableRelatedParties to LoansAndLeasesReceivableAllowance.
# Added NontradeReceivablesCurrent to ReceivablesNetCurrent.
# Created new clean tag: RelatedPartyTransactionDueFromToRelatedParty
# Created new clean tag: Supplies
# Added PurchaseObligation to ContractualObligation.
# Added ServicingAssetAtAmortizedValue to ServicingAssetAtFairValueAmount.
# Created new clean tag: LoansPledgedAsCollateral
# Added PartnersCapitalIncludingPortionAttributableToNoncontrollingInterest to StockholdersEquityIncludingPortionAttributableToNoncontrollingInterest.
# Added AllowanceForDoubtfulAccountsPremiumsAndOtherReceivables to AllowanceForDoubtfulAccountsReceivableCurrent.
# Created new clean tag: JuniorSubordinatedNotes
# Added ContractWithCustomerRefundLiability to ContractWithCustomerLiabilityCurrent.
# Added PrepaidExpenseNoncurrent to PrepaidExpenseCurrent.
# Added PensionAndOtherPostretirementAndPostemploymentBenefitPlansLiabilitiesNoncurrent to PensionAndOtherPostretirementDefinedBenefitPlansLiabilitiesNoncurrent.
# Created new clean tag: TimeDeposits100000OrMore
# Added FIFOInventoryAmount to InventoryNet.
# Added FairValueMeasurementWithUnobservableInputsReconciliationRecurringBasisAssetValue to FairValueMeasurementWithUnobservableInputsReconciliationsRecurringBasisLiabilityValue.
# Created new clean tag: CertainLoansAcquiredInTransferNotAccountedForAsDebtSecuritiesCarryingAmountNet
# Added IndefiniteLivedTradeNames to IndefiniteLivedTrademarks.
# Created new clean tag: SecurityOwnedAndPledgedAsCollateralFairValue
# Added DerivativeAssetsLiabilitiesAtFairValueNet to DerivativeAssetFairValueGrossLiability.
# Added CustomerAdvancesCurrent to CustomerDepositsCurrent.
# Created new clean tag: DerivativeNetLiabilityPositionAggregateFairValue
# Added LoansAndLeasesReceivableBeforeFeesGross to LoansAndLeasesReceivableAllowance.
# Added PartnersCapitalAttributableToNoncontrollingInterest to StockholdersEquityIncludingPortionAttributableToNoncontrollingInterest.
# Created new clean tag: DebtInstrumentConvertibleConversionPrice1
# Added NotesPayableFairValueDisclosure to AssetsFairValueDisclosure.
# Added FederalFundsPurchased to FederalFundsSold.
# Created new clean tag: DepositsNegotiableOrderOfWithdrawalNOW
# Added HeldToMaturitySecuritiesCurrent to MarketableSecuritiesCurrent.
# Added ServicingAsset to ServicingAssetAtFairValueAmount.
# Created new clean tag: SelfInsuranceReserveNoncurrent
# Added SecuredDebtCurrent to SecuredDebt.
# Created new clean tag: TenantImprovements
# Added SeniorLongTermNotes to SeniorNotes.
# Added RetainedEarningsUnappropriated to RetainedEarningsAccumulatedDeficit.
# Added NotesAndLoansReceivableGrossCurrent to ReceivablesNetCurrent.
# Added OtherAssetsFairValueDisclosure to AssetsFairValueDisclosure.
# Added CustomerRefundLiabilityCurrent to ContractWithCustomerLiabilityCurrent.
# Created new clean tag: PrepaidReinsurancePremiums
# Created new clean tag: CommonStockShareSubscribedButUnissuedSubscriptionsReceivable
# Added LossContingencyAccrualCarryingValueCurrent to LossContingencyAccrualAtCarryingValue.
# Added OilAndGasPropertySuccessfulEffortMethodAccumulatedDepreciationDepletionAndAmortization to OilAndGasPropertySuccessfulEffortMethodNet.
# Added AvailableForSaleSecuritiesEquitySecurities to AvailableForSaleSecuritiesDebtSecurities.
# Added CommonStockSharesSubscriptions to CommonStockShareSubscribedButUnissuedSubscriptionsReceivable.
# Created new clean tag: FiniteLivedPatentsGross
# Created new clean tag: LiabilityForFuturePolicyBenefits
# Added PremiumsAndOtherReceivablesNet to OtherReceivables.
# Added DeferredTaxLiabilitiesGrossNoncurrent to DeferredIncomeTaxLiabilitiesNet.
# Added AvailableForSaleSecuritiesNoncurrent to AvailableForSaleSecuritiesDebtSecurities.
# Added StandardProductWarrantyAccrualCurrent to ProductWarrantyAccrual.
# Added FederalReserveBankStock to FederalHomeLoanBankStock.
# Added MortgageLoansOnRealEstate to MortgageLoansOnRealEstateCommercialAndConsumerNet.
# Added InventoryPartsAndComponentsNetOfReserves to InventoryFinishedGoodsNetOfReserves.
# Created new clean tag: MinorityInterestInOperatingPartnerships
# Added FairValueNetAssetLiability to FinanceLeaseLiability.
# Added DeferredCostsAndOtherAssets to DeferredFinanceCostsNet.
# Added DerivativeFairValueOfDerivativeNet to DerivativeFairValueOfDerivativeAsset.
# Created new clean tag: TimeDepositMaturitiesYearOne
# Created new clean tag: AllowanceForLoanAndLeaseLossesRealEstate
# Added UnprovedOilAndGasPropertySuccessfulEffortMethod to OilAndGasPropertySuccessfulEffortMethodNet.
# Added PensionAndOtherPostretirementDefinedBenefitPlansCurrentLiabilities to PensionAndOtherPostretirementDefinedBenefitPlansLiabilitiesNoncurrent.
# Added RedeemableNoncontrollingInterestEquityCommonCarryingAmount to RedeemableNoncontrollingInterestEquityCarryingAmount.
# Created new clean tag: FederalHomeLoanBankAdvancesMaturitiesSummaryDueWithinOneYearOfBalanceSheetDate
# Added OilAndGasPropertyFullCostMethodNet to OilAndGasPropertySuccessfulEffortMethodNet.
# Added NotesAndLoansPayable to NotesPayable.
# Created new clean tag: DeferredTaxLiabilitiesGoodwillAndIntangibleAssetsIntangibleAssets
# Created new clean tag: AociLossCashFlowHedgeCumulativeGainLossAfterTax
# Created new clean tag: PublicUtilitiesPropertyPlantAndEquipmentAccumulatedDepreciation
# Created new clean tag: LineOfCreditFacilityFairValueOfAmountOutstanding
# Added DisposalGroupIncludingDiscontinuedOperationCashAndCashEquivalents to AssetsOfDisposalGroupIncludingDiscontinuedOperationCurrent.
# Added PrepaidExpenseAndOtherAssetsNoncurrent to OtherAssetsNoncurrent.
# Created new clean tag: DirectFinancingLeaseNetInvestmentInLease
# Added NotesReceivableRelatedParties to NotesPayableRelatedPartiesClassifiedCurrent.
# Added CommissionsPayableToBrokerDealersAndClearingOrganizations to ReceivablesFromBrokersDealersAndClearingOrganizations.
# Added CapitalLeasesBalanceSheetAssetsByMajorClassNet to CapitalLeasedAssetsGross.
# Added AssetsNet to Assets.
# Added DeferredCreditsAndOtherLiabilitiesNoncurrent to DeferredRentCreditNoncurrent.
# Added RetainedEarningsAppropriated to RetainedEarningsAccumulatedDeficit.
# Created new clean tag: OilAndGasJointInterestBillingReceivablesCurrent
# Added BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedLiabilities to BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedAssets.
# Added OtherInventory to InventoryNet.
# Created new clean tag: InterestReceivableAndOtherAssets
# Created new clean tag: PayablesToCustomers
# Added BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedIntangibles to BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedAssets.
# Added OtherAssetsMiscellaneousCurrent to OtherAssetsMiscellaneous.
# Added InterestBearingDomesticDepositBrokered to InterestBearingDepositsInBanks.
# Added PublicUtilitiesPropertyPlantAndEquipmentNet to PropertyPlantAndEquipmentNet.
# Created new clean tag: LandAvailableForDevelopment
# Added DepositsFairValueDisclosure to AssetsFairValueDisclosure.
# Added NotesReceivableRelatedPartiesNoncurrent to NotesPayableRelatedPartiesClassifiedCurrent.
# Added PublicUtilitiesPropertyPlantAndEquipmentPlantInService to PublicUtilitiesPropertyPlantAndEquipmentAccumulatedDepreciation.
# Added OtherLongTermDebtCurrent to LongTermDebt.
# Added DueToAffiliateNoncurrent to DueToAffiliateCurrent.
# Added FinancialInstrumentsOwnedAtFairValue to InvestmentOwnedAtFairValue.
# Added AccrualForTaxesOtherThanIncomeTaxesCurrentAndNoncurrent to AccruedIncomeTaxesCurrent.
# Added SettlementLiabilitiesCurrent to EmployeeRelatedLiabilitiesCurrent.
# Added ReceivablesFromCustomers to PayablesToCustomers.
# Created new clean tag: DerivativeLiabilityFairValueGrossLiabilityIncludingNotSubjectToMasterNettingArrangement
# Added FederalFundsPurchasedAndSecuritiesSoldUnderAgreementsToRepurchase to SecuritiesSoldUnderAgreementsToRepurchase.
# Added BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedNet to BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedAssets.
# Created new clean tag: CapitalizedCostsProvedProperties
# Added RestrictedInvestmentsNoncurrent to RestrictedCashAndInvestmentsCurrent.
# Added LoansReceivableNet to ReceivablesNetCurrent.
# Added OilAndGasPropertySuccessfulEffortMethodGross to OilAndGasPropertySuccessfulEffortMethodNet.
# Added AccruedAdvertisingCurrent to AccruedIncomeTaxesCurrent.
# Added OtherInventoryNetOfReserves to InventoryFinishedGoodsNetOfReserves.
# Created new clean tag: DepositLiabilitiesAccruedInterest
# Added NetInvestmentInLease to DirectFinancingLeaseNetInvestmentInLease.
# Created new clean tag: AssetsHeldInTrust
# Added SeparateAccountsLiability to SecurityDepositLiability.
# Added InterestAndDividendsPayableCurrent to InterestPayableCurrentAndNoncurrent.
# Added PostemploymentBenefitsLiabilityNoncurrent to OperatingLeaseLiabilityNoncurrent.
# Created new clean tag: AdvancesOnInventoryPurchases
# Created new clean tag: AociTaxAttributableToParent
# Added DeferredCompensationEquity to DeferredCompensationPlanAssets.
# Added MarginDepositAssets to DemandDepositAccounts.
# Added BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedIntangibleAssetsOtherThanGoodwill to BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedAssets.
# Added AllowanceForNotesAndLoansReceivableCurrent to AllowanceForDoubtfulAccountsReceivableCurrent.
# Created new clean tag: SeparateAccountAssets
# Added OilAndGasPropertyFullCostMethodGross to OilAndGasPropertySuccessfulEffortMethodNet.
# Added DerivativeCollateralRightToReclaimSecurities to DerivativeCollateralRightToReclaimCash.
# Created new clean tag: DeferredCostsLeasingAccumulatedAmortization
# Added TemporaryEquityLiquidationPreference to PreferredStockLiquidationPreferenceValue.
# Created new clean tag: AssetsNoncurrentOtherThanNoncurrentInvestmentsAndPropertyPlantAndEquipment
# Added DebtInstrumentCollateralAmount to DebtInstrumentCarryingAmount.
# Added InterestRateDerivativeLiabilitiesAtFairValue to DerivativeNetLiabilityPositionAggregateFairValue.
# Added AccountsReceivableGross to OtherReceivables.
# Added TimeDepositsLessThan100000 to TimeDeposits100000OrMore.
# Added DueFromAffiliateNoncurrent to DueToAffiliateCurrent.
# Added LandImprovements to TenantImprovements.
# Added OtherNotesPayableCurrent to AccountsPayableCurrent.
# Created new clean tag: CapitalizationLongtermDebtAndEquity
# Added DueToOtherRelatedPartiesClassifiedCurrent to NotesPayableRelatedPartiesClassifiedCurrent.
# Added NotesReceivableRelatedPartiesCurrent to NotesPayableRelatedPartiesClassifiedCurrent.
# Added BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedCashAndEquivalents to BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedAssets.
# Added LiabilityForFuturePolicyBenefitsAndUnpaidClaimsAndClaimsAdjustmentExpense to LiabilityForClaimsAndClaimsAdjustmentExpense.
# Added DeferredFinanceCostsGross to DeferredFinanceCostsNet.
# Added InterestBearingDomesticDepositDemand to InterestBearingDepositsInBanks.
# Created new clean tag: MineralPropertiesNet
# Added IndefiniteLivedLicenseAgreements to IndefiniteLivedTrademarks.
# Added NotesAndLoansPayableCurrent to AccountsPayableCurrent.
# Created new clean tag: LoansInsurancePolicy
# Added EmbeddedDerivativeFairValueOfEmbeddedDerivativeLiability to DerivativeFairValueOfDerivativeAsset.
# Created new clean tag: UnrecordedUnconditionalPurchaseObligationBalanceSheetAmount
# Added UnsecuredLongTermDebt to LongTermDebt.
# Created new clean tag: AdvanceRent
# Added ContractWithCustomerAssetGrossCurrent to ContractWithCustomerLiabilityCurrent.
# Created new clean tag: TemporaryEquityRedemptionPricePerShare
# Created new clean tag: LongTermLoansFromBank
# Added LoansPayableToBankCurrent to AccountsPayableCurrent.
# Added PropertyPlantAndEquipmentOtherAccumulatedDepreciation to PublicUtilitiesPropertyPlantAndEquipmentAccumulatedDepreciation.
# Added AllowanceForDoubtfulOtherReceivablesCurrent to AllowanceForDoubtfulAccountsReceivableCurrent.
# Added FiniteLivedIntangibleAssetAcquiredInPlaceLeases to FiniteLivedIntangibleAssetsAccumulatedAmortization.
# Added MortgagesHeldForSaleFairValueDisclosure to AssetsFairValueDisclosure.
# Added AdvancesToAffiliate to DueToAffiliateCurrent.
# Added OtherFiniteLivedIntangibleAssetsGross to FiniteLivedPatentsGross.
# Added NoninterestBearingDomesticDepositDemand to InterestBearingDepositsInBanks.
# Created new clean tag: RealEstateInvestmentsUnconsolidatedRealEstateAndOtherJointVentures
# Added RegulatoryLiabilities to Liabilities.
# Added DepositLiabilityCurrent to SecurityDepositLiability.
# Created new clean tag: ManagementFeePayable
# Created new clean tag: FinancialInstrumentsOwnedUSGovernmentAndAgencyObligationsAtFairValue
# Added InterestBearingDomesticDepositChecking to InterestBearingDepositsInBanks.
# Added SecuritiesSoldUnderAgreementsToRepurchaseGross to SecuritiesSoldUnderAgreementsToRepurchase.
# Added LongTermInvestmentsAndReceivablesNet to AccruedInvestmentIncomeReceivable.
# Created new clean tag: RegulatoryAssets
# Added DerivativeInstrumentsAndHedges to DerivativeAssets.
# Added CustomerAdvancesAndDeposits to CustomerDepositsCurrent.
# Created new clean tag: ShorttermDebtFairValue
# ...
# Added WeightedAverageNumberOfUnitsOutstandingForCalculationOfBasicAndDilutedLossPerCapitalUnit to WeightedAverageNumberOfSharesOutstandingBasic.
# Added WeightedAverageNumberOfShareOutstandingSubjectToRedeemableBasicAndDiluted to WeightedAverageNumberOfSharesOutstandingBasic.
# Added WeightedAverageNumberOfLimitedPartnershipUnitOutstandingBasicAndDiluted to WeightedAverageNumberOfSharesOutstandingBasic.
# Added TemporaryEquitySharesIssuableUponConversionPeriodIncreaseDecrease to TemporaryEquitySharesConversionOfConvertibleSecurities.
# Added WeightedAverageCommonSharesOutstandingBasic to WeightedAverageNumberOfSharesOutstandingBasic.
# Added PartnersCapitalAccountUnitsSoldInPublicOffering to PartnersCapitalAccountUnitsRedeemed.
# Added LimitedPartnersCapitalAccountSharesUnitsSurrendered to PartnersCapitalAccountUnitsRedeemed.
# Added ConversionOfStockSharesIssued1 to ConversionOfStockSharesConverted1.
# Added DebtConversionConvertedInstrumentWarrantsOrOptionsIssuedValue to DebtConversionConvertedInstrumentSharesIssued1.
# Added ShareBasedGoodsAndNonemployeeServicesTransactionSharesApprovedForIssuance to ShareBasedGoodsAndNonemployeeServicesTransactionQuantityOfSecuritiesIssued.
# Created new clean tag: Shareswithheldfortaxesshares
# Created new clean tag: WeightedAverageSharesOutstandingOfCommonStockBasicAndDilutedFoundersAndPrivatePlacementShares
# Created new clean tag: NoncashOrPartNoncashAcquisitionNoncashFinancialOrEquityInstrumentConsiderationSharesIssued1
# Added PartnersCapitalAccountUnitsTreasury to PartnersCapitalAccountUnitsRedeemed.
# Added StockIssuedDuringPeriodSharesPeriodIncreaseDecrease to StockIssuedDuringPeriodSharesStockOptionsExercised.
# Created new clean tag: WeightedAverageNumberOfLimitedPartnershipUnitsIncludingAntidilutiveSecurities
# Added WeightedAverageSharesOfSeniorCommonStockOutstandingBasic to WeightedAverageNumberOfSharesOutstandingBasic.
# Added PartnersCapitalAccountUnitsSoldInPrivatePlacement to PartnersCapitalAccountUnitsRedeemed.
# Created new clean tag: UnitsIssuedForVestingAndExercisedRelatedToCompensationPlans
# Created new clean tag: SharesIssuedForCash
# Created new clean tag: TreasuryStockIssuedDuringPeriodSharesEmployeeBenefitPlan
# Added StockIssuedDuringPeriodSharesDividendReinvestmentPlanAndEmployeeBenefitPlans to TreasuryStockIssuedDuringPeriodSharesEmployeeBenefitPlan.
# Added BasicAndDilutedWeightedAverageSharesOutstandingOfFounderShares to WeightedAverageNumberOfSharesOutstandingBasic.
# Added WeightedAverageNumberOfSharesOutstandingUsedToComputeEarningsPerShareBasicandDiluted to WeightedAverageNumberOfSharesOutstandingBasic.
# Added WeightedAverageNumberOfShareOutstandingBasicAndDilutedNonRredeemableCommonStock to WeightedAverageNumberOfSharesOutstandingBasic.
# Added WeightedAverageLimitedPartnershipUnitsOutstandingSubordinatedBasicAndDiluted to WeightedAverageNumberOfLimitedPartnershipUnitsIncludingAntidilutiveSecurities.
# Added PartnersCapitalAccountUnitsConverted to PartnersCapitalAccountUnitsRedeemed.
# Added WeightedAverageNumberOfAmericanDepositorySharesOutstanding to WeightedAverageNumberOfSharesOutstandingBasic.
# Added Q4StockbasedCompensationInShares to Q3StockbasedCompensationInShares.
# Created new clean tag: TreasuryStockSharesAcquiredCostMethodSettlementOfAcceleratedShareRepurchaseProgram
# Added ReturnOfPreferredStockShares to PreferredStockDividendsShares.
# Created new clean tag: ExerciseOfStockOptionsNetOfCashlessExerciseShares
# Added ShareBasedCompensationArrangementByShareBasedPaymentAwardNonOptionEquityInstrumentsForfeitures to ShareBasedCompensationArrangementByShareBasedPaymentAwardOptionsGrantsInPeriodGross.
# Added WeightedaverageSharesDiluted to WeightedAverageNumberOfSharesOutstandingBasic.
# Added TemporaryEquitySharesConverted to TemporaryEquitySharesConversionOfConvertibleSecurities.
# Added NetExerciseOfStockOptionsAndRelatedTaxBenefitShares to ExerciseOfStockOptionsNetOfCashlessExerciseShares.
# Added StockIssuedDuringPeriodSharesStockBasedCompensationAwards to StockIssuedDuringPeriodSharesStockOptionsExercised.
# Added TemporaryEquityStockIssuedDuringPeriodSharesNewIssues to TreasuryStockIssuedDuringPeriodSharesEmployeeBenefitPlan.
# Added WeightedAverageLimitedLiabilityCompanyUnit to WeightedAverageLimitedLiabilityCompanyUnits.
# Created new clean tag: WeightedAverageSharesUsedInComputingBasicAndDilutedNetLossPerShareFromContinuingOperations
# Added WeightedAverageSharesOutstandingBasicAndDiluted to WeightedAverageNumberOfSharesOutstandingBasic.
# Added UnvestedRestrictedStockShares to VestingOfRestrictedStockSharesDeferred.
# Created new clean tag: ClassOfWarrantOrRightIssued
# Created new clean tag: NumberOfCapitalUnitsSold
# Created new clean tag: IssuanceOfCommonStockFromPerformanceShareUnitsandExerciseofStockOptions
# Created new clean tag: AdjustmentstoAdditionalPaidinCapitalEquityComponentofConvertibleDebtTerminationofCappedCallOptionsShares
# Added BasicAndDilutedWeightedAverageSharesOutstanding to WeightedAverageNumberOfSharesOutstandingBasic.
# Added Q1StockbasedCompensationInShares to Q3StockbasedCompensationInShares.
# Added WeightedAverageShares to WeightedAverageNumberOfSharesOutstandingBasic.
# Added StockIssuedDuringPeriodSharesWarrantsExercised to StockIssuedDuringPeriodSharesStockOptionsExercised.
# Created new clean tag: StockholdersEquityOtherShares
# Added StockIssuedDuringPeriodSharesDirectorStockPurchasePlans to StockIssuedDuringPeriodSharesStockOptionsExercised.
# Added WeightedAverageNumberOfDilutedSharesOutstandingDiscontinuedOperations to WeightedAverageNumberOfSharesOutstandingBasic.
# Added WeightedAverageSharesOutstandingOfRedeemableCommonStock to WeightedAverageNumberOfSharesOutstandingBasic.
# Added WeightedAverageSharesUsedInComputingBasicAndDilutedNetLossPerShareFromDiscontinuedOperations to WeightedAverageSharesUsedInComputingBasicAndDilutedNetLossPerShareFromContinuingOperations.
# Created new clean tag: SurrenderOfSharesUponRestrictedStockAndRestrictedUnitVestingAndExerciseofStockAppreciationRights
# Created new clean tag: RepurchaseOfCommonAndPreferredSharesShares
# Added NumberofStockIssuedDuringPeriodSharesStockOptionsExercisedNetOfTaxes to StockIssuedDuringPeriodSharesStockOptionsExercised.
# Added WeightedAverageNumberOfDilutedSharesOutstandingFromContinuingOperations to WeightedAverageNumberOfSharesOutstandingBasic.
# Added ContinuingOperationWeightedAverageNumberofSharesOutstandingDiluted to WeightedAverageNumberOfSharesOutstandingBasic.
# Created new clean tag: NumberOfCommonUnitsOutstanding
# Created new clean tag: CommonSharesIssuedSharesFromTreasuryStockForStockBasedCompensation
# Added StockIssuedDuringPeriodSharesWarrantExercised to StockIssuedDuringPeriodSharesStockOptionsExercised.
# Added WeightedAverageRedeemableUnitsOutstanding to WeightedAverageNumberOfSharesOutstandingBasic.
# Added BasicAndDilutedWeightedAverageSharesOutstandingOfPublicShares to WeightedAverageNumberOfSharesOutstandingBasic.
# Added StockTenderedDuringPeriodShares to StockRepurchasedAndRetiredDuringPeriodShares.
# Added WeightedAverageNumberOfShareOutstandingNonRedeemableCommonStockBasicAndDiluted to WeightedAverageNumberOfSharesOutstandingBasic.
# Created new clean tag: ReclassificationsofTemporarytoPermanentEquityShares
# Created new clean tag: CommonStockIssuedtoDirectors
# Created new clean tag: IssuanceOfUnitEquivalents
# Created new clean tag: SharesIssuedAsDebtInducementShares
# Created new clean tag: PurchaseOfIntellectualPropertyShares
# Added WeightedAverageNumberOfSharesOutstandingBasicIncludingLimitedPartnershipUnits to WeightedAverageNumberOfSharesOutstandingBasic.
# Initialized tag map
# Created new clean tag: EffectiveIncomeTaxRateReconciliationAtFederalStatutoryIncomeTaxRate
# Added EffectiveIncomeTaxRateReconciliationOtherAdjustments to EffectiveIncomeTaxRateReconciliationAtFederalStatutoryIncomeTaxRate.
# Created new clean tag: DebtInstrumentInterestRateDuringPeriod
# Created new clean tag: TotalReturnAtNetAssetValue
# Created new clean tag: AnnualizedNetInvestmentIncomeLossRatio
# Created new clean tag: PreferredStockDividendRatePercentage
# Created new clean tag: LimitedLiabilityCompanyLLCOrLimitedPartnershipLPManagingMemberOrGeneralPartnerOwnershipInterest
# Added LimitedLiabilityCompanyLLCOrLimitedPartnershipLPMembersOrLimitedPartnersOwnershipInterest to LimitedLiabilityCompanyLLCOrLimitedPartnershipLPManagingMemberOrGeneralPartnerOwnershipInterest.
# Created new clean tag: AnnualizedRateOfSponsorsFee
# Created new clean tag: StockholdersEquityNoteStockSplitConversionRatio1
# Created new clean tag: RevenueAsAPercentageOfNetSales
# Created new clean tag: RatioOfTotalExpensesToAverageNetAssetValue
# Created new clean tag: IncomeTaxExpenseBenefitNetPercentage
# Created new clean tag: NetlossgainonconvertibledebtderivativesasaPercentofNetSales
# Created new clean tag: Restructuringchargepercenttosales
# Created new clean tag: LaborAndOtherOperatingExpensesNetPercentage
# Created new clean tag: AnnualizedDividendRateOnCapitalStock
# Created new clean tag: CostOfGoodsAndServicesSoldPercent
# Added OtherNonoperatingIncomeExpenseNetPercentage to LaborAndOtherOperatingExpensesNetPercentage.
# Created new clean tag: ResearchAndDevelopmentExpenseExcludingAcquiredInProcessCostPercentToSales
# Added OperatingIncomeLossasaPercentageofNetSales to RevenueAsAPercentageOfNetSales.
# Created new clean tag: GrossProfitPercentage
# Added NonoperatingIncomeExpenseNetPercentage to LaborAndOtherOperatingExpensesNetPercentage.
# Created new clean tag: NetIncomeLossPercentage
# Added IncomeTaxExpenseBenefitPercent to IncomeTaxExpenseBenefitNetPercentage.
# Added GrossProfitasaPercentageofNetSales to GrossProfitPercentage.
# Created new clean tag: SellinggeneralandadministrativeexpensesasaPercentofNetSales
# Created new clean tag: NoncontrollingInterestWeightedAverageOwnershipPercentage
# Added RatioOfPerformanceFeeToAverageNetAssetValue to RatioOfTotalExpensesToAverageNetAssetValue.
# Added CostOfGoodsAndServicesSoldNetPercentage to CostOfGoodsAndServicesSoldPercent.
# Created new clean tag: CostofProductsSoldasaPercentofNetSales
# Added CostOfGoodsSoldPercentToSales to CostofProductsSoldasaPercentofNetSales.
# Added SellingGeneralAndAdministrativeExpensesNetPercentage to SellinggeneralandadministrativeexpensesasaPercentofNetSales.
# Added InterestExpensePercent to LaborAndOtherOperatingExpensesNetPercentage.
# Added OtherNonOperatingIncomeExpensePercentToSales to LaborAndOtherOperatingExpensesNetPercentage.
# Added GrossProfitPercentToSales to GrossProfitPercentage.
# Added PreferredStockClassifiedAsDebtDividendRatePercentage to PreferredStockDividendRatePercentage.
# Created new clean tag: InvestmentIncomeInterestPercentToSales
# Added RatioOfExpensesPriorToPerformanceFeeToAverageNetAssetValue to RatioOfTotalExpensesToAverageNetAssetValue.
# Created new clean tag: OtherComprehensiveIncomeLossOtherIncomeLossNetOfTaxPercent
# Created new clean tag: IncomeLossFromContinuingOperationsBeforeIncomeTaxesMinorityInterestAndIncomeLossFromEquityMethodInvestmentsPercentToSales
# Added RevenuesPercentage to RevenueAsAPercentageOfNetSales.
# Added GainlossBeforeIncomeTaxesasaPercentofNetSales to CostofProductsSoldasaPercentofNetSales.
# Created new clean tag: PercentageOfOwnedCompaniesDerivativeLossesOnCashFlowHedgesReclassificationToEquityInEarnings
# Added RatioOfNetInvestmentIncomeLossToAverageNetAssetValue to RatioOfTotalExpensesToAverageNetAssetValue.
# Added CostofGoodsSoldasaPercentageofNetSales to CostofProductsSoldasaPercentofNetSales.
# Added NetIncomeAttributableToParentPercentToSales to InvestmentIncomeInterestPercentToSales.
# Added IncomeTaxExpenseBenefitasaPercentageofNetSales to IncomeTaxExpenseBenefitNetPercentage.
# Added StockDividendsDistributedPercentOfEarnings to PreferredStockDividendRatePercentage.
# Added AnnualizedRateOfSponsorsFeeBeforeWaiver to AnnualizedRateOfSponsorsFee.
# Added OperatingIncomeLossPercent to NetIncomeLossPercentage.
# Created new clean tag: DepreciationDepletionAndAmortizationNetPercentage
# Added GrossProfitasaPercentofNetSales to GrossProfitPercentage.
# Created new clean tag: DividendsCashAnnualizedRate
# Added NetSalesasaPercentofNetSales to RevenueAsAPercentageOfNetSales.
# Created new clean tag: DebtInstrumentBasisSpreadOnVariableRate1
# Created new clean tag: InterestIncomeExpenseNonoperatingNetasaPercentageofNetSales
# Added IncomeTaxExpenseBenefitPercentToSales to IncomeTaxExpenseBenefitNetPercentage.
# Added GrossProfitPercent to GrossProfitPercentage.
# Added IncomeLossFromContinuingOperationsBeforeIncomeTaxesMinorityInterestAndIncomeLossFromEquityMethodInvestmentsNetPercentage to IncomeLossFromContinuingOperationsBeforeIncomeTaxesMinorityInterestAndIncomeLossFromEquityMethodInvestmentsPercentToSales.
# Added ComprehensiveIncomeNetOfTaxPercent to OtherComprehensiveIncomeLossOtherIncomeLossNetOfTaxPercent.
# Added GrossProfitNetPercentage to GrossProfitPercentage.
# Created new clean tag: NumberOfReportableSegments
# Created new clean tag: ChargesrelatedtorestructuringactivitiesasaPercentofNetSales
# Created new clean tag: WeightedAverageNumberOfGoldReceipts
# Created new clean tag: DebtConversionOriginalDebtInterestRateOfDebt
# Created new clean tag: TotalReturnPercentage
# Added SellingGeneralandAdministrativeExpenseasaPercentageofNetSales to SellinggeneralandadministrativeexpensesasaPercentofNetSales.
# Added IncomeLossfromContinuingOperationsbeforeIncomeTaxesExtraordinaryItemsNoncontrollingInterestPercent to IncomeLossFromContinuingOperationsBeforeIncomeTaxesMinorityInterestAndIncomeLossFromEquityMethodInvestmentsPercentToSales.
# Added InterestExpenseNetPercentage to LaborAndOtherOperatingExpensesNetPercentage.
# Added SellingGeneralAndAdministrativeExpensePercentToSales to SellinggeneralandadministrativeexpensesasaPercentofNetSales.
# Added InterestexpenseasaPercentofNetSales to InterestIncomeExpenseNonoperatingNetasaPercentageofNetSales.
# Created new clean tag: TotalExpenses
# Added SellingGeneralAdministrativeExpenseAsPercentNetSales to SellinggeneralandadministrativeexpensesasaPercentofNetSales.
# Created new clean tag: OtherComprehensiveIncomeForeignCurrencyTransactionAndTranslationGainLossArisingDuringPeriodNetOfTaxPercent
# Created new clean tag: NetincomeLossAttributabletoParentasaPercentageofNetSales
# Added DepreciationAndAmortizationPercent to DepreciationDepletionAndAmortizationNetPercentage.
# Added VariableInterestEntityOwnershipPercentage to NoncontrollingInterestWeightedAverageOwnershipPercentage.
# Created new clean tag: InvestmentOwnedContractsIssued
# Added IncomeTaxProvisionasaPercentofNetSales to CostofProductsSoldasaPercentofNetSales.
# Added SellingGeneralAndAdministrativeExpensePercent to SellinggeneralandadministrativeexpensesasaPercentofNetSales.
# Added OperatingProfitNetPercentage to GrossProfitPercentage.
# Created new clean tag: RevenueFromContractWithCustomerExcludingAssessedTaxPercentage
# Added NetInvestmentLossRatio to AnnualizedNetInvestmentIncomeLossRatio.
# Added NetGainLossasapercentofNetSales to NetincomeLossAttributabletoParentasaPercentageofNetSales.
# Added TotalReturnNetAssetValue to TotalReturnAtNetAssetValue.
# Created new clean tag: ExpenseRatio
# Created new clean tag: ChangeInNetAssetsFromOperationsPerReceipt
# Added InterestExpensePercentToSales to InvestmentIncomeInterestPercentToSales.
# Added NetIncomeLossAttributabletoParentPercent to NetincomeLossAttributabletoParentasaPercentageofNetSales.
# Added SalesRevenueGoodsNetPercentToSales to RevenueAsAPercentageOfNetSales.
# Added GrossProfitRatio to GrossProfitPercentage.
# Added WeightedAverageCostOfBorrowings to WeightedAverageNumberOfGoldReceipts.
# Created new clean tag: MortgageLoansOnRealEstateInterestRate
# Added OtherComprehensiveIncomeLossNetOfTaxPercent to OtherComprehensiveIncomeLossOtherIncomeLossNetOfTaxPercent.
# Created new clean tag: IncomeLossfromContinuingOperationsbeforeEquityMethodInvestmentsIncomeTaxesExtraordinaryItemsNoncontrollingInterestasaPercentageofNetSales
# Added InterestincomeasaPercentofNetSales to InterestIncomeExpenseNonoperatingNetasaPercentageofNetSales.
# Added OperatingGainLossasaPercentofNetSales to CostofProductsSoldasaPercentofNetSales.

# %%
for map in list_of_maps:
    if len(map) == 0:
        list_of_maps.remove(map)

# %%
[len(list_of_maps[i]) for i in range(len(list_of_maps))]
# Out:
# [1689, 73, 25, 2392, 66, 44, 0]

# %% [markdown]
# We'll convert these dictionary tag maps to a data-frame to easily use SQL-style joins.

# %%
tag_map_df = pd.DataFrame(columns = ['clean_tag', 'tag', 'uom', 'qtrs'])
tag_map_df
# Out:
# Empty DataFrame
# Columns: [clean_tag, tag, uom, qtrs]
# Index: []

# %%
i = 0

for qtr in unique_qtr:
    for uom in unique_uom:
        map_df = pd.DataFrame(dict([(k,pd.Series(v)) for k,v in list_of_maps[i].items()]))\
            .melt()\
            .dropna()\
            .rename({'variable':'clean_tag', 'value':'tag'}, axis = 'columns')
        map_df['uom'] = uom
        map_df['qtrs'] = qtr
        tag_map_df = tag_map_df.append(map_df, ignore_index = True)
        
        i += 1

# %%
print("Consolidated ",round((1-len(tag_map_df.clean_tag.unique())/len(tag_map_df.tag.unique()))*100,2),"% of tags", sep = "")
# Out:
# Consolidated 78.11% of tags

# %% [markdown]
# In addition to the algorithm, we use domain knowledge to add in exceptions.

# %%
~(pd.array([True, False, False])&pd.array([True, False, False])&pd.array([True, False, False]))
# Out:
# <PandasArray>
# [False, True, True]
# Length: 3, dtype: bool

# %%
tag_map_df = tag_map_df.query("~((clean_tag == 'InterestExpense')&(qtrs == 0))")\
    .query("~((clean_tag == 'ShareBasedCompensation')&(qtrs == 0))")\
    .query("~((clean_tag == 'AmortizationOfDebtDiscountPremium')&(qtrs == 0))")\
    .query("~((clean_tag == 'PaymentsOfStockIssuanceCosts')&(qtrs == 0))")

# %% [markdown]
# ## Save <a name="Save"></a>
# Save tag map to build/clean

# %%
# Save
tag_map_df.to_csv(data_root+'02-build/clean/2019q3/tag_map.csv', index = False)
