# %% [markdown]
# # Program Header

# %%
import pandas as pd
import numpy as np
import autoreload
import os
import sys
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
nb_dir = os.path.split(os.getcwd())[0]
if nb_dir not in sys.path:
    sys.path.append(nb_dir)
from header import *

# %%
data_root = initialize_data_root("AH")

# %%
import math

# %% [markdown]
# # Table of contents
# 1. [Import](#Import)
# 2. [Data Understanding](#DataUnderstanding)
# 3. [Clean](#Clean)
# 4. [Merge](#Merge)
# 5. [Further Cleaning](#FurtherCleaning)
# 6. [Save](#Save)

# %% [markdown]
# ## Import <a name="Import"></a>

# %%
raw_num_data = pd.read_csv(data_root+'02-build/raw/2019q3/num.csv')
raw_pre_data = pd.read_csv(data_root+'02-build/raw/2019q3/pre.csv')
raw_sub_data = pd.read_csv(data_root+'02-build/raw/2019q3/sub.csv')
raw_tag_data = pd.read_csv(data_root+'02-build/raw/2019q3/tag.csv')

# %% [markdown]
# ## Data Understanding <a name="DataUnderstanding"></a>

# %% [markdown]
# Useful columns based on reading the readme.txt:
# * **num**: Numeric data and actual values associated to `adsh-ddate-tag-etc`. All columns are relevant
# * **pre**: Location of tags and a preferred label (`plabel`). `plabel` (and joining columns) seems relevant
# * **sub**: Summary information about submission. Business-specific information including industry and company name are relevant
# * **tag**: Tag-level dataset. `doc` seems to be a more descriptive `plabel` from **pre** dataset

# %% [markdown]
# ## Clean <a name="Clean"></a>
# Clean the individual datasets to prepare for the merge

# %%
raw_num_data.head()
# Out:
#                    adsh                                  tag      version  \
# 0  0001625376-19-000017                    EntityPublicFloat     dei/2014
# 1  0000034563-19-000064  DerivativeNonmonetaryNotionalAmount  invest/2013
# 2  0000034563-19-000064  DerivativeNonmonetaryNotionalAmount  invest/2013
# 3  0001370946-19-000033  DerivativeNonmonetaryNotionalAmount  invest/2013
# 4  0000225648-19-000108  DerivativeNonmonetaryNotionalAmount  invest/2013
#
#   coreg     ddate  qtrs    uom       value footnote
# 0   NaN  20180430     0    USD         0.0      NaN
# 1   NaN  20190630     0     lb  48183000.0      NaN
# 2   NaN  20180630     0     lb  43459000.0      NaN
# 3   NaN  20190630     0  MMBTU         2.0      NaN
# 4   NaN  20190630     0     MW   4300000.0      NaN

# %%
raw_pre_data.head()
# Out:
#                    adsh  report  line stmt  inpth rfile  \
# 0  0001625376-19-000017       1     9   CP      0     H
# 1  0001625376-19-000017       1    14   CP      0     H
# 2  0001625376-19-000019       1    11   CP      0     H
# 3  0001766016-19-000005       1    10   CP      0     H
# 4  0001047469-19-004442       1     6   CP      0     H
#
#                        tag   version                      plabel  negating
# 0        EntityPublicFloat  dei/2014         Entity Public Float         0
# 1  DocumentFiscalYearFocus  dei/2014  Document Fiscal Year Focus         0
# 2  DocumentFiscalYearFocus  dei/2014  Document Fiscal Year Focus         0
# 3  DocumentFiscalYearFocus  dei/2014  Document Fiscal Year Focus         0
# 4  DocumentFiscalYearFocus  dei/2014  Document Fiscal Year Focus         0

# %%
raw_sub_data.head()
# Out:
#                    adsh   cik                               name     sic  \
# 0  0000002178-19-000086  2178     ADAMS RESOURCES & ENERGY, INC.  5172.0
# 1  0000002488-19-000104  2488         ADVANCED MICRO DEVICES INC  3674.0
# 2  0000002488-19-000113  2488         ADVANCED MICRO DEVICES INC  3674.0
# 3  0000002488-19-000144  2488         ADVANCED MICRO DEVICES INC  3674.0
# 4  0000002969-19-000042  2969  AIR PRODUCTS & CHEMICALS INC /DE/  2810.0
#
#   countryba stprba       cityba       zipba                    bas1 bas2  ...  \
# 0        US     TX      HOUSTON       77027  17 S. BRIAR HOLLOW LN.  NaN  ...
# 1        US     CA  SANTA CLARA       95054    2485 AUGUSTINE DRIVE  NaN  ...
# 2        US     CA  SANTA CLARA       95054    2485 AUGUSTINE DRIVE  NaN  ...
# 3        US     CA  SANTA CLARA       95054    2485 AUGUSTINE DRIVE  NaN  ...
# 4        US     PA    ALLENTOWN  18195-1501      7201 HAMILTON BLVD  NaN  ...
#
#      period      fy  fp     filed               accepted prevrpt detail  \
# 0  20190630  2019.0  Q2  20190807  2019-08-07 17:21:00.0       0      1
# 1  20190630  2019.0  Q2  20190731  2019-07-31 16:27:00.0       0      1
# 2  20190731  2019.0  Q3  20190808  2019-08-08 16:10:00.0       0      0
# 3  20190831  2019.0  Q3  20190906  2019-09-06 16:11:00.0       0      0
# 4  20190630  2019.0  Q3  20190725  2019-07-25 13:02:00.0       0      1
#
#                          instance nciks  aciks
# 0             ae-20190630_htm.xml     1    NaN
# 1          amd0629201910q_htm.xml     1    NaN
# 2       amdform8k08082019_htm.xml     1    NaN
# 3  amdform8kequitysalesse_htm.xml     1    NaN
# 4       apd-10qx30jun2019_htm.xml     1    NaN
#
# [5 rows x 36 columns]

# %%
raw_tag_data.head()
# Out:
#                         tag      version  custom  abstract   datatype iord  \
# 0         EntityPublicFloat     dei/2014       0         0   monetary    I
# 1   DocumentFiscalYearFocus     dei/2014       0         0      gYear    D
# 2     DocumentPeriodEndDate     dei/2014       0         0       date    D
# 3  CurrentFiscalYearEndDate     dei/2014       0         0  gMonthDay    D
# 4            InvestmentAxis  invest/2013       0         1       axis  NaN
#
#   crdr                        tlabel  \
# 0    C           Entity Public Float
# 1  NaN    Document Fiscal Year Focus
# 2  NaN      Document Period End Date
# 3  NaN  Current Fiscal Year End Date
# 4  NaN             Investment [Axis]
#
#                                                  doc
# 0  State aggregate market value of voting and non...
# 1  This is focus fiscal year of the document repo...
# 2  The end date of the period reflected on the co...
# 3  End date of current fiscal year in the format ...
# 4  A categorization of investments (securities, d...

# %% [markdown]
# ## Clean <a name="Clean"></a>

# %%
pre_data = raw_num_data\
    .filter(['adsh', 'tag', 'version', 'plabel'], axis = 'columns')\
    .drop_duplicates()

# %%
sub_data = raw_sub_data\
    .filter(['adsh', 'cik', 'name', 'sic', 'countryba', 'period', 'form', 'fye', 'accepted', 'instance'], axis = 'columns')\
    .rename(mapper = {'name':'company_name', 'countryba':'country'}, axis = 'columns')\
    .assign(period = pd.to_datetime(raw_sub_data['period'], format='%Y%m%d', errors = 'coerce'))\
    .assign(dyear = raw_num_data['ddate'].map(lambda x: math.floor(x/10000)))\
    .query("form in ['10-Q', '10-K']") # Keep only the quarterly and annual filings

# %%
tag_data = raw_tag_data\
    .filter(['tag', 'version', 'doc'])\
    .drop_duplicates()

# %%
tag_data['doc'][0]
# Out:
# "State aggregate market value of voting and non-voting common equity held by non-affiliates computed by reference to price at which the common equity was last sold, or average bid and asked price of such common equity, as of the last business day of registrant's most recently completed second fiscal quarter. The public float should be reported on the cover page of the registrants form 10K."

# %%
# Get rid of coregister/parent company
# Keep only the balance sheet and single quarter flows

num_data = raw_num_data\
    .drop('footnote', axis = 'columns')\
    .assign(no_coreg = pd.isna(raw_num_data['coreg']))\
    .assign(no_value = pd.isna(raw_num_data['value']))\
    .assign(ddate = pd.to_datetime(raw_num_data['ddate'], format = '%Y%m%d', errors = 'coerce'))\
    .query("(no_coreg == True) & (no_value == False)")\
    .query("(qtrs in (0,1))")\
    .query("uom in ('USD', 'shares', 'pure')")\
    .query("(ddate >= '2019-01-01')&(ddate <= '2019-12-31')")

# %%
num_data.shape
# Out:
# (697055, 10)

# %% [markdown]
# ## Merge <a name="Merge"></a>

# %%
num_data.columns
# Out:
# Index(['adsh', 'tag', 'version', 'coreg', 'ddate', 'qtrs', 'uom', 'value',
#        'no_coreg', 'no_value'],
#       dtype='object')

# %%
sec_data = num_data.merge(pre_data, on = ['adsh', 'tag', 'version'])\
    .merge(sub_data, on = ['adsh'])\
    .merge(tag_data, on = ['tag', 'version'])\
    .reset_index(drop = True)

# %% [markdown]
# ## Further Cleaning  <a name="FurtherCleaning"></a>

# %% [markdown]
# We need to decide whether to use the `period` as our variable date or `ddate` as our variable date. According to the readme, `ddate` is more accurate. However, it is also much more unstable and some `ddates` even have impossible values, i.e. 2021 shares outstanding values for 2019q3 data. We've decided to keep the maximum `ddate` observation within an `adsh, tag, period` observation.

# %% [markdown]
# See if we have **sec_data** observations at the `adsh, tag, period` level

# %%
multiple_matches = sec_data.groupby(['adsh', 'tag', 'period'], as_index = False)\
    .count()\
    .sort_values('value', ascending = False)\
    .query("value > 1")

# %%
multiple_matches
# Out:
#                         adsh  \
# 260676  0001476045-19-000069
# 260739  0001476045-19-000069
# 382934  0001564590-19-031281
# 381022  0001564590-19-031229
# 60389   0000826675-19-000046
# 381024  0001564590-19-031229
# 45433   0000726728-19-000079
# 381026  0001564590-19-031229
# 382938  0001564590-19-031281
# 233012  0001428205-19-000214
# 429168  0001635650-19-000029
# 429167  0001635650-19-000029
# 458754  0001717547-19-000014
# 458753  0001717547-19-000014
# 265620  0001479094-19-000018
# 139258  0001144204-19-034727
# 139264  0001144204-19-034727
# 458688  0001717307-19-000046
# 320704  0001558370-19-007621
# 228672  0001410578-19-000660
# 208319  0001318084-19-000048
# 304883  0001556593-19-000015
# 215687  0001362988-19-000096
# 428012  0001631596-19-000014
# 116095  0001078782-19-000658
# 384427  0001564590-19-031501
# 139253  0001144204-19-034727
# 309634  0001558370-19-006710
# 428185  0001632790-19-000047
# 428274  0001632790-19-000047
# ...                      ...
# 12708   0000040211-19-000062
# 251823  0001437749-19-018069
# 251816  0001437749-19-018069
# 12705   0000040211-19-000062
# 251815  0001437749-19-018069
# 390462  0001564590-19-033247
# 122170  0001099219-19-000138
# 12707   0000040211-19-000062
# 251807  0001437749-19-018069
# 198642  0001232582-19-000044
# 251843  0001437749-19-018069
# 251833  0001437749-19-018069
# 251842  0001437749-19-018069
# 251830  0001437749-19-018069
# 296665  0001528930-19-000031
# 183026  0001213900-19-014847
# 251840  0001437749-19-018069
# 12698   0000040211-19-000062
# 251839  0001437749-19-018069
# 296675  0001528930-19-000031
# 390464  0001564590-19-033247
# 401022  0001585364-19-000083
# 122163  0001099219-19-000138
# 251844  0001437749-19-018069
# 251831  0001437749-19-018069
# 69806   0000876523-19-000044
# 251838  0001437749-19-018069
# 231410  0001418135-19-000054
# 122161  0001099219-19-000138
# 251806  0001437749-19-018069
#
#                                                       tag     period  version  \
# 260676               CommonStockDividendsPerShareDeclared 2019-06-30        8
# 260739       RegularDistributionsOnLongTermInvestmentPlan 2019-06-30        8
# 382934                                         SharePrice 2019-06-30        6
# 381022                                         SharePrice 2019-06-30        6
# 60389                CommonStockDividendsPerShareDeclared 2019-06-30        6
# 381024            StockRedeemedOrCalledDuringPeriodShares 2019-06-30        6
# 45433                CommonStockDividendsPerShareCashPaid 2019-06-30        6
# 381026                 StockRepurchasedDuringPeriodShares 2019-06-30        6
# 382938       StockRepurchasedAndRetiredDuringPeriodShares 2019-06-30        6
# 233012               CommonStockDividendsPerShareCashPaid 2019-06-30        5
# 429168  DistributionMadeToLimitedPartnerDistributionsP... 2019-06-30        5
# 429167  DistributionMadeToLimitedPartnerCashDistributi... 2019-06-30        5
# 458754               CommonStockDividendsPerShareDeclared 2019-06-30        5
# 458753               CommonStockDividendsPerShareCashPaid 2019-06-30        5
# 265620               CommonStockDividendsPerShareCashPaid 2019-06-30        5
# 139258                                      NetIncomeLoss 2019-03-31        4
# 139264                                           Revenues 2019-03-31        4
# 458688                           DividendsCommonStockCash 2019-06-30        4
# 320704                PartnersCapitalAccountDistributions 2019-06-30        4
# 228672               CommonStockDividendsPerShareDeclared 2019-06-30        4
# 208319               CommonStockDividendsPerShareDeclared 2019-06-30        4
# 304883        PaymentsToAcquireMortgageServicingRightsMSR 2019-06-30        4
# 215687                           DividendsCommonStockCash 2019-06-30        4
# 428012               CommonStockDividendsPerShareDeclared 2019-06-30        4
# 116095                                         SharePrice 2019-06-30        4
# 384427                           DividendsCommonStockCash 2019-06-30        4
# 139253                                        GrossProfit 2019-03-31        4
# 309634               CommonStockDividendsPerShareDeclared 2019-06-30        4
# 428185               CommonStockDividendsPerShareDeclared 2019-06-30        4
# 428274            PreferredStockDividendsPerShareDeclared 2019-06-30        4
# ...                                                   ...        ...      ...
# 12708   OtherComprehensiveIncomeLossReclassificationAd... 2019-06-30        2
# 251823                ContractWithCustomerAssetNetCurrent 2019-07-31        2
# 251816  CapitalizedComputerSoftwareAccumulatedAmortiza... 2019-07-31        2
# 12705   OtherComprehensiveIncomeLossPensionAndOtherPos... 2019-06-30        2
# 251815                                      AssetsCurrent 2019-07-31        2
# 390462                                        Liabilities 2019-07-31        2
# 122170               TreasuryStockValueAcquiredCostMethod 2019-06-30        2
# 12707   OtherComprehensiveIncomeLossReclassificationAd... 2019-06-30        2
# 251807                       AccountsReceivableNetCurrent 2019-07-31        2
# 198642               CommonStockDividendsPerShareDeclared 2019-06-30        2
# 251843                                      GoodwillGross 2019-07-31        2
# 251833                           DividendsCommonStockCash 2019-07-31        2
# 251842                                           Goodwill 2019-07-31        2
# 251830                    DeferredTaxAssetsLiabilitiesNet 2019-07-31        2
# 296665                       PropertyPlantAndEquipmentNet 2019-07-31        2
# 183026  StockIssuedDuringPeriodValueSubjectToPossibleR... 2019-06-30        2
# 251840                     FiniteLivedIntangibleAssetsNet 2019-07-31        2
# 12698   OtherComprehensiveIncomeForeignCurrencyTransac... 2019-06-30        2
# 251839                   FiniteLivedIntangibleAssetsGross 2019-07-31        2
# 296675                 RetainedEarningsAccumulatedDeficit 2019-07-31        2
# 390464                                 LiabilitiesCurrent 2019-07-31        2
# 401022                           DividendsCommonStockCash 2019-06-30        2
# 122163  StockholdersEquityIncludingPortionAttributable... 2019-06-30        2
# 251844          GoodwillImpairedAccumulatedImpairmentLoss 2019-07-31        2
# 251831                DeferredTaxAssetsValuationAllowance 2019-07-31        2
# 69806   AdjustmentsToAdditionalPaidInCapitalSharebased... 2019-06-30        2
# 251838  FiniteLivedIntangibleAssetsAccumulatedAmortiza... 2019-07-31        2
# 231410  AdjustmentsToAdditionalPaidInCapitalSharebased... 2019-06-30        2
# 122161  StockIssuedDuringPeriodValueShareBasedCompensa... 2019-06-30        2
# 251806        AccountsPayableAndAccruedLiabilitiesCurrent 2019-07-31        2
#
#         coreg  ddate  qtrs  uom  value  no_coreg  ...  cik  company_name  sic  \
# 260676      0      8     8    8      8         8  ...    8             8    8
# 260739      0      8     8    8      8         8  ...    8             8    8
# 382934      0      6     6    6      6         6  ...    6             6    6
# 381022      0      6     6    6      6         6  ...    6             6    6
# 60389       0      6     6    6      6         6  ...    6             6    6
# 381024      0      6     6    6      6         6  ...    6             6    6
# 45433       0      6     6    6      6         6  ...    6             6    6
# 381026      0      6     6    6      6         6  ...    6             6    6
# 382938      0      6     6    6      6         6  ...    6             6    6
# 233012      0      5     5    5      5         5  ...    5             5    5
# 429168      0      5     5    5      5         5  ...    5             5    5
# 429167      0      5     5    5      5         5  ...    5             5    5
# 458754      0      5     5    5      5         5  ...    5             5    5
# 458753      0      5     5    5      5         5  ...    5             5    5
# 265620      0      5     5    5      5         5  ...    5             5    5
# 139258      0      4     4    4      4         4  ...    4             4    4
# 139264      0      4     4    4      4         4  ...    4             4    4
# 458688      0      4     4    4      4         4  ...    4             4    4
# 320704      0      4     4    4      4         4  ...    4             4    4
# 228672      0      4     4    4      4         4  ...    4             4    4
# 208319      0      4     4    4      4         4  ...    4             4    4
# 304883      0      4     4    4      4         4  ...    4             4    4
# 215687      0      4     4    4      4         4  ...    4             4    4
# 428012      0      4     4    4      4         4  ...    4             4    4
# 116095      0      4     4    4      4         4  ...    4             4    4
# 384427      0      4     4    4      4         4  ...    4             4    4
# 139253      0      4     4    4      4         4  ...    4             4    4
# 309634      0      4     4    4      4         4  ...    4             4    4
# 428185      0      4     4    4      4         4  ...    4             4    4
# 428274      0      4     4    4      4         4  ...    4             4    4
# ...       ...    ...   ...  ...    ...       ...  ...  ...           ...  ...
# 12708       0      2     2    2      2         2  ...    2             2    2
# 251823      0      2     2    2      2         2  ...    2             2    2
# 251816      0      2     2    2      2         2  ...    2             2    2
# 12705       0      2     2    2      2         2  ...    2             2    2
# 251815      0      2     2    2      2         2  ...    2             2    2
# 390462      0      2     2    2      2         2  ...    2             2    2
# 122170      0      2     2    2      2         2  ...    2             2    2
# 12707       0      2     2    2      2         2  ...    2             2    2
# 251807      0      2     2    2      2         2  ...    2             2    2
# 198642      0      2     2    2      2         2  ...    2             2    2
# 251843      0      2     2    2      2         2  ...    2             2    2
# 251833      0      2     2    2      2         2  ...    2             2    2
# 251842      0      2     2    2      2         2  ...    2             2    2
# 251830      0      2     2    2      2         2  ...    2             2    2
# 296665      0      2     2    2      2         2  ...    2             2    2
# 183026      0      2     2    2      2         2  ...    2             2    2
# 251840      0      2     2    2      2         2  ...    2             2    2
# 12698       0      2     2    2      2         2  ...    2             2    2
# 251839      0      2     2    2      2         2  ...    2             2    2
# 296675      0      2     2    2      2         2  ...    2             2    2
# 390464      0      2     2    2      2         2  ...    2             2    2
# 401022      0      2     2    2      2         2  ...    2             2    2
# 122163      0      2     2    2      2         2  ...    2             2    2
# 251844      0      2     2    2      2         2  ...    2             2    2
# 251831      0      2     2    2      2         2  ...    2             2    2
# 69806       0      2     2    2      2         2  ...    2             2    2
# 251838      0      2     2    2      2         2  ...    2             2    2
# 231410      0      2     2    2      2         2  ...    2             2    2
# 122161      0      2     2    2      2         2  ...    2             2    2
# 251806      0      2     2    2      2         2  ...    2             2    2
#
#         country  form  fye  accepted  instance  dyear  doc
# 260676        8     8    8         8         8      8    8
# 260739        8     8    8         8         8      8    8
# 382934        6     6    6         6         6      6    6
# 381022        6     6    6         6         6      6    6
# 60389         6     6    6         6         6      6    6
# 381024        6     6    6         6         6      6    6
# 45433         6     6    6         6         6      6    6
# 381026        6     6    6         6         6      6    6
# 382938        6     6    6         6         6      6    6
# 233012        5     5    5         5         5      5    5
# 429168        5     5    5         5         5      5    5
# 429167        5     5    5         5         5      5    5
# 458754        5     5    5         5         5      5    5
# 458753        5     5    5         5         5      5    5
# 265620        5     5    5         5         5      5    5
# 139258        4     4    4         4         4      4    4
# 139264        4     4    4         4         4      4    4
# 458688        4     4    4         4         4      4    4
# 320704        4     4    4         4         4      4    4
# 228672        4     4    4         4         4      4    4
# 208319        4     4    4         4         4      4    4
# 304883        4     4    4         4         4      4    4
# 215687        4     4    4         4         4      4    4
# 428012        4     4    4         4         4      4    4
# 116095        4     4    4         4         4      4    4
# 384427        4     4    4         4         4      4    4
# 139253        4     4    4         4         4      4    4
# 309634        4     4    4         4         4      4    4
# 428185        4     4    4         4         4      4    4
# 428274        4     4    4         4         4      4    4
# ...         ...   ...  ...       ...       ...    ...  ...
# 12708         2     2    2         2         2      2    2
# 251823        2     2    2         2         2      2    2
# 251816        2     2    2         2         2      2    2
# 12705         2     2    2         2         2      2    2
# 251815        2     2    2         2         2      2    2
# 390462        2     2    2         2         2      2    2
# 122170        2     2    2         2         2      2    2
# 12707         2     2    2         2         2      2    2
# 251807        2     2    2         2         2      2    2
# 198642        2     2    2         2         2      2    2
# 251843        2     2    2         2         2      2    2
# 251833        2     2    2         2         2      2    2
# 251842        2     2    2         2         2      2    2
# 251830        2     2    2         2         2      2    2
# 296665        2     2    2         2         2      2    2
# 183026        2     2    2         2         2      2    2
# 251840        2     2    2         2         2      2    2
# 12698         2     2    2         2         2      2    2
# 251839        2     2    2         2         2      2    2
# 296675        2     2    2         2         2      2    2
# 390464        2     2    2         2         2      2    2
# 401022        2     2    2         2         2      2    2
# 122163        2     2    2         2         2      2    2
# 251844        2     2    2         2         2      2    2
# 251831        2     2    2         2         2      2    2
# 69806         2     2    2         2         2      2    2
# 251838        2     2    2         2         2      2    2
# 231410        2     2    2         2         2      2    2
# 122161        2     2    2         2         2      2    2
# 251806        2     2    2         2         2      2    2
#
# [37440 rows x 21 columns]

# %% [markdown]
# We'll keep only the max `ddate` within each `adsh, tag, period`.

# %%
sec_data = sec_data.loc[sec_data.groupby(['adsh', 'tag', 'period'], as_index = False)['ddate'].idxmax()]

# %%
multiple_matches = sec_data.groupby(['adsh', 'tag', 'period'], as_index = False)\
    .count()\
    .sort_values('value', ascending = False)\
    .query("value > 1")

# %%
multiple_matches
# Out:
# Empty DataFrame
# Columns: [adsh, tag, period, version, coreg, ddate, qtrs, uom, value, no_coreg, no_value, cik, company_name, sic, country, form, fye, accepted, instance, dyear, doc]
# Index: []
#
# [0 rows x 21 columns]

# %%
old_rows = raw_num_data.shape[0]
new_rows = sec_data.shape[0]

print("We've gone from ", old_rows, " to ", new_rows, " observations.")
print("That is a ",math.floor((1-new_rows/old_rows)*100),"% decrease.", sep = "")
# Out:
# We've gone from  2325267  to  465540  observations.
# That is a 79% decrease.

# %% [markdown]
# The issue we will tackle in the next part will be that there are too many tags to reshape the data easily:

# %%
print("Raw version tags:",len(raw_num_data.tag.unique()))
print("Cleaned version tags:",len(sec_data.tag.unique()))
# Out:
# Raw version tags: 120892
# Cleaned version tags: 19300

# %% [markdown]
# ## Save <a name="Save"></a>
# Create CSV versions in build/raw

# %%
sec_data.columns
# Out:
# Index(['adsh', 'tag', 'version', 'coreg', 'ddate', 'qtrs', 'uom', 'value',
#        'no_coreg', 'no_value', 'cik', 'company_name', 'sic', 'country',
#        'period', 'form', 'fye', 'accepted', 'instance', 'dyear', 'doc'],
#       dtype='object')

# %%
sec_data.to_csv(data_root+'02-build/clean/2019q3/sec_data_long.csv', index = False)
