# %% [markdown]
# # Program Header

# %%
import pandas as pd
import numpy as np
import os
import sys
nb_dir = os.path.split(os.getcwd())[0]
if nb_dir not in sys.path:
    sys.path.append(nb_dir)
from header import *
initialize_data_root("AY")
# Out:
# 'Initialized data root'

# %%
data_root
# Out:
# 'C:/Users/Andrew/1001-term-project/data/'

# %% [markdown]
# # Table of contents
# 1. [Import](#Import)
# 2. [Data Understanding](#DataUnderstanding)
# 2. [Clean](#Clean)
# 3. [Merge](#Merge)
# 4. [Create Features](#CreateFeatures)
# 5. [Save](#Save)

# %% [markdown]
# ## Import <a name="Import"></a>

# %%
data_root
# Out:
# 'C:/Users/Andrew/1001-term-project/data/'

# %%
raw_num_data = pd.read_csv(data_root+'02-build/raw/2019q3/num.csv')
raw_pre_data = pd.read_csv(data_root+'02-build/raw/2019q3/pre.csv')
raw_sub_data = pd.read_csv(data_root+'02-build/raw/2019q3/sub.csv')
raw_tag_data = pd.read_csv(data_root+'02-build/raw/2019q3/tag.csv')

# %% [markdown]
# ## Data Understanding <a name="DataUnderstanding"></a>

# %% [markdown]
# Useful columns based on reading the readme.txt:
# * **num**: Numeric data and actual values associated to `adsh-ddate-tag-etc`. All columns are relevant
# * **pre**: Location of tags and a preferred label (`plabel`). `plabel` (and joining columns) seems relevant
# * **sub**: Summary information about submission. Business-specific information including industry and company name are relevant
# * **tag**: Tag-level dataset. `doc` seems to be a more descriptive `plabel` from **pre** dataset

# %% [markdown]
# ## Clean <a name="Clean"></a>
# Clean the individual datasets to prepare for the merge:
# * Filter down to relevant columns
# *

# %%
raw_num_data.head()
# Out:
#                    adsh                                  tag      version  \
# 0  0001625376-19-000017                    EntityPublicFloat     dei/2014
# 1  0000034563-19-000064  DerivativeNonmonetaryNotionalAmount  invest/2013
# 2  0000034563-19-000064  DerivativeNonmonetaryNotionalAmount  invest/2013
# 3  0001370946-19-000033  DerivativeNonmonetaryNotionalAmount  invest/2013
# 4  0000225648-19-000108  DerivativeNonmonetaryNotionalAmount  invest/2013
#
#   coreg     ddate  qtrs    uom       value footnote
# 0   NaN  20180430     0    USD         0.0      NaN
# 1   NaN  20190630     0     lb  48183000.0      NaN
# 2   NaN  20180630     0     lb  43459000.0      NaN
# 3   NaN  20190630     0  MMBTU         2.0      NaN
# 4   NaN  20190630     0     MW   4300000.0      NaN

# %%
raw_pre_data.head()
# Out:
#                    adsh  report  line stmt  inpth rfile  \
# 0  0001625376-19-000017       1     9   CP      0     H
# 1  0001625376-19-000017       1    14   CP      0     H
# 2  0001625376-19-000019       1    11   CP      0     H
# 3  0001766016-19-000005       1    10   CP      0     H
# 4  0001047469-19-004442       1     6   CP      0     H
#
#                        tag   version                      plabel  negating
# 0        EntityPublicFloat  dei/2014         Entity Public Float         0
# 1  DocumentFiscalYearFocus  dei/2014  Document Fiscal Year Focus         0
# 2  DocumentFiscalYearFocus  dei/2014  Document Fiscal Year Focus         0
# 3  DocumentFiscalYearFocus  dei/2014  Document Fiscal Year Focus         0
# 4  DocumentFiscalYearFocus  dei/2014  Document Fiscal Year Focus         0

# %%
raw_sub_data.head()
# Out:
#                    adsh   cik                               name     sic  \
# 0  0000002178-19-000086  2178     ADAMS RESOURCES & ENERGY, INC.  5172.0
# 1  0000002488-19-000104  2488         ADVANCED MICRO DEVICES INC  3674.0
# 2  0000002488-19-000113  2488         ADVANCED MICRO DEVICES INC  3674.0
# 3  0000002488-19-000144  2488         ADVANCED MICRO DEVICES INC  3674.0
# 4  0000002969-19-000042  2969  AIR PRODUCTS & CHEMICALS INC /DE/  2810.0
#
#   countryba stprba       cityba       zipba                    bas1 bas2  ...  \
# 0        US     TX      HOUSTON       77027  17 S. BRIAR HOLLOW LN.  NaN  ...
# 1        US     CA  SANTA CLARA       95054    2485 AUGUSTINE DRIVE  NaN  ...
# 2        US     CA  SANTA CLARA       95054    2485 AUGUSTINE DRIVE  NaN  ...
# 3        US     CA  SANTA CLARA       95054    2485 AUGUSTINE DRIVE  NaN  ...
# 4        US     PA    ALLENTOWN  18195-1501      7201 HAMILTON BLVD  NaN  ...
#
#      period      fy  fp     filed               accepted prevrpt detail  \
# 0  20190630  2019.0  Q2  20190807  2019-08-07 17:21:00.0       0      1
# 1  20190630  2019.0  Q2  20190731  2019-07-31 16:27:00.0       0      1
# 2  20190731  2019.0  Q3  20190808  2019-08-08 16:10:00.0       0      0
# 3  20190831  2019.0  Q3  20190906  2019-09-06 16:11:00.0       0      0
# 4  20190630  2019.0  Q3  20190725  2019-07-25 13:02:00.0       0      1
#
#                          instance nciks  aciks
# 0             ae-20190630_htm.xml     1    NaN
# 1          amd0629201910q_htm.xml     1    NaN
# 2       amdform8k08082019_htm.xml     1    NaN
# 3  amdform8kequitysalesse_htm.xml     1    NaN
# 4       apd-10qx30jun2019_htm.xml     1    NaN
#
# [5 rows x 36 columns]

# %%
raw_tag_data.head()
# Out:
#                         tag      version  custom  abstract   datatype iord  \
# 0         EntityPublicFloat     dei/2014       0         0   monetary    I
# 1   DocumentFiscalYearFocus     dei/2014       0         0      gYear    D
# 2     DocumentPeriodEndDate     dei/2014       0         0       date    D
# 3  CurrentFiscalYearEndDate     dei/2014       0         0  gMonthDay    D
# 4            InvestmentAxis  invest/2013       0         1       axis  NaN
#
#   crdr                        tlabel  \
# 0    C           Entity Public Float
# 1  NaN    Document Fiscal Year Focus
# 2  NaN      Document Period End Date
# 3  NaN  Current Fiscal Year End Date
# 4  NaN             Investment [Axis]
#
#                                                  doc
# 0  State aggregate market value of voting and non...
# 1  This is focus fiscal year of the document repo...
# 2  The end date of the period reflected on the co...
# 3  End date of current fiscal year in the format ...
# 4  A categorization of investments (securities, d...

# %% [markdown]
# ## Clean <a name="Clean"></a>

# %%
pre_data = raw_num_data\
    .filter(['adsh', 'tag', 'version', 'plabel'], axis = 'columns')\
    .drop_duplicates()

# %%
sub_data = raw_sub_data\
    .filter(['adsh', 'cik', 'name', 'sic', 'countryba', 'period', 'form', 'fye', 'accepted', 'instance'], axis = 'columns')\
    .rename(mapper = {'name':'company_name', 'countryba':'country'}, axis = 'columns')\
    .query("form in ['10-Q', '10-K']") # Keep only the quarterly and annual filings

# %%
tag_data = raw_tag_data\
    .filter(['tag', 'version', 'doc'])\
    .drop_duplicates()

# %%
tag_data['doc'][0]
# Out:
# "State aggregate market value of voting and non-voting common equity held by non-affiliates computed by reference to price at which the common equity was last sold, or average bid and asked price of such common equity, as of the last business day of registrant's most recently completed second fiscal quarter. The public float should be reported on the cover page of the registrants form 10K."

# %%
# Get rid of coregister/parent company
# Keep only the balance sheet and single quarter flows

num_data = raw_num_data\
    .drop('footnote', axis = 'columns')\
    .assign(no_coreg = pd.isna(raw_num_data['coreg']))\
    .assign(no_value = pd.isna(raw_num_data['value']))\
    .assign(ddate = pd.to_datetime(raw_num_data['ddate'], format='%Y%m%d', errors = 'coerce'))\
    .query("(no_coreg == True) & (no_value == False) & (qtrs in (0,1)) & (uom in ['pur'])")

# %%
num_data.shape
# Out:
# (1349220, 10)

# %% [markdown]
# See if we have **num_data** observations at the `adsh, tag, ddate` level

# %%
multiple_matches = num_data.groupby(['adsh', 'tag', 'ddate'], as_index = False)\
    .count()\
    .sort_values('value', ascending = False)\
    .query("value > 1")
duplicate_causing_tags = multiple_matches.tag.unique()
duplicate_causing_tags
# Out:
# array(['DerivativeNotionalAmount', 'ClosingForeignExchangeRate',
#        'DerivativeNetCurrencyUnitsOutstanding',
#        'DerivativeNonmonetaryNotionalAmount', 'MonetaryAssets',
#        'VariableInterestEntityNumberOfFacilities',
#        'FinanceLeaseLiability', 'NumberOfNewbuildVessels',
#        'CashFDICInsuredAmount',
#        'FiniteLivedIntangibleAssetsAccumulatedAmortization',
#        'SeniorNotes1', 'DeferredTaxAssetsLiabilitiesNet',
#        'StatutoryDuesPayableCurrent',
#        'DebtorReorganizationItemsGainLossonFreshStartAdjustments',
#        'FiniteLivedIntangibleAssetsAmortizationExpenseYearFive',
#        'ShorttermDepositsNotClassifiedAsCashEquivalents',
#        'ShorttermBorrowings',
#        'FiniteLivedIntangibleAssetsAmortizationExpenseYearFour',
#        'DeferredTaxAssetsInventory',
#        'FiniteLivedIntangibleAssetsAmortizationExpenseYearThree',
#        'FiniteLivedIntangibleAssetsAmortizationExpenseYearTwo',
#        'DebtorReorganizationItemsWriteOffOfDeferredFinancingCosts',
#        'SegmentLiabilities', 'ProceedsFromIssuanceOrSaleOfEquity',
#        'DeferredTaxAssetsGrossNoncurrent', 'SegmentAssets',
#        'DeferredTaxAssetsGrossCurrent',
#        'RetentionMoneySecurityDepositsAndOthersNoncurrent',
#        'DebtorReorganizationItemsDebtorInPossessionFacilityFinancingCosts',
#        'DeferredIncomeTaxLiabilities', 'FiniteLivedIntangibleAssetsGross',
#        'FiniteLivedIntangibleAssetsNet',
#        'DebtorReorganizationItemsCashPaymentsNet',
#        'ReserveOfGainsAndLossesOnHedgingInstrumentsThatHedgeInvestmentsInEquityInstruments',
#        'DebtorReorganizationItemsWriteoffOfDebtDiscount',
#        'DebtorReorganizationItemsGainLossonLiabilitiesSubjectToCompromise',
#        'FiniteLivedIntangibleAssetsAmortizationExpenseNextTwelveMonths',
#        'EquitySecuritiesWithoutReadilyDeterminableFairValueAmount',
#        'TradeAndOtherCurrentPayablesToTradeSuppliers',
#        'EquitySecuritiesFvNiCost', 'ProfitLoss',
#        'DebtorReorganizationItemsProfessionalandOtherBankruptcyFees',
#        'EmployeeRelatedLiabilitiesCurrent', 'EarnestDepositForInvestment',
#        'DepositsAssetsNoncurrent',
#        'DepositOnAcquisitionOfPropertyPlantAndEquipmentNoncurrent',
#        'DeferredTaxLiabilityNotRecognizedAmountOfUnrecognizedDeferredTaxLiabilityUndistributedEarningsOfDomesticSubsidiaries',
#        'FiniteLivedIntangibleAssetsAmortizationExpenseAfterYearFive',
#        'DeferredTaxLiabilitiesTaxDeferredIncome',
#        'DebtorReorganizationItemsOtherItemsNet',
#        'DeferredTaxLiabilitiesPropertyPlantAndEquipment',
#        'WorkInProgress', 'DeferredTaxLiabilitiesNoncurrent',
#        'DeferredTaxLiabilitiesGoodwillAndIntangibleAssetsIntangibleAssets',
#        'UnclaimedMaturedFixedDepositsCurrent', 'LongTermDebt',
#        'TradeAndOtherReceivablesDueFromRelatedParties',
#        'ReserveOfGainsAndLossesFromInvestmentsInEquityInstruments',
#        'DebtorReorganizationItemsNet',
#        'TradeAndOtherPayablesUndiscountedCashFlows',
#        'DeferredTaxAssetsOther', 'TradeAndOtherPayablesToRelatedParties',
#        'DeferredTaxAssetsNet',
#        'DeferredTaxAssetsLiabilitiesNetNoncurrent',
#        'DeferredDiscountsFinanceChargesAndInterestIncludedInReceivables',
#        'BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedCurrentLiabilitiesAccountsPayable',
#        'ReserveOfExchangeDifferencesOnTranslation',
#        'OtherFinancialLiabilitiesUndiscountedCashFlows',
#        'CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalents',
#        'OtherCurrentNonfinancialLiabilities',
#        'StockIssuedDuringPeriodValueIssuedForServices',
#        'OtherCurrentNonfinancialAssets',
#        'OtherCurrentLiabilitiesClassifiedAsOther',
#        'ContractWithCustomerLiabilityAdditionsDuringPeriod',
#        'OtherCurrentFinancialLiabilitiesOther',
#        'CashAndCashEquivalentsAtCarryingValue',
#        'OtherCurrentFinancialLiabilities',
#        'OtherCurrentFinancialAssetsClassifiedAsOthers',
#        'OtherCurrentFinancialAssets', 'AssetsCurrent',
#        'OtherCurrentAssetsClassifiedAsOther',
#        'WeightedAverageNumberOfDilutedSharesOutstanding',
#        'OtherBorrowings', 'PaymentsOfStockIssuanceCosts',
#        'ComprehensiveIncomeNetOfTaxIncludingPortionAttributableToNoncontrollingInterest',
#        'NoncurrentTaxesRecoverableStatutoryDepositsAndDuesFromGovernment',
#        'Assets', 'NoncurrentRestrictedBankDeposits',
#        'WeightedAverageNumberOfSharesOutstandingBasic',
#        'NoncurrentRecognisedLiabilitiesDefinedBenefitPlan',
#        'ComprehensiveIncomeNetOfTaxAttributableToNoncontrollingInterest',
#        'AllowanceForDoubtfulAccountsReceivableNoncurrent',
#        'NoncurrentReceivables', 'NoncurrentProvisions',
#        'ComprehensiveIncomeNetOfTax', 'NoncurrentPrepayments',
#        'OtherEquityInterest', 'CommonStockParOrStatedValuePerShare',
#        'ReserveOfCashFlowHedges', 'OtherInvestmentsCurrent',
#        'DeferredIncomeTaxExpenseBenefit',
#        'ContractWithCustomerLiabilityNoncurrent',
#        'ProceedsFromLinesOfCredit',
#        'ContractWithCustomerLiabilityCurrent',
#        'RepaymentOfLoansPayableRelatedPartyTransactions',
#        'ShareBasedCompensationArrangementsByShareBasedPaymentAwardOptionsExercisesInPeriodWeightedAverageExercisePrice',
#        'ContractWithCustomerLiability', 'RecognisedFinanceLeaseAsAssets',
#        'ContractReceivableDueTwoToThreeYears',
#        'ContractReceivableDueThreeToFourYears',
#        'ContractReceivableDueOneToTwoYears', 'PropertyPlantAndEquipment',
#        'ContractReceivableDueFourToFiveYears',
#        'OtherUnallocatedFinancialLiabilities',
#        'ContractReceivableDueFiveYearsOrMore',
#        'OtherUnallocatedFinancialAssets', 'CommonStockValue',
#        'OtherTangibleOrIntangibleAssetsTransferred', 'OtherReserves',
#        'OtherNoncurrentNonfinancialLiabilities',
#        'OtherNoncurrentNonfinancialAssets',
#        'CurrentIncomeTaxExpenseBenefit',
#        'OtherNoncurrentLiabilitiesClassifiedAsOther',
#        'OtherNoncurrentFinancialLiabilities',
#        'OtherNoncurrentFinancialAssets',
#        'OtherNonCurrentFinancialAssetsClassifiedAsOthers',
#        'ContractWithCustomerLiabilityRevenueRecognized',
#        'OtherNonCurrentAssetsClassifiedAsOther',
#        'OtherInvestmentsNoncurrent',
#        'IntangibleAssetsNetExcludingGoodwill', 'Liabilities',
#        'InventoryCurrentAndNoncurrentNet', 'CreditSubstitutesPerforming',
#        'DeferredTaxAssetsDerivativeInstruments',
#        'DeferredFinanceCostsNet',
#        'DebtSecuritiesAvailableForSaleUnrealizedLossPositionAccumulatedLoss',
#        'BusinessAcquisitionCostOfAcquiredEntityWorkingCapitalAdjustment',
#        'DebtSecuritiesAvailableForSaleUnrealizedLossPosition',
#        'DebtSecuritiesAvailableForSaleContinuousUnrealizedLossPositionLessThan12MonthsAccumulatedLoss',
#        'DeferredTaxAssetsTaxDeferredExpenseReservesAndAccrualsReserves',
#        'DebtSecuritiesAvailableForSaleContinuousUnrealizedLossPositionLessThan12Months',
#        'CommonStockDividendsPerShareDeclared',
#        'DebtSecuritiesAvailableForSaleContinuousUnrealizedLossPosition12MonthsOrLongerAccumulatedLoss',
#        'DebtSecuritiesAvailableForSaleContinuousUnrealizedLossPosition12MonthsOrLonger',
#        'CommonStockValueOutstanding',
#        'AvailableForSaleDebtSecuritiesAccumulatedGrossUnrealizedGainBeforeTax',
#        'GuaranteedBenefitLiabilityNet',
#        'CashAndDueFromBanksAndRestrictedCashFairValueDisclosure',
#        'DebtConversionConvertedInstrumentAmount1',
#        'CashAndDueFromBanksAndRestrictedCash',
#        'CapitalizedComputerSoftwareGross', 'BillsPayable',
#        'AvailableforsaleCreditSubstituteSecurities',
#        'AvailableForSaleSecuritiesRestricted',
#        'AvailableForSaleSecuritiesDebtSecuritiesAtFairValue',
#        'AvailableForSaleSecuritiesDebtSecurities',
#        'AvailableForSaleDebtSecuritiesAmortizedCostBasis',
#        'DeferredTaxAssetsPropertyPlantAndEquipment',
#        'DeferredTaxAssetsTaxDeferredExpenseCompensationAndBenefits',
#        'DueFromRelatedParties', 'OperatingIncomeLoss',
#        'NonoperatingIncomeExpense', 'DerivativeFairValueOfDerivativeNet',
#        'NetIncomeLossFromContinuingOperationsAvailableToCommonShareholdersBasic',
#        'DerivativeFairValueOfDerivativeLiabilityAmountOffsetAgainstCollateral',
#        'DerivativeFairValueOfDerivativeLiability',
#        'DerivativeFairValueOfDerivativeAssetAmountOffsetAgainstCollateral',
#        'NetIncomeLossAvailableToCommonStockholdersBasic',
#        'DerivativeFairValueOfDerivativeAsset',
#        'NetIncomeLossAttributableToNoncontrollingInterest',
#        'NetIncomeLoss', 'PreferredStockRedemptionAmount1',
#        'DepositsWithClearingOrganizationsAndOthersSecurities',
#        'DepositsSavingsDeposits', 'Deposits',
#        'DeferredTaxLiabilitiesOtherComprehensiveIncome',
#        'DeferredTaxLiabilitiesInvestments',
#        'DeferredTaxAssetsUnrealizedLossesOnAvailableforSaleSecuritiesGross',
#        'DeferredTaxAssetsTaxDeferredExpenseReservesAndAccrualsProvisionForLoanLosses',
#        'DeferredTaxAssetsTaxDeferredExpenseLoanOriginationCost',
#        'NumberofPropertiesSoldPreviouslyIncludedInAssetSalesProgram',
#        'AvailableForSaleDebtSecuritiesAccumulatedGrossUnrealizedLossBeforeTax',
#        'ImmutepReceivedInCashPayment', 'InventoryNet',
#        'OperatingLeasesFutureMinimumPaymentsDueCurrent',
#        'PropertyPlantAndEquipmentNet', 'PropertyPlantAndEquipmentGross',
#        'PrepaidExpenseCurrent', 'StockIssuedDuringPeriodValueNewIssues',
#        'PrepaidExpenseAndOtherAssetsCurrent',
#        'PremiumsCollectedOnBehalfOfThirdParty',
#        'OtherReceivablesNetCurrent',
#        'TemporaryEquityAccretionToRedemptionValue', 'OtherPayables',
#        'OtherLiabilitiesNoncurrent',
#        'OperatingLeasesFutureMinimumPaymentsDueInTwoYears',
#        'OperatingLeasesFutureMinimumPaymentsDueInThreeYears',
#        'OperatingLeasesFutureMinimumPaymentsDueInFourYears',
#        'OperatingLeasesFutureMinimumPaymentsDue',
#        'EffectiveIncomeTaxRateContinuingOperations', 'MinorityInterest',
#        'EarningsPerShareDiluted', 'MarketableSecuritiesNoncurrent',
#        'EarningsPerShareBasic', 'LiabilitiesCurrent',
#        'LiabilitiesAndStockholdersEquity',
#        'DiscontinuedOperationIncomeLossFromDiscontinuedOperationNetOfTaxPerDilutedShare',
#        'NoncurrentMarginMoneyWithBanks',
#        'DiscontinuedOperationIncomeLossFromDiscontinuedOperationNetOfTaxPerBasicShare',
#        'DirectOperatingCosts', 'InventoryNoncurrent',
#        'DepreciationDepletionAndAmortization',
#        'RetainedEarningsAccumulatedDeficit', 'StatutoryReserve',
#        'TreasuryStockValueAcquiredCostMethod', 'StockholdersEquity',
#        'AdvanceTaxesNet', 'AdditionalPaidInCapitalCommonStock',
#        'AccumulatedOtherComprehensiveIncomeLossNetOfTax',
#        'AccumulatedDepreciationDepletionAndAmortizationPropertyPlantAndEquipment',
#        'AccruedLiabilitiesCurrentAndNoncurrent',
#        'AccruedLiabilitiesAndOtherLiabilities',
#        'AccountsReceivableRelatedParties',
#        'AccountsPayableCurrentAndNoncurrent',
#        'AccountsPayableAndOtherAccruedLiabilities',
#        'InterestIncomeExpenseNonoperatingNet',
#        'IncrementalCommonSharesAttributableToShareBasedPaymentArrangements',
#        'IncomeTaxExpenseBenefit', 'IncomeLossFromEquityMethodInvestments',
#        'IncomeLossFromDiscontinuedOperationsNetOfTaxAttributableToReportingEntity',
#        'IncomeLossFromDiscontinuedOperationsNetOfTaxAttributableToNoncontrollingInterest',
#        'IncomeLossFromDiscontinuedOperationsNetOfTax',
#        'IncomeLossFromContinuingOperationsPerDilutedShare',
#        'IncomeLossFromContinuingOperationsPerBasicShare',
#        'IncomeLossFromContinuingOperationsIncludingPortionAttributableToNoncontrollingInterest',
#        'IncomeLossFromContinuingOperationsBeforeIncomeTaxesExtraordinaryItemsNoncontrollingInterest',
#        'ProceedsFromIssuanceOfPrivatePlacement',
#        'NumberOfReportableSegments', 'GainLossOnInvestments',
#        'ValueAddedTaxReceivableCurrent',
#        'UndistributedEarningsOfDomesticSubsidiaries',
#        'TreasuryStockCommonValue',
#        'StockholdersEquityIncludingPortionAttributableToNoncontrollingInterest',
#        'AllowanceForDoubtfulAccountsReceivableCurrent',
#        'NoncurrentInvestmentsOtherThanInvestmentsAccountedForUsingEquityMethod',
#        'NoncurrentLiabilities',
#        'BondsDesignatedAsCashFlowHedgesAgainstForecastedRevenue',
#        'BankBorrowingsUndiscountedCashFlows',
#        'DebtInstrumentPeriodicPaymentTermsBalloonPaymentToBePaid',
#        'BalancesWithBanks', 'AmountsReceivableRelatedPartyTransactions',
#        'AmountsPayableRelatedPartyTransactions',
#        'AdditionalPaidinCapital', 'AcceptancesRelatedPartyTransactions',
#        'AcceptancesFromRelatedPartyTransactions',
#        'AdjustmentsToAdditionalPaidInCapitalWarrantIssued',
#        'AdjustmentsToAdditionalPaidInCapitalSharebasedCompensationRequisiteServicePeriodRecognitionValue',
#        'NumberOfRealEstateProperties', 'Borrowings',
#        'LeaseAndRentalExpense', 'NumberOfUniversityServicePartners',
#        'ShareBasedCompensationArrangementByShareBasedPaymentAwardPerShareWeightedAveragePriceOfSharesPurchased',
#        'SaleLeasebackTransactionAmountDueUnderFinancingArrangement',
#        'RepaymentsOfShortTermDebt',
#        'SaleOfStockConsiderationReceivedOnTransaction',
#        'ForeignExchangeCurrencyTranslationRate',
#        'TranslationAdjustmentFunctionalToReportingCurrencyNetOfTax',
#        'ProceedsFromSaleOfProductiveAssets', 'DividendsPreferredStock',
#        'GoodwillImpairmentLoss', 'NotionalAmount',
#        'BuyersCreditFromBanksAtFloatingInterestRate',
#        'ShareBasedGoodsAndNonemployeeServicesTransactionCapitalizedCost',
#        'CurrentAndNoncurrentPortionOfLongtermBorrowings',
#        'CurrentInvestments', 'CurrentInterestPayable',
#        'CurrentInterCorporateDepositsLiabilities',
#        'CurrentInterCorporateDeposits',
#        'CurrentGovernmentGrantReceivables',
#        'CurrentFinanceLeaseLiabilities',
#        'CurrentDerivativeFinancialLiabilities',
#        'CurrentDerivativeFinancialAssets', 'CurrentContractLiabilities',
#        'CurrentCommercialPapersIssuedAndCurrentPortionOfNoncurrentCommercialPapersIssued',
#        'CurrentBorrowingsAndCurrentPortionOfNoncurrentBorrowings',
#        'CurrentAssetsClassifiedAsHeldForSale', 'CurrentAssets',
#        'CurrentAdvancesToSuppliersAndContractors', 'Capital1',
#        'CurrentAdvancesAndOtherReceivablesRecoverableInCashIncludingSupplierRecoveries',
#        'CurrentAcceptances', 'CostOfHedgeReserveEquity',
#        'CostOfHedgeReserve', 'CommonStockDividendsPerShareCashPaid',
#        'CollateralizedDebtObligationsUndiscountedCashFlows',
#        'CollateralizedDebtObligations', 'CashOnHand',
#        'CashCollateralReceivedSubjectToEnforceableMasterNettingArrangementOrSimilarAgreementNotSetOffAgainstFinancialAssets',
#        'CashCollateralPledgedSubjectToEnforceableMasterNettingArrangementOrSimilarAgreementNotSetOffAgainstFinancialLiabilities',
#        'CashAndCashEquivalents',
#        'IncomeTaxExaminationAssessmentOutstanding',
#        'LossContingencyAmountOfFine', 'CurrentLoanToChannelPartner',
#        'ProceedsFromIssuanceOfCommonStock',
#        'ClassOfWarrantOrRightExercisePriceOfWarrantsOrRights1',
#        'TaxDisallowanceNotIncludingInterestAndPenalties',
#        'MonthlyRentPayment', 'Cash', 'DilutedEarningsLossPerShare',
#        'PaymentsToAcquireProductiveAssets',
#        'RecognisedFinanceLeaseAsLiabilities',
#        'TreasuryStockSharesAcquired', 'PromissoryNotePayable',
#        'LossContingencyAllegedTaxesOwedIncludingPenaltiesAndInterest',
#        'LossContingencyAllegedTaxesOwed', 'BasicEarningsLossPerShare',
#        'ProceedsFromSaleOfFinanceReceivables',
#        'ProceedsFromRepatriatedFunds',
#        'TreasuryStockAcquiredAverageCostPerShare',
#        'ShareBasedCompensationArrangementByShareBasedPaymentAwardActualForfeituresPercentage',
#        'StockIssuedDuringPeriodValuePrivatePlacements',
#        'PromissoryNotePayableToAlthea', 'InitialPublicOfferingAmount',
#        'AssetRetirementObligationsNoncurrent',
#        'WeightedAverageNumberOfShareOutstandingBasicAndDiluted',
#        'RevenueFromContractWithCustomerIncludingAssessedTax',
#        'ShareBasedCompensationArrangementByShareBasedPaymentAwardOptionsOutstandingIntrinsicValue',
#        'ShareBasedCompensationArrangementByShareBasedPaymentAwardOptionsOutstandingWeightedAverageExercisePrice',
#        'ConvertibleDebt', 'EarningsPerShareBasicAndDiluted',
#        'CurrentLiabilities',
#        'CurrentLoansReceivedAndCurrentPortionOfNoncurrentLoansReceived',
#        'AllowanceForDoubtfulAccountsReceivable', 'AccountsPayableCurrent',
#        'AccountsReceivableNetNoncurrent', 'AccountsReceivableNetCurrent',
#        'LongtermBorrowings', 'LongTermBorrowingsIncludingCurrentPortion',
#        'AccountsReceivableNet', 'LoansReceived',
#        'LoansReceivableRelatedPartyTransactions',
#        'AccountsReceivableGrossNoncurrent',
#        'LoansPayableRelatedPartyTransactions', 'AccountsReceivableGross',
#        'LiabilityTowardsVehiclesSoldUnderRepurchaseArrangementsCurrent',
#        'AccountsReceivableBilledForLongTermContractsOrPrograms',
#        'LiabilityTowardsEmployeeSeparationSchemeNoncurrent',
#        'MinimumFinanceLeasePaymentsPayableAtPresentValue',
#        'OtherComprehensiveIncomeLossForeignCurrencyTransactionAndTranslationAdjustmentNetOfTax',
#        'InvestmentsOtherThanInvestmentsAccountedForUsingEquityMethod',
#        'AntidilutiveSecuritiesExcludedFromComputationOfEarningsPerShareAmount',
#        'InvestmentAccountedForUsingEquityMethodCurrentAndNoncurrent',
#        'InvestmentAccountedForUsingEquityMethod', 'Inventories',
#        'AmortizationOfIntangibleAssets',
#        'IntangibleAssetsUnderDevelopmentEndingBalance',
#        'IntangibleAssetsUnderDevelopmentBeginningBalance',
#        'IntangibleAssetsOtherThanGoodwill',
#        'MinimumFinanceLeasePaymentsPayable',
#        'AccrualForTaxesOtherThanIncomeTaxesCurrent',
#        'AllocatedShareBasedCompensationExpense', 'NoncurrentAssets',
#        'NoncurrentLeasePrepayments', 'OperatingLeaseLeaseIncome',
#        'NoncurrentGovernmentGrantsReceivable',
#        'NoncurrentFinanceLeaseLiabilities',
#        'NoncurrentDerivativeFinancialLiabilities',
#        'NoncurrentDerivativeFinancialAssets',
#        'NoncurrentContractLiabilities',
#        'NoncurrentAssetsOtherThanFinancialInstrumentsDeferredTaxAssetsPostemploymentBenefitAssetsAndRightsArisingUnderInsuranceContracts',
#        'NoncontrollingInterests',
#        'MinimumLeasePaymentsPayableUnderNoncancellableOperatingLease',
#        'AccruedPropertyPlantEquipmentPayable',
#        'NonCurrentLoansToJointArrangements', 'NonCurrentLoansToEmployees',
#        'NonCurrentLoanToChannelPartner', 'AccruedProfessionalFeesCurrent',
#        'NonConvertibleDebentures',
#        'PreferredStockAccretionOfRedemptionDiscount',
#        'NetFinancialLiabilitiesSubjectToOffsettingEnforceableMasterNettingArrangementsOrSimilarAgreementsInStatementOfFinancialPosition',
#        'AccruedIncomeTaxesCurrent',
#        'NetFinancialLiabilitiesSubjectToOffsettingEnforceableMasterNettingArrangementsOrSimilarAgreements',
#        'NetFinancialAssetsSubjectToOffsettingEnforceableMasterNettingArrangementsOrSimilarAgreementsInStatementOfFinancialPosition',
#        'AccruedExpensesAndOtherCurrentLiabilities',
#        'NetFinancialAssetsSubjectToOffsettingEnforceableMasterNettingArrangementsOrSimilarAgreements',
#        'GrossFinancialLiabilitiesSubjectToOffsettingEnforceableMasterNettingArrangementsOrSimilarAgreements',
#        'GrossFinancialLiabilitiesSetOffAgainstFinancialAssetsSubjectToOffsettingEnforceableMasterNettingArrangementsOrSimilarAgreements',
#        'CurrentMarginMoneyWithBanks', 'GovernmentGrantsMaximumAmount',
#        'EquityAndLiabilities', 'Equity', 'PaymentsForRepurchaseOfEquity1',
#        'DeferredTaxLiabilityAsset',
#        'DefinedContributionPlanAssetsTransferredAsResultOfAcquisition',
#        'DeferredTaxLiabilities', 'DeferredTaxAssets',
#        'DeductibleTemporaryDifferencesForWhichNoDeferredTaxAssetIsRecognised',
#        'GrantsReceivable', 'EquityAttributableToOwnersOfParent',
#        'DebtInstrumentDenominatedInForeignCurrencyCarryingValue',
#        'CurrentTradeReceivables',
#        'CurrentTaxesRecoverableStatutoryDepositsAndDuesFromGovernment',
#        'CurrentTaxLiabilitiesCurrent', 'CurrentTaxAssetsNoncurrent',
#        'CurrentTaxAssetsCurrent', 'CurrentTaxAssets',
#        'CurrentRestrictedBankDeposits',
#        'CurrentRawMaterialsAndCurrentProductionSupplies',
#        'CurrentProvisions', 'CurrentPrepaidExpenses',
#        'MortgageLoansOnRealEstate', 'CurrentPortionOfLongtermBorrowings',
#        'NetIncomeLossIncludingPortionAttributableToNonredeemableNoncontrollingInterest',
#        'EquityForCapitalManagementPurposes',
#        'GrossFinancialAssetsSubjectToOffsettingEnforceableMasterNettingArrangementsOrSimilarAgreements',
#        'UnitsIssuedDuringPeriodValue',
#        'GrossFinancialAssetsSetOffAgainstFinancialLiabilitiesSubjectToOffsettingEnforceableMasterNettingArrangementsOrSimilarAgreements',
#        'Goodwill', 'ForeignCurrencyDerivativeInstrumentsCarryingValue',
#        'FinishedGoods', 'FinancialLiabilitiesUndiscountedCashFlows',
#        'FinancialLiabilitiesAtFairValue', 'FinancialLiabilities',
#        'TreasuryStockAcquiredAverageCostPerShare1',
#        'FinancingReceivableModificationsNumberOfContracts2',
#        'FinancialInstrumentsSubjectToEnforceableMasterNettingArrangementOrSimilarAgreementNotSetOffAgainstFinancialLiabilities',
#        'FinancialInstrumentsSubjectToEnforceableMasterNettingArrangementOrSimilarAgreementNotSetOffAgainstFinancialAssets',
#        'FairValueOfDerivativeFinancialAssetsAndLiabilitiesNet',
#        'FinancingReceivableModificationsSubsequentDefaultNumberOfContracts1',
#        'FinancialAssetsAtFairValue', 'FinancialAssets',
#        'FinanceReceivablesNoncurrent', 'FinanceReceivablesCurrent',
#        'FinanceReceivables', 'CommercialPapersAuthorized',
#        'FinanceLeaseLiabilities', 'OperatingLeaseCost',
#        'FinancingReceivableIndividuallyEvaluatedForImpairment',
#        'FederalFundsSoldAndSecuritiesBorrowedOrPurchasedUnderAgreementsToResellFairValueDisclosure',
#        'RepaymentsAdvancesUnderSyndicateCreditAgreement',
#        'RemainingEstimatedAmountOfContractExecutedOnCapital',
#        'FairMarketPricePerShare', 'NotesAndLoansReceivableNetNoncurrent',
#        'ReserveOfSharebasedPayments', 'NotesAndLoansReceivableNetCurrent',
#        'RestrictedDepositsCollateralPledgedAsSecurityForLiabilities',
#        'RetainedEarnings', 'LongTermInvestments', 'RetentionPayables',
#        'LiabilitiesNoncurrent', 'SecuredBankLoansReceived',
#        'IncomeTaxReconciliationTaxSettlementsDomestic',
#        'SecuredBorrowings', 'InterestReceivableCurrent',
#        'InterestPayableCurrent', 'SharePremium',
#        'ShortTermInvestmentAsSecurityBySubsidiaryToOverdraftFacility',
#        'GuaranteeObligationsCurrentCarryingValue',
#        'ShortTermInvestmentsInBondsOfRelatedParty',
#        'ShorttermBankDeposits', 'RedeemablePreferenceSharesValue',
#        'RedeemablePreferenceSharesRedeemedValue', 'RawMaterials',
#        'RestrictedCashAndCashEquivalentsAtCarryingValue',
#        'ShortTermBorrowings', 'OtherAssets', 'OtherFinancialLiabilities',
#        'OtherLiabilities', 'RestrictedCashOperatingFunds',
#        'OtherNoncurrentAssets', 'OtherNoncurrentLiabilities',
#        'PutOptionLiabilityWithNoncontrollingInterests',
#        'OtherShortTermInvestments1', 'ParValuePerShare',
#        'PayableUnderTradeFinancingArrangements',
#        'ProceedsFromRelatedPartyDebt',
#        'PropertyPlantAndEquipmentAndExplorationAndEvaluationAssets',
#        'PayablesRelatedToLongTermInvestments',
#        'OperatingLeaseRentExpensePerMonth',
#        'PropertyPlantAndEquipmentPledgedAsSecurity', 'Provisions',
#        'ShorttermDepositsClassifiedAsCashEquivalents',
#        'StockIssuedDuringPeriodSharesNewIssues',
#        'RegularDistributionsOnLongTermInvestmentPlan', 'AssetsNoncurrent',
#        'TaxCreditCarryforwardAmount', 'AdditionalPaidInCapital',
#        'Dividends', 'AccruedExpensesAndOtherLiabilitiesCurrent',
#        'TaxesPayableCurrent',
#        'StockIssuedDuringPeriodSharesIssuedForServices',
#        'StockholdersEquityNoteSubscriptionsReceivable',
#        'FinanceLeaseRightOfUseAssetAmortization',
#        'IssueOfConvertibleInstruments',
#        'DisposalGroupIncludingDiscontinuedOperationConsiderationTransferredReleasedFromEscrow',
#        'ShorttermProvisionForDecommissioningRestorationAndRehabilitationCosts',
#        'StatutoryLiabilities', 'StructuredInvestmentNetOfLiability',
#        'DueToRelatedPartiesCurrent', 'CashTransferred',
#        'TangibleExplorationAndEvaluationAssets',
#        'DueFromRelatedPartiesCurrent', 'TotalCapital',
#        'TradeAndOtherCurrentPayables', 'TradeAndOtherCurrentReceivables',
#        'TradeAndOtherCurrentReceivablesDueFromRelatedParties',
#        'TradeAndOtherPayables',
#        'TradeAndOtherReceivablesAndOtherNonCurrentAssets',
#        'TradePayablesToRelatedPartyTransactions',
#        'TradeReceivablesRelatedPartyTransactions', 'TreasuryShares',
#        'UnclaimedDividendsCurrent', 'UndrawnBorrowingFacilities',
#        'UndrawnFundBasedCommittedFacilities', 'NumberOfJointVentureSites',
#        'UnpaidDividend', 'UnpaidDividendIncludedInCashAndCashEquivalents',
#        'UnsecuredBankLoansReceived', 'DeferredIncomeTaxAssetsNet',
#        'UnusedMinimumAlternativeTaxCredit',
#        'UnusedTaxCreditsForWhichNoDeferredTaxAssetRecognised',
#        'TimeDeposits', 'SharesIssuedPricePerShare',
#        'ShortTermFundingDebts',
#        'CurrentRecognisedLiabilitiesDefinedBenefitPlan',
#        'CurrentAssetsLiabilities',
#        'ForeignCurrencyExchangeRateTranslation1',
#        'CurrentInventoriesHeldForSale', 'ContractAssetsOutstanding',
#        'CurrentRestrictedCashAndCashEquivalents',
#        'CurrentUnsecuredBankLoansReceivedAndCurrentPortionOfNoncurrentUnsecuredBankLoansReceived',
#        'DividendsCommonStock', 'DepositsHeldAsCollateral',
#        'DepositsHeldAsMarginMoney', 'CurrentAdvances',
#        'CommitmentAmountPayable', 'DerivativeFinancialLiabilities',
#        'CommercialPaper', 'CreditDerivativeNominalAmount',
#        'DebtInstrumentUnusedBorrowingCapacityAmount', 'AccountsPayable',
#        'StockIssuedDuringPeriodSharesStockWarrantsExercised',
#        'AdvancePetroleumProfit',
#        'AllowanceAccountForCreditLossesOfFinancialAssets',
#        'AmountPayableToOwnedPostEmploymentBenefitTrust',
#        'AmountsPayableRelatedPartyTransactionsCurrent',
#        'CommissionAndConsultancyFeesPayable', 'BankAcceptanceLiabilities',
#        'BankingLimitsAssignedForGroupCompanies', 'CapitalReserve',
#        'NumberOfNotes',
#        'CashAndCashEquivalentsIfDifferentFromStatementOfFinancialPosition',
#        'CashAndCashEquivalentsShortTermBankDepositAndCurrentRestrictedCash',
#        'CashBankAndCurrentInvestmentsIncludingShortTermDepositsWithEquity',
#        'DerivativeFinancialAssets',
#        'DiscountedTradeReceivablesOnRecourseBasis', 'StatutoryReserves',
#        'NoncurrentFinancialAssets',
#        'MaximumExposureToCreditRiskOfFinancialAssets',
#        'NetAssetsLiabilities', 'NetDebt', 'NonConvertibleBonds',
#        'NonFinancialLiabilities', 'CommonStockDividendRatePerShare',
#        'AssessableProfitLessThan255180',
#        'LongTermBorrowingIncludingCurrentPortion',
#        'LineOfCreditFacilityMaximumBorrowingCapacity',
#        'NoncurrentPortionOfNoncurrentUnsecuredBankLoansReceived',
#        'NonderivativeAndDerivativeFinancialLiabilitiesUndiscountedCashFlows',
#        'NotesAndDebenturesIssued', 'LineOfCreditFacilityAmount',
#        'DrawnBorrowingFacilities', 'ExportCommitments',
#        'RestrictedCashAndCashEquivalents', 'ExportObligationLiability',
#        'ForeignCurrencyExchangeTranslationRateBalanceSheetItems',
#        'IncomeTaxExaminationPreliminaryTaxAssessmentAmount',
#        'TreasuryStockRetiredCostMethodAmount',
#        'ExposureToCreditRiskOnLoanCommitmentsAndFinancialGuaranteeContracts',
#        'FinancialAssetLiabilitiesNet',
#        'FinancialInstrumentsCarryingValue', 'FixedBankDeposits',
#        'LiabilityForStructuredInvestments', 'NotesPayable',
#        'GuaranteesOutstandingGivenTaken', 'InterestReserveOnLoansPayable',
#        'InventoriesTotal', 'DebtToAffiliatedPartyForCapitalization',
#        'Investment', 'InvestmentInRehabilitionTrust', 'IssuedCapital',
#        'LiabilitiesCapitalExpenditure',
#        'LiabilitiesFromSharebasedPaymentTransactions2011',
#        'CashCashEquivalentsAndShortTermInvestments',
#        'FinancingReceivableAllowanceForCreditLossesCollectivelyEvaluatedForImpairment',
#        'PaymentsToAcquireEquityMethodInvestments',
#        'SensitivityAnalysisOfFairValueOfInterestsContinuedToBeHeldByTransferorServicingAssetsOrLiabilitiesImpactOf20PercentAdverseChangeInPrepaymentSpeed',
#        'InterestAndDebtExpense',
#        'SensitivityAnalysisOfFairValueOfInterestsContinuedToBeHeldByTransferorServicingAssetsOrLiabilitiesImpactOf20PercentAdverseChangeInExpectedCreditLosses',
#        'SensitivityAnalysisOfFairValueOfInterestsContinuedToBeHeldByTransferorServicingAssetsOrLiabilitiesImpactOf10PercentAdverseChangeInPrepaymentSpeed',
#        'SensitivityAnalysisOfFairValueOfInterestsContinuedToBeHeldByTransferorServicingAssetsOrLiabilitiesImpactOf10PercentAdverseChangeInExpectedCreditLosses',
#        'SecurityDeposit',
#        'SecuritiesSoldUnderAgreementsToRepurchaseGross',
#        'SecuritiesSoldUnderAgreementsToRepurchaseAmountOffsetAgainstCollateral',
#        'SecuritiesPurchasedUnderAgreementsToResellGross',
#        'SecuritiesLoanedOrSoldUnderAgreementsToRepurchaseFairValueDisclosure',
#        'RetainedEarningsAppropriated', 'RetainageDeposit',
#        'RestrictedCash', 'RemittancesInTransit',
#        'PrepaidExpenseCurrentAndNoncurrent', 'OtherReceivables',
#        'AcceleratedShareRepurchasesSharesRepurchased',
#        'OtherLongTermDebt', 'OtherLiabilitiesFairValueDisclosure',
#        'OtherAssetsMiscellaneous', 'OtherAssetsFairValueDisclosure',
#        'OtherAssetsExcludingNonFinancialInstruments',
#        'TimeDepositMaturitiesYearThree', 'UnrecognizedTaxBenefits',
#        'UnconditionalCancellableCommitments',
#        'WeightedAverageFairValueAtMeasurementDateOtherEquityInstrumentsGranted',
#        'TradingSecuritiesGrossUnrealizedLosses',
#        'TradingSecuritiesGrossUnrealizedGains', 'TradingSecuritiesCost',
#        'TradingSecuritiesAtFairValue', 'TradingSecurities',
#        'TimeDepositMaturitiesYearTwo', 'TimeDepositMaturitiesYearOne',
#        'ReorganizationItems', 'TimeDepositMaturitiesYearFour',
#        'TimeDepositMaturitiesYearFive',
#        'TimeDepositMaturitiesAfterYearFive', 'TermPlacements',
#        'UnderwritersCommissionExpense', 'SubordinatedDebt',
#        'AccruedLicenseFeesCurrent', 'ShorttermDebtFairValue',
#        'OperatingLeasesFutureMinimumPaymentsDueThereafter',
#        'FurnitureAndFixturesGross', 'InterestPayableCurrentAndNoncurrent',
#        'InterestBearingDepositLiabilities',
#        'ImpairedFinancingReceivableUnpaidPrincipalBalance',
#        'ImpairedFinancingReceivableRelatedAllowance',
#        'ImpairedFinancingReceivableRecordedInvestment',
#        'ImpairedCreditSubstitutesNet', 'ImpairedCreditSubstitutes',
#        'OtherGeneralAndAdministrativeExpense',
#        'GuaranteesFairValueDisclosure', 'OtherComprehensiveIncomeLossTax',
#        'GoodwillGross', 'OtherComprehensiveIncomeLossNetOfTax',
#        'InterestPayableFairValueDisclosure',
#        'OtherComprehensiveIncomeForeignCurrencyTransactionAndTranslationGainLossArisingDuringPeriodNetOfTax',
#        'FinancingReceivableRecordedInvestmentNonaccrualStatus',
#        'FinancingReceivableModificationsRecordedInvestment',
#        'FinancingReceivableCollectivelyEvaluatedForImpairment',
#        'FinancingReceivableAllowanceForCreditLossesIndividuallyEvaluatedForImpairment1',
#        'OtherOperatingIncomeExpenseNet', 'InterestReceivable',
#        'LongTermDebtExceptPerpetualBonds',
#        'OperatingLeasesFutureMinimumPaymentsDueInFiveYears',
#        'NoninterestBearingDepositLiabilities',
#        'LongTermDebtMaturitiesRepaymentsOfPrincipalInYearTwo',
#        'LongTermDebtMaturitiesRepaymentsOfPrincipalInYearThree',
#        'LongTermDebtMaturitiesRepaymentsOfPrincipalInYearFour',
#        'LongTermDebtMaturitiesRepaymentsOfPrincipalInYearFive',
#        'LongTermDebtMaturitiesRepaymentsOfPrincipalInNextTwelveMonths',
#        'LongTermDebtMaturitiesRepaymentsOfPrincipalAfterYearFive',
#        'LongTermDebtFairValue', 'InterestReceivableFairValueDisclosure',
#        'LoansReceivableFairValueDisclosure', 'LoansPledgedAsCollateral',
#        'LoansAndLeasesReceivableRelatedParties',
#        'LoansAndLeasesReceivableNetReportedAmount',
#        'LoansAndLeasesReceivableNetOfDeferredIncome',
#        'LoansAndLeasesReceivableAllowance',
#        'PaymentsToAcquirePropertyPlantAndEquipment',
#        'LitigationSettlementAmountAwardedToOtherParty',
#        'LandAndPremisesGross', 'UnusedCommitmentsToExtendCredit',
#        'CurrentProvisionsForEmployeeBenefits',
#        'CreditCardCollectionInHand', 'AssetImpairmentCharges',
#        'AdvancesOnInventoryPurchases', 'AccruedEmployeeBenefitsCurrent',
#        'DeferredIncomeClassifiedAsCurrent',
#        'ProceedsFromIssueOfSubordinatedLiabilities',
#        'DeferredIncomeClassifiedAsNoncurrent', 'Penaltiesperday',
#        'AggregatePriceOfOfferingAmount', 'OtherAssetsNoncurrent',
#        'GainLossOnSaleOfPropertyPlantEquipment', 'NotesPayableCurrent',
#        'LongTermDeposits', 'BalancesWithBanksOnCurrentAccount',
#        'BankOverdraftsClassifiedAsCashEquivalents',
#        'FinanceLeaseLiabilityNoncurrent',
#        'UtilizationOfAccountsReceivableFactoringFacilityUnderArrangement',
#        'CashAndCashEquivalentsBeforeBankOverdrafts',
#        'DividendsPayableCurrent', 'NumberOfOperatingSegments',
#        'ShareIssueRelatedCost', 'EntityNumberOfEmployees',
#        'StockOptionPlanExpense', 'VariableLeaseCost',
#        'ProceedsFromIssuingShares',
#        'TemporaryEquityEliminationAsPartofReorganization',
#        'StockIssuedDuringPeriodValueAcquisitions',
#        'StockIssuedDuringPeriodValueSharebasedCompensationDiscontinuedOperationsNetofForfeitures',
#        'StockIssuedDuringPeriodValueShareBasedCompensation',
#        'StockIssuedDuringPeriodValueRestrictedStockAwardNetOfForfeitures',
#        'StockIssuedDuringPeriodValueReorganizationItems',
#        'StockIssuedDuringPeriodValueReorganization',
#        'StockIssuedDuringPeriodValueOther',
#        'SellingGeneralAndAdministrativeExpense', 'Revenues',
#        'Debtinstrumentcovenantcompliancecashrequiredtobemaintainedpercentage',
#        'IfrsPrepaidExpenseAndOtherAssetsCurrent',
#        'IfrsPrepaidExpenseAndOtherAssetsNoncurrent',
#        'EffectiveIncomeTaxRateReconciliationAtFederalStatutoryIncomeTaxRate',
#        'NetProceedsFromSaleOfPayrollTaxCredits',
#        'IntangibleAssetsAndGoodwill', 'Secondpartofloan',
#        'ItemsInCourseOfCollectionFromOtherBanks', 'LongtermDeposits',
#        'RedeemableNoncontrollingInterestEquityOtherRedemptionValue',
#        'NoncurrentPayables', 'NoncurrentProvisionsForEmployeeBenefits',
#        'GainLossOnDispositionOfAssets',
#        'MaximumLimitForSaleOfEligibleTradeReceivables',
#        'DerivativeFinancialLiabilitiesUndiscountedCashFlows',
#        'UndistributedEarningsOfForeignSubsidiaries',
#        'NumberOfVesselsInOperation',
#        'DistributionMadeToLimitedPartnerCashDistributionsDeclared',
#        'InterestPayableRelatedParties', 'InterestExpenseRelatedParty',
#        'ShareBasedCompensationArrangementByShareBasedPaymentAwardPaymentUponTerminationOfIncentivePlan',
#        'OperatingLeasesRentExpenseNet', 'UnsecuredDebt',
#        'TreasuryStockAvailableForRepurchase',
#        'GainsLossesOnExtinguishmentOfDebt',
#        'TreasuryStockSharesAcquiredAsPartOfPubliclyAnnouncedPlansOrPrograms',
#        'DueToOfficersOrStockholdersCurrentAndNoncurrent',
#        'DividendsCommonStockCash', 'CommonStockSharesSubscriptions',
#        'LesseeOperatingLeaseLeaseNotYetCommencedPaymentsDue',
#        'GainLossOnDispositionOfAssets1',
#        'NumberOfSharesIssuedToManagerForBaseManagementPerformanceFees',
#        'DueToOtherRelatedPartiesCurrentAndNoncurrent',
#        'StockRepurchasedDuringPeriodValue',
#        'ExercisePriceOfOutstandingShareOptionsExercisable',
#        'GainLossOnSaleOfGroundLeasesAndLeaseIntangibleAssetsAndBelowMarketLeaseLiabilities',
#        'DebtInstrumentUnamortizedDiscountPremiumNet',
#        'DeferredRevenueRevenueRecognized1',
#        'AccumulatedOtherComprehensiveIncome',
#        'PartnersCapitalAccountUnitBasedCompensation',
#        'PaymentOfCashDividendsOnSeniorPreferredStockToTreasury',
#        'DebtInstrumentConvertibleConversionPrice1',
#        'ImprovementsPaidByTheLandLord',
#        'PartnersCapitalAccountContributions', 'DebtInstrumentFaceAmount',
#        'OtherComprehensiveIncomeLossPensionAndOtherPostretirementBenefitPlansAdjustmentNetOfTax',
#        'DebtInstrumentCollateralAmount', 'DebtInstrumentRepurchaseAmount',
#        'RestructuringCharges',
#        'ProceedsFromDivestitureOfInterestInSubsidiariesAndAffiliates',
#        'RepaymentsOfNotesPayable', 'MonetaryLiabilities',
#        'LoansPayableNonCurrent', 'NumberOfMajorProductCategories',
#        'CollaborativeArrangementPaymentforResearchandDevelopmentAgreement',
#        'IntercompanyForeignCurrencyBalanceAmount',
#        'NoncurrentLeaseLiabilities',
#        'DefinedBenefitPlanAccumulatedBenefitObligationIncreaseDecreaseForPlanAmendment',
#        'ClassOfWarrantOrRightExercisesInPeriodExercisePrice',
#        'AverageForeignCurrencyExchangeRateTranslation', 'GroundLeasesNet',
#        'NonCurrentPortionOfBankLoansAndNotesPayable',
#        'CashFlowsBetweenTransfereeAndTransferorProceedsFromCollectionsReinvestedInRevolvingPeriodTransfers',
#        'RightofuseAssets', 'CurrentPortionOfBankLoansAndNotesPayable',
#        'PaymentsToAcquireBusinessesNetOfCashAcquired',
#        'PaymentsToAcquireBusinessesGross',
#        'CashFlowsBetweenTransfereeAndTransferorProceedsFromNewTransfers',
#        'LossContingencyAccrualAtCarryingValue',
#        'LesseeOperatingLeaseMonthlyRentalPayments',
#        'OperatingLeaseRightOfUseAsset',
#        'StockToBeIssuedDuringPeriodSharesIssuedForServicesAndEmployees',
#        'ProceedsFromDebtNetOfIssuanceCosts', 'CurrentLeaseLiabilities',
#        'NumberOfUnitsInRealEstateProperty',
#        'OutstandingBefiexTaxAssessment', 'PaymentsToMinorityShareholders',
#        'GoodwillAcquiredDuringPeriod',
#        'ResearchAndDevelopmentExpensesReduction',
#        'MinimumBlockOfSharesIssuedRedeemedAgainstBullion',
#        'EquityMethodInvestmentSoldCarryingAmount',
#        'MinorityInterestDecreaseFromRedemptions',
#        'LongTermDebtMaturitiesRepaymentsOfPrincipalInRollingYearThree',
#        'CurrentDividendPayables',
#        'StockIssuedDuringPeriodSharesStockOptionsExercised',
#        'StockIssuedDuringPeriodValuePrivatePlacementOfCommonStock',
#        'BusinessCombinationRecognizedIdentifiableAssetsAcquiredGoodwillAndLiabilitiesAssumedLessNoncontrollingInterest',
#        'AmortizationOfDeferredRent',
#        'LineOfCreditFacilityCollateralAmount', 'LineOfCredit',
#        'BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedCustomerList',
#        'RepaymentsOfLongTermDebt',
#        'BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedEnvironmentalComplianceApproval',
#        'ProceedsFromConvertibleDebtAmountPerInstrument',
#        'ProceedsFromConvertibleDebt',
#        'BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedEquipment',
#        'Commercialpapereurodenominated', 'ValueAddedTaxPotentialPayment',
#        'LossContingencyDamagesAwardedValue',
#        'BusinessAcquisitionCostOfAcquiredEntityTransactionCosts',
#        'ProceedsFromAccountsReceivableSecuritization',
#        'NetIncomeLossAttributableToAcquirerPriorToBusinessCombination',
#        'BusinessCombinationAcquisitionRelatedCosts',
#        'BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedCurrentAssetsReceivables',
#        'BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedLand',
#        'AccountsPayableRelatedPartiesCurrentAndNoncurrent',
#        'OperatingLeaseExpense', 'NumberOfStores', 'PaymentsOfDividends',
#        'CommercialPaperAtCarryingValue', 'OffBalanceSheetReserves',
#        'ValueOfInstrumentsGrantedInSharebasedPaymentArrangement',
#        'CashUninsuredAmount',
#        'NetIncomeLossAttributabletoNoncontrollingInterestSubsequentToReorganization',
#        'SecuredDebt'], dtype=object)

# %%
print("%.2f%% tags create duplicates"% round(len(duplicate_causing_tags)/len(num_data.tag.unique())*100,2))
# Out:
# 1.08% tags create duplicates

# %% [markdown]
# Since only a small percent of tags are trouble, we'll just remove them for now.

# %%
num_data = num_data.query("tag not in @duplicate_causing_tags")

# %% [markdown]
# Note for checking: These tags may just be variations of other important tags. Investigate if we're dropping anything important. Needs further investigation during checking process.

# %% [markdown]
# Now, we have unique rows for each `adsh, tag, ddate`.

# %%
multiple_matches = num_data.groupby(['adsh', 'tag', 'ddate'], as_index = False)\
    .count()\
    .sort_values('value', ascending = False)\
    .query("value > 1")
multiple_matches
# Out:
# Empty DataFrame
# Columns: [adsh, tag, ddate, version, coreg, qtrs, uom, value, no_coreg, no_value]
# Index: []

# %% [markdown]
# ## Merge <a name="Merge"></a>

# %%
num_data.columns
# Out:
# Index(['adsh', 'tag', 'version', 'coreg', 'ddate', 'qtrs', 'uom', 'value',
#        'no_coreg', 'no_value'],
#       dtype='object')

# %%
sec_data = num_data.merge(pre_data, on = ['adsh', 'tag', 'version'])\
    .merge(sub_data, on = ['adsh'])\
    .merge(tag_data, on = ['tag', 'version'])

# %% [markdown]
# ## Create Features <a name="CreateFeatures"></a>
# Create `ticker` and `clean_tag` based on financial statement line items.

# %%
sec_data[['cik','company_name','instance']].drop_duplicates().shape
# Out:
# (5776, 3)

# %%
pd.DataFrame(sec_data.tag.unique()).to_csv(data_root+"tags.csv")

# %%
test = sec_data.copy().sample(1000)
test.iloc[0:1,]
# Out:
#                    adsh                                 tag   version coreg  \
# 0  0001766016-19-000005  EntityCommonStockSharesOutstanding  dei/2014   NaN
#
#       ddate  qtrs     uom      value  no_coreg  no_value      cik  \
# 0  20190630     0  shares  2071002.0      True     False  1766016
#
#                  company_name     sic country    period  form     fye  \
# 0  CRUCIAL INNOVATIONS, CORP.  8200.0      CN  20190630  10-Q  1231.0
#
#                 accepted           instance  \
# 0  2019-07-19 18:35:00.0  none-20190630.xml
#
#                                                  doc
# 0  Indicate number of shares or other units outst...

# %%
test = sec_data.copy()
test['clean_tag'] = np.where((test['tag'].str.match('revenue', case = False))&
                             (test['qtrs'] == 1)&
                             (test['uom'] == 'USD'), 
                             'Revenue', test['tag'])

# %%
test

# %%
def check_for_problems(tag):
    problems = test.query('clean_tag == @tag')\
        .groupby(['adsh', 'ddate'], as_index = False)\
        .size()
    
    problems = problems[problems != 1].reset_index(name = 'count')
    
    return(problems)

tag_tracker = check_for_problems("Revenue")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-327-6809fe79f4f1> in <module>
#       8     return(problems)
#       9
# ---> 10 tag_tracker = check_for_problems("Revenue")
#
# <ipython-input-327-6809fe79f4f1> in check_for_problems(tag)
#       1 def check_for_problems(tag):
# ----> 2     problems = test.query('clean_tag == @tag')\
#       3         .groupby(['adsh', 'ddate'], as_index = False)\
#       4         .size()
#       5
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     531             return self[attr]
#     532         if hasattr(self.obj, attr):
# --> 533             return self._make_wrapper(attr)
#     534
#     535         raise AttributeError("%r object has no attribute %r" %
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _make_wrapper(self, name)
#     568                    "using the 'apply' method".format(kind, name,
#     569                                                      type(self).__name__))
# --> 570             raise AttributeError(msg)
#     571
#     572         self._set_group_selection()
#
# AttributeError: Cannot access callable attribute 'query' of 'DataFrameGroupBy' objects, try using the 'apply' method

# %%
tag_tracker['count'].value_counts()
# Out:
# 2    232
# 3     19
# 4      2
# Name: count, dtype: int64

# %%
issue = 1
test.query('(clean_tag == @tag)&(adsh == @tag_tracker.adsh[@issue])&(ddate == @tag_tracker.ddate[@issue])')
# Out:
#                         adsh  \
# 333091  0000004962-19-000051
# 338462  0000004962-19-000051
#
#                                                       tag       version coreg  \
# 333091                       RevenuesNetOfInterestExpense  us-gaap/2019   NaN
# 338462  RevenueFromContractWithCustomerExcludingAssess...  us-gaap/2019   NaN
#
#            ddate  qtrs  uom         value  no_coreg  no_value  ...  \
# 333091  20190630     1  USD  1.083800e+10      True     False  ...
# 338462  20190630     1  USD  7.080000e+09      True     False  ...
#
#                company_name     sic  country    period  form     fye  \
# 333091  AMERICAN EXPRESS CO  6199.0       US  20190630  10-Q  1231.0
# 338462  AMERICAN EXPRESS CO  6199.0       US  20190630  10-Q  1231.0
#
#                      accepted            instance  \
# 333091  2019-07-23 15:55:00.0  axpq21910q_htm.xml
# 338462  2019-07-23 15:55:00.0  axpq21910q_htm.xml
#
#                                                       doc clean_tag
# 333091  Amount of revenue recognized from goods sold, ...   Revenue
# 338462  Amount, excluding tax collected from customer,...   Revenue
#
# [2 rows x 21 columns]

# %%
test.query('(clean_tag == @tag)&(adsh in @tag_tracker.adsh)&(ddate in @tag_tracker.ddate)').uom.unique()
# Out:
# array(['USD', 'CAD', 'pure'], dtype=object)

# %%
tag_tracker.index[0][0]
# Out:
# '0000002488-19-000104'

# %%
tag = 'Revenue'
problems = test.query('clean_tag == @tag')\
        .groupby(['adsh', 'ddate'])\
        .size()\
        .value_counts()

# %%
# Out:
# 1    4637
# 2     423
# 3      25
# 4       3
# dtype: int64

# %%
test_series = pd.Series(['revenue', 'rev', 'rev12', '4324324', 'reven'])

test_series.str.match('revenue', case = False)
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %% [markdown]
# ## Reshape <a name="Reshape"></a>

# %% [markdown]
# Check again that we're unique on the `adsh-ddate-tag` level

# %%
sec_data.groupby(['adsh', 'tag', 'ddate'], as_index = False)\
    .count()\
    .sort_values('value', ascending = False)\
    .query("value > 1")
# Out:
# Empty DataFrame
# Columns: [adsh, tag, ddate, version, coreg, qtrs, uom, value, no_coreg, no_value, cik, company_name, sic, country, period, form, fye, accepted, instance, doc]
# Index: []

# %%
sec_data_wide = sec_data.pivot_table(values = 'value',
                                     index = ['adsh', 'company_name', 'ddate', 'qtrs', 
                                                        'uom', 'cik', 'sic', 'country', 'period'],
                                    columns = 'tag')

# %%
sec_data_wide.reset_index()

# %%
sec_data_wide.head()
# Out:
# tag                                                                                                    ACAIndustryFeeExpense  \
# adsh                 company_name                   ddate    qtrs uom    cik  sic    country period
# 0000002178-19-000086 ADAMS RESOURCES & ENERGY, INC. 20180630 1    USD    2178 5172.0 US      20190630                    NaN
#                                                     20181231 0    USD    2178 5172.0 US      20190630                    NaN
#                                                                   shares 2178 5172.0 US      20190630                    NaN
#                                                     20190331 0    shares 2178 5172.0 US      20190630                    NaN
#                                                              1    USD    2178 5172.0 US      20190630                    NaN
#
# tag                                                                                                    AMPSImpactonStockholdersEquity  \
# adsh                 company_name                   ddate    qtrs uom    cik  sic    country period
# 0000002178-19-000086 ADAMS RESOURCES & ENERGY, INC. 20180630 1    USD    2178 5172.0 US      20190630                             NaN
#                                                     20181231 0    USD    2178 5172.0 US      20190630                             NaN
#                                                                   shares 2178 5172.0 US      20190630                             NaN
#                                                     20190331 0    shares 2178 5172.0 US      20190630                             NaN
#                                                              1    USD    2178 5172.0 US      20190630                             NaN
#
# tag                                                                                                    AOCIImpactofNEPDeconsolidation  \
# adsh                 company_name                   ddate    qtrs uom    cik  sic    country period
# 0000002178-19-000086 ADAMS RESOURCES & ENERGY, INC. 20180630 1    USD    2178 5172.0 US      20190630                             NaN
#                                                     20181231 0    USD    2178 5172.0 US      20190630                             NaN
#                                                                   shares 2178 5172.0 US      20190630                             NaN
#                                                     20190331 0    shares 2178 5172.0 US      20190630                             NaN
#                                                              1    USD    2178 5172.0 US      20190630                             NaN
#
# tag                                                                                                    AOCIreclassedtoRetainedEarningsincometax  \
# adsh                 company_name                   ddate    qtrs uom    cik  sic    country period
# 0000002178-19-000086 ADAMS RESOURCES & ENERGY, INC. 20180630 1    USD    2178 5172.0 US      20190630                                       NaN
#                                                     20181231 0    USD    2178 5172.0 US      20190630                                       NaN
#                                                                   shares 2178 5172.0 US      20190630                                       NaN
#                                                     20190331 0    shares 2178 5172.0 US      20190630                                       NaN
#                                                              1    USD    2178 5172.0 US      20190630                                       NaN
#
# tag                                                                                                    APICEquityBasedPaymentArrangementIncreaseForCostRecognition  \
# adsh                 company_name                   ddate    qtrs uom    cik  sic    country period
# 0000002178-19-000086 ADAMS RESOURCES & ENERGY, INC. 20180630 1    USD    2178 5172.0 US      20190630                                                NaN
#                                                     20181231 0    USD    2178 5172.0 US      20190630                                                NaN
#                                                                   shares 2178 5172.0 US      20190630                                                NaN
#                                                     20190331 0    shares 2178 5172.0 US      20190630                                                NaN
#                                                              1    USD    2178 5172.0 US      20190630                                                NaN
#
# tag                                                                                                    APICSharebasedPaymentArrangementESOPIncreaseforCostRecognition  \
# adsh                 company_name                   ddate    qtrs uom    cik  sic    country period
# 0000002178-19-000086 ADAMS RESOURCES & ENERGY, INC. 20180630 1    USD    2178 5172.0 US      20190630                                                NaN
#                                                     20181231 0    USD    2178 5172.0 US      20190630                                                NaN
#                                                                   shares 2178 5172.0 US      20190630                                                NaN
#                                                     20190331 0    shares 2178 5172.0 US      20190630                                                NaN
#                                                              1    USD    2178 5172.0 US      20190630                                                NaN
#
# tag                                                                                                    APICSharebasedPaymentArrangementIncreaseforCostRecognitionServicesRendered  \
# adsh                 company_name                   ddate    qtrs uom    cik  sic    country period
# 0000002178-19-000086 ADAMS RESOURCES & ENERGY, INC. 20180630 1    USD    2178 5172.0 US      20190630                                                NaN
#                                                     20181231 0    USD    2178 5172.0 US      20190630                                                NaN
#                                                                   shares 2178 5172.0 US      20190630                                                NaN
#                                                     20190331 0    shares 2178 5172.0 US      20190630                                                NaN
#                                                              1    USD    2178 5172.0 US      20190630                                                NaN
#
# tag                                                                                                    APICSharebasedPaymentArrangementReclassificationfromLiabilitytoEquity  \
# adsh                 company_name                   ddate    qtrs uom    cik  sic    country period
# 0000002178-19-000086 ADAMS RESOURCES & ENERGY, INC. 20180630 1    USD    2178 5172.0 US      20190630                                                NaN
#                                                     20181231 0    USD    2178 5172.0 US      20190630                                                NaN
#                                                                   shares 2178 5172.0 US      20190630                                                NaN
#                                                     20190331 0    shares 2178 5172.0 US      20190630                                                NaN
#                                                              1    USD    2178 5172.0 US      20190630                                                NaN
#
# tag                                                                                                    APICSharebasedPaymentArrangementReversalOfCostRecognition  \
# adsh                 company_name                   ddate    qtrs uom    cik  sic    country period
# 0000002178-19-000086 ADAMS RESOURCES & ENERGY, INC. 20180630 1    USD    2178 5172.0 US      20190630                                                NaN
#                                                     20181231 0    USD    2178 5172.0 US      20190630                                                NaN
#                                                                   shares 2178 5172.0 US      20190630                                                NaN
#                                                     20190331 0    shares 2178 5172.0 US      20190630                                                NaN
#                                                              1    USD    2178 5172.0 US      20190630                                                NaN
#
# tag                                                                                                    ATMAndCheckCardExpense  \
# adsh                 company_name                   ddate    qtrs uom    cik  sic    country period
# 0000002178-19-000086 ADAMS RESOURCES & ENERGY, INC. 20180630 1    USD    2178 5172.0 US      20190630                     NaN
#                                                     20181231 0    USD    2178 5172.0 US      20190630                     NaN
#                                                                   shares 2178 5172.0 US      20190630                     NaN
#                                                     20190331 0    shares 2178 5172.0 US      20190630                     NaN
#                                                              1    USD    2178 5172.0 US      20190630                     NaN
#
# tag                                                                                                    ...  \
# adsh                 company_name                   ddate    qtrs uom    cik  sic    country period    ...
# 0000002178-19-000086 ADAMS RESOURCES & ENERGY, INC. 20180630 1    USD    2178 5172.0 US      20190630  ...
#                                                     20181231 0    USD    2178 5172.0 US      20190630  ...
#                                                                   shares 2178 5172.0 US      20190630  ...
#                                                     20190331 0    shares 2178 5172.0 US      20190630  ...
#                                                              1    USD    2178 5172.0 US      20190630  ...
#
# tag                                                                                                    WriteoffOfCreditFacilityAmendmentFees  \
# adsh                 company_name                   ddate    qtrs uom    cik  sic    country period
# 0000002178-19-000086 ADAMS RESOURCES & ENERGY, INC. 20180630 1    USD    2178 5172.0 US      20190630                                    NaN
#                                                     20181231 0    USD    2178 5172.0 US      20190630                                    NaN
#                                                                   shares 2178 5172.0 US      20190630                                    NaN
#                                                     20190331 0    shares 2178 5172.0 US      20190630                                    NaN
#                                                              1    USD    2178 5172.0 US      20190630                                    NaN
#
# tag                                                                                                    WriteoffOfDeferredOfferingCosts  \
# adsh                 company_name                   ddate    qtrs uom    cik  sic    country period
# 0000002178-19-000086 ADAMS RESOURCES & ENERGY, INC. 20180630 1    USD    2178 5172.0 US      20190630                              NaN
#                                                     20181231 0    USD    2178 5172.0 US      20190630                              NaN
#                                                                   shares 2178 5172.0 US      20190630                              NaN
#                                                     20190331 0    shares 2178 5172.0 US      20190630                              NaN
#                                                              1    USD    2178 5172.0 US      20190630                              NaN
#
# tag                                                                                                    WriteoffOfFullyDepreciatedAsset  \
# adsh                 company_name                   ddate    qtrs uom    cik  sic    country period
# 0000002178-19-000086 ADAMS RESOURCES & ENERGY, INC. 20180630 1    USD    2178 5172.0 US      20190630                              NaN
#                                                     20181231 0    USD    2178 5172.0 US      20190630                              NaN
#                                                                   shares 2178 5172.0 US      20190630                              NaN
#                                                     20190331 0    shares 2178 5172.0 US      20190630                              NaN
#                                                              1    USD    2178 5172.0 US      20190630                              NaN
#
# tag                                                                                                    WriteoffOfInsuranceReceivable  \
# adsh                 company_name                   ddate    qtrs uom    cik  sic    country period
# 0000002178-19-000086 ADAMS RESOURCES & ENERGY, INC. 20180630 1    USD    2178 5172.0 US      20190630                            NaN
#                                                     20181231 0    USD    2178 5172.0 US      20190630                            NaN
#                                                                   shares 2178 5172.0 US      20190630                            NaN
#                                                     20190331 0    shares 2178 5172.0 US      20190630                            NaN
#                                                              1    USD    2178 5172.0 US      20190630                            NaN
#
# tag                                                                                                    WriteoffofNetDiscountandDebtIssuanceCosts  \
# adsh                 company_name                   ddate    qtrs uom    cik  sic    country period
# 0000002178-19-000086 ADAMS RESOURCES & ENERGY, INC. 20180630 1    USD    2178 5172.0 US      20190630                                        NaN
#                                                     20181231 0    USD    2178 5172.0 US      20190630                                        NaN
#                                                                   shares 2178 5172.0 US      20190630                                        NaN
#                                                     20190331 0    shares 2178 5172.0 US      20190630                                        NaN
#                                                              1    USD    2178 5172.0 US      20190630                                        NaN
#
# tag                                                                                                    WrittenOptionsAtFairValue  \
# adsh                 company_name                   ddate    qtrs uom    cik  sic    country period
# 0000002178-19-000086 ADAMS RESOURCES & ENERGY, INC. 20180630 1    USD    2178 5172.0 US      20190630                        NaN
#                                                     20181231 0    USD    2178 5172.0 US      20190630                        NaN
#                                                                   shares 2178 5172.0 US      20190630                        NaN
#                                                     20190331 0    shares 2178 5172.0 US      20190630                        NaN
#                                                              1    USD    2178 5172.0 US      20190630                        NaN
#
# tag                                                                                                    WrittendownValue  \
# adsh                 company_name                   ddate    qtrs uom    cik  sic    country period
# 0000002178-19-000086 ADAMS RESOURCES & ENERGY, INC. 20180630 1    USD    2178 5172.0 US      20190630               NaN
#                                                     20181231 0    USD    2178 5172.0 US      20190630               NaN
#                                                                   shares 2178 5172.0 US      20190630               NaN
#                                                     20190331 0    shares 2178 5172.0 US      20190630               NaN
#                                                              1    USD    2178 5172.0 US      20190630               NaN
#
# tag                                                                                                    WrittendownValueFixedAssets  \
# adsh                 company_name                   ddate    qtrs uom    cik  sic    country period
# 0000002178-19-000086 ADAMS RESOURCES & ENERGY, INC. 20180630 1    USD    2178 5172.0 US      20190630                          NaN
#                                                     20181231 0    USD    2178 5172.0 US      20190630                          NaN
#                                                                   shares 2178 5172.0 US      20190630                          NaN
#                                                     20190331 0    shares 2178 5172.0 US      20190630                          NaN
#                                                              1    USD    2178 5172.0 US      20190630                          NaN
#
# tag                                                                                                    WrittendownValueOtherAssets  \
# adsh                 company_name                   ddate    qtrs uom    cik  sic    country period
# 0000002178-19-000086 ADAMS RESOURCES & ENERGY, INC. 20180630 1    USD    2178 5172.0 US      20190630                          NaN
#                                                     20181231 0    USD    2178 5172.0 US      20190630                          NaN
#                                                                   shares 2178 5172.0 US      20190630                          NaN
#                                                     20190331 0    shares 2178 5172.0 US      20190630                          NaN
#                                                              1    USD    2178 5172.0 US      20190630                          NaN
#
# tag                                                                                                    property
# adsh                 company_name                   ddate    qtrs uom    cik  sic    country period
# 0000002178-19-000086 ADAMS RESOURCES & ENERGY, INC. 20180630 1    USD    2178 5172.0 US      20190630       NaN
#                                                     20181231 0    USD    2178 5172.0 US      20190630       NaN
#                                                                   shares 2178 5172.0 US      20190630       NaN
#                                                     20190331 0    shares 2178 5172.0 US      20190630       NaN
#                                                              1    USD    2178 5172.0 US      20190630       NaN
#
# [5 rows x 21068 columns]

# %%
percent_missing = sec_data_wide.isnull().sum() * 100 / len(sec_data_wide)
missing_value_df = pd.DataFrame({'column_name': sec_data_wide.columns,
                                 'percent_missing': percent_missing}).sort_values('percent_missing', ascending = True)

# %%
missing_value_df.head()
# Out:
#                                                    column_name  \
# tag
# CommonStockSharesAuthorized        CommonStockSharesAuthorized
# CommonStockSharesIssued                CommonStockSharesIssued
# CommonStockSharesOutstanding      CommonStockSharesOutstanding
# PreferredStockSharesAuthorized  PreferredStockSharesAuthorized
# InterestExpense                                InterestExpense
#
#                                 percent_missing
# tag
# CommonStockSharesAuthorized           83.811840
# CommonStockSharesIssued               84.298172
# CommonStockSharesOutstanding          85.140030
# PreferredStockSharesAuthorized        89.458326
# InterestExpense                       89.560624

# %% [markdown]
# ## Save <a name="Save"></a>
# Create CSV versions in build/raw

# %%
sec_data.to_csv(data_root+'02-build/clean/2019q3/sec_data_long.csv')

# %%
sec_data_wide.to_csv(data_root+'02-build/clean/2019q3/sec_data_wide.csv')
