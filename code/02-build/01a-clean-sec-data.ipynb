# %% [markdown]
# # Program Header

# %%
import pandas as pd
import numpy as np
import autoreload
import os
import sys
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
nb_dir = os.path.split(os.getcwd())[0]
if nb_dir not in sys.path:
    sys.path.append(nb_dir)
from header import *

# %%
data_root = initialize_data_root("AY")

# %% [markdown]
# # Table of contents
# 1. [Import](#Import)
# 2. [Data Understanding](#DataUnderstanding)
# 2. [Clean](#Clean)
# 3. [Merge](#Merge)
# 5. [Save](#Save)

# %% [markdown]
# ## Import <a name="Import"></a>

# %%
raw_num_data = pd.read_csv(data_root+'02-build/raw/2019q3/num.csv')
raw_pre_data = pd.read_csv(data_root+'02-build/raw/2019q3/pre.csv')
raw_sub_data = pd.read_csv(data_root+'02-build/raw/2019q3/sub.csv')
raw_tag_data = pd.read_csv(data_root+'02-build/raw/2019q3/tag.csv')

# %% [markdown]
# ## Data Understanding <a name="DataUnderstanding"></a>

# %% [markdown]
# Useful columns based on reading the readme.txt:
# * **num**: Numeric data and actual values associated to `adsh-ddate-tag-etc`. All columns are relevant
# * **pre**: Location of tags and a preferred label (`plabel`). `plabel` (and joining columns) seems relevant
# * **sub**: Summary information about submission. Business-specific information including industry and company name are relevant
# * **tag**: Tag-level dataset. `doc` seems to be a more descriptive `plabel` from **pre** dataset

# %% [markdown]
# ## Clean <a name="Clean"></a>
# Clean the individual datasets to prepare for the merge

# %%
raw_num_data.head()
# Out:
#                    adsh                                  tag      version  \
# 0  0001625376-19-000017                    EntityPublicFloat     dei/2014
# 1  0000034563-19-000064  DerivativeNonmonetaryNotionalAmount  invest/2013
# 2  0000034563-19-000064  DerivativeNonmonetaryNotionalAmount  invest/2013
# 3  0001370946-19-000033  DerivativeNonmonetaryNotionalAmount  invest/2013
# 4  0000225648-19-000108  DerivativeNonmonetaryNotionalAmount  invest/2013
#
#   coreg     ddate  qtrs    uom       value footnote
# 0   NaN  20180430     0    USD         0.0      NaN
# 1   NaN  20190630     0     lb  48183000.0      NaN
# 2   NaN  20180630     0     lb  43459000.0      NaN
# 3   NaN  20190630     0  MMBTU         2.0      NaN
# 4   NaN  20190630     0     MW   4300000.0      NaN

# %%
raw_pre_data.head()
# Out:
#                    adsh  report  line stmt  inpth rfile  \
# 0  0001625376-19-000017       1     9   CP      0     H
# 1  0001625376-19-000017       1    14   CP      0     H
# 2  0001625376-19-000019       1    11   CP      0     H
# 3  0001766016-19-000005       1    10   CP      0     H
# 4  0001047469-19-004442       1     6   CP      0     H
#
#                        tag   version                      plabel  negating
# 0        EntityPublicFloat  dei/2014         Entity Public Float         0
# 1  DocumentFiscalYearFocus  dei/2014  Document Fiscal Year Focus         0
# 2  DocumentFiscalYearFocus  dei/2014  Document Fiscal Year Focus         0
# 3  DocumentFiscalYearFocus  dei/2014  Document Fiscal Year Focus         0
# 4  DocumentFiscalYearFocus  dei/2014  Document Fiscal Year Focus         0

# %%
raw_sub_data.head()
# Out:
#                    adsh   cik                               name     sic  \
# 0  0000002178-19-000086  2178     ADAMS RESOURCES & ENERGY, INC.  5172.0
# 1  0000002488-19-000104  2488         ADVANCED MICRO DEVICES INC  3674.0
# 2  0000002488-19-000113  2488         ADVANCED MICRO DEVICES INC  3674.0
# 3  0000002488-19-000144  2488         ADVANCED MICRO DEVICES INC  3674.0
# 4  0000002969-19-000042  2969  AIR PRODUCTS & CHEMICALS INC /DE/  2810.0
#
#   countryba stprba       cityba       zipba                    bas1 bas2  ...  \
# 0        US     TX      HOUSTON       77027  17 S. BRIAR HOLLOW LN.  NaN  ...
# 1        US     CA  SANTA CLARA       95054    2485 AUGUSTINE DRIVE  NaN  ...
# 2        US     CA  SANTA CLARA       95054    2485 AUGUSTINE DRIVE  NaN  ...
# 3        US     CA  SANTA CLARA       95054    2485 AUGUSTINE DRIVE  NaN  ...
# 4        US     PA    ALLENTOWN  18195-1501      7201 HAMILTON BLVD  NaN  ...
#
#      period      fy  fp     filed               accepted prevrpt detail  \
# 0  20190630  2019.0  Q2  20190807  2019-08-07 17:21:00.0       0      1
# 1  20190630  2019.0  Q2  20190731  2019-07-31 16:27:00.0       0      1
# 2  20190731  2019.0  Q3  20190808  2019-08-08 16:10:00.0       0      0
# 3  20190831  2019.0  Q3  20190906  2019-09-06 16:11:00.0       0      0
# 4  20190630  2019.0  Q3  20190725  2019-07-25 13:02:00.0       0      1
#
#                          instance nciks  aciks
# 0             ae-20190630_htm.xml     1    NaN
# 1          amd0629201910q_htm.xml     1    NaN
# 2       amdform8k08082019_htm.xml     1    NaN
# 3  amdform8kequitysalesse_htm.xml     1    NaN
# 4       apd-10qx30jun2019_htm.xml     1    NaN
#
# [5 rows x 36 columns]

# %%
raw_tag_data.head()
# Out:
#                         tag      version  custom  abstract   datatype iord  \
# 0         EntityPublicFloat     dei/2014       0         0   monetary    I
# 1   DocumentFiscalYearFocus     dei/2014       0         0      gYear    D
# 2     DocumentPeriodEndDate     dei/2014       0         0       date    D
# 3  CurrentFiscalYearEndDate     dei/2014       0         0  gMonthDay    D
# 4            InvestmentAxis  invest/2013       0         1       axis  NaN
#
#   crdr                        tlabel  \
# 0    C           Entity Public Float
# 1  NaN    Document Fiscal Year Focus
# 2  NaN      Document Period End Date
# 3  NaN  Current Fiscal Year End Date
# 4  NaN             Investment [Axis]
#
#                                                  doc
# 0  State aggregate market value of voting and non...
# 1  This is focus fiscal year of the document repo...
# 2  The end date of the period reflected on the co...
# 3  End date of current fiscal year in the format ...
# 4  A categorization of investments (securities, d...

# %% [markdown]
# ## Clean <a name="Clean"></a>

# %%
pre_data = raw_num_data\
    .filter(['adsh', 'tag', 'version', 'plabel'], axis = 'columns')\
    .drop_duplicates()

# %%
sub_data = raw_sub_data\
    .filter(['adsh', 'cik', 'name', 'sic', 'countryba', 'period', 'form', 'fye', 'accepted', 'instance'], axis = 'columns')\
    .rename(mapper = {'name':'company_name', 'countryba':'country'}, axis = 'columns')\
    .query("form in ['10-Q', '10-K']") # Keep only the quarterly and annual filings

# %%
tag_data = raw_tag_data\
    .filter(['tag', 'version', 'doc'])\
    .drop_duplicates()

# %%
tag_data['doc'][0]
# Out:
# "State aggregate market value of voting and non-voting common equity held by non-affiliates computed by reference to price at which the common equity was last sold, or average bid and asked price of such common equity, as of the last business day of registrant's most recently completed second fiscal quarter. The public float should be reported on the cover page of the registrants form 10K."

# %%
# Get rid of coregister/parent company
# Keep only the balance sheet and single quarter flows

num_data = raw_num_data\
    .drop('footnote', axis = 'columns')\
    .assign(no_coreg = pd.isna(raw_num_data['coreg']))\
    .assign(no_value = pd.isna(raw_num_data['value']))\
    .assign(ddate = pd.to_datetime(raw_num_data['ddate'], format='%Y%m%d', errors = 'coerce'))\
    .query("(no_coreg == True) & (no_value == False) & (ddate > '2018-01-01')")\
    .query("(qtrs in (0,1))")\
    .query("uom in ('USD', 'shares', 'pure')")

# %%
num_data.shape
# Out:
# (1273597, 10)

# %% [markdown]
# See if we have **num_data** observations at the `adsh, tag, ddate` level

# %%
multiple_matches = num_data.groupby(['adsh', 'tag', 'ddate'], as_index = False)\
    .count()\
    .sort_values('value', ascending = False)\
    .query("value > 1")
duplicate_causing_tags = multiple_matches.tag.unique()

# %%
print("%.2f%% tags create duplicates"% round(len(duplicate_causing_tags)/len(num_data.tag.unique())*100,2))
# Out:
# 0.20% tags create duplicates

# %% [markdown]
# Since only a small percent of tags are trouble, we'll just remove them for now.

# %%
num_data = num_data.query("tag not in @duplicate_causing_tags")

# %% [markdown]
# Note for checking: These tags may just be variations of other important tags. Investigate if we're dropping anything important. Needs further investigation during checking process.

# %% [markdown]
# Now, we have unique rows for each `adsh, tag, ddate`.

# %%
multiple_matches = num_data.groupby(['adsh', 'tag', 'ddate'], as_index = False)\
    .count()\
    .sort_values('value', ascending = False)\
    .query("value > 1")
multiple_matches
# Out:
# Empty DataFrame
# Columns: [adsh, tag, ddate, version, coreg, qtrs, uom, value, no_coreg, no_value]
# Index: []

# %% [markdown]
# ## Merge <a name="Merge"></a>

# %%
num_data.columns
# Out:
# Index(['adsh', 'tag', 'version', 'coreg', 'ddate', 'qtrs', 'uom', 'value',
#        'no_coreg', 'no_value'],
#       dtype='object')

# %%
sec_data = num_data.merge(pre_data, on = ['adsh', 'tag', 'version'])\
    .merge(sub_data, on = ['adsh'])\
    .merge(tag_data, on = ['tag', 'version'])

# %%
sec_data
# Out:
#                         adsh  \
# 0       0001326771-19-000035
# 1       0001326771-19-000035
# 2       0001392091-19-000074
# 3       0001558370-19-007743
# 4       0001558370-19-007743
# 5       0000877860-19-000070
# 6       0001254699-19-000011
# 7       0001331465-19-000121
# 8       0001331465-19-000121
# 9       0001518715-19-000167
# 10      0001518715-19-000167
# 11      0001331463-19-000129
# 12      0001331463-19-000129
# 13      0001339947-19-000031
# 14      0001339947-19-000031
# 15      0001564590-19-030266
# 16      0001564590-19-030266
# 17      0000937834-19-000017
# 18      0000937834-19-000017
# 19      0001325878-19-000017
# 20      0001325878-19-000017
# 21      0001564590-19-030843
# 22      0001564590-19-030843
# 23      0001628280-19-010467
# 24      0001628280-19-010467
# 25      0000930236-19-000026
# 26      0000930236-19-000026
# 27      0001331451-19-000147
# 28      0001331451-19-000147
# 29      0001281761-19-000071
# ...                      ...
# 785718  ValueOfStockClassifiedAsTemporaryEquitySurrend...
# 785719  StockholdersEquityIncludingPortionsAttributabl...
# 785720                       Restrictedvotingsharesissued
# 785721                       Restrictedvotingsharesissued
# 785722                  Restrictedvotingsharesoutstanding
# 785723                  Restrictedvotingsharesoutstanding
# 785724            SpecialVotingSharesIssuedandOutstanding
# 785725            SpecialVotingSharesIssuedandOutstanding
# 785726           Managementleasingandotherservicesrevenue
# 785727           Managementleasingandotherservicesrevenue
#
#                      version coreg      ddate  qtrs     uom         value  \
# 0                invest/2013   NaN 2019-06-30     0     USD  3.024480e+10
# 1                invest/2013   NaN 2018-12-31     0     USD  1.380677e+10
# 2                invest/2013   NaN 2019-06-30     0     USD  0.000000e+00
# 3                invest/2013   NaN 2018-12-31     0     USD  7.059350e+08
# 4                invest/2013   NaN 2019-06-30     0     USD  9.058640e+08
# 5                invest/2013   NaN 2019-06-30     0     USD  6.100000e+08
# 6                invest/2013   NaN 2019-06-30     0     USD  1.250000e+08
# 7                invest/2013   NaN 2019-06-30     0     USD  6.435700e+10
# 8                invest/2013   NaN 2018-12-31     0     USD  5.951800e+10
# 9                invest/2013   NaN 2019-06-30     0     USD  4.103995e+09
# 10               invest/2013   NaN 2018-12-31     0     USD  5.698157e+09
# 11               invest/2013   NaN 2019-06-30     0     USD  1.281230e+10
# 12               invest/2013   NaN 2018-12-31     0     USD  1.324127e+10
# 13               invest/2013   NaN 2019-06-30     0     USD  7.250000e+08
# 14               invest/2013   NaN 2018-09-30     0     USD  6.420000e+08
# 15               invest/2013   NaN 2018-12-31     0     USD  5.489690e+08
# 16               invest/2013   NaN 2019-06-30     0     USD  5.410600e+08
# 17               invest/2013   NaN 2019-06-30     0     USD  2.284080e+11
# 18               invest/2013   NaN 2018-12-31     0     USD  2.264340e+11
# 19               invest/2013   NaN 2019-06-30     0     USD  1.837870e+10
# 20               invest/2013   NaN 2018-12-31     0     USD  1.249760e+10
# 21               invest/2013   NaN 2019-06-30     0     USD  6.600000e+08
# 22               invest/2013   NaN 2018-12-31     0     USD  6.600000e+08
# 23               invest/2013   NaN 2019-06-30     0     USD  3.004000e+08
# 24               invest/2013   NaN 2018-12-31     0     USD  2.782000e+08
# 25               invest/2013   NaN 2019-06-30     0     USD  7.597742e+09
# 26               invest/2013   NaN 2018-12-31     0     USD  5.911385e+09
# 27               invest/2013   NaN 2019-06-30     0     USD  5.882800e+10
# 28               invest/2013   NaN 2018-12-31     0     USD  5.597100e+10
# 29               invest/2013   NaN 2019-06-30     0     USD  1.321210e+11
# ...                      ...   ...        ...   ...     ...           ...
# 785698  0001437749-19-015637   NaN 2019-06-30     1     USD  2.507089e+08
# 785699  0001437749-19-015637   NaN 2018-06-30     1     USD -2.751807e+07
# 785700  0001437749-19-015637   NaN 2019-06-30     1     USD -1.636611e+07
# 785701  0001437749-19-015637   NaN 2018-06-30     1     USD  6.592413e+06
# 785702  0001437749-19-015637   NaN 2019-06-30     1     USD  5.821811e+06
# 785703  0001437749-19-015637   NaN 2018-03-31     1     USD  2.073779e+08
# 785704  0001437749-19-015637   NaN 2018-06-30     1     USD  3.503905e+08
# 785705  0001437749-19-015637   NaN 2019-03-31     1     USD  3.026811e+08
# 785706  0001437749-19-015637   NaN 2019-06-30     1     USD  8.443112e+07
# 785707  0001437749-19-015635   NaN 2018-03-31     1     USD  1.400918e+09
# 785708  0001437749-19-015635   NaN 2018-06-30     1     USD -7.497589e+08
# 785709  0001437749-19-015635   NaN 2019-03-31     1     USD  1.011594e+09
# 785710  0001437749-19-015635   NaN 2019-06-30     1     USD  7.901011e+08
# 785711  0001437749-19-015635   NaN 2018-06-30     1     USD  2.850656e+07
# 785712  0001437749-19-015635   NaN 2019-06-30     1     USD  2.214776e+07
# 785713  0001437749-19-015635   NaN 2018-06-30     1     USD  7.411485e+06
# 785714  0001437749-19-015635   NaN 2019-06-30     1     USD  7.621405e+06
# 785715  0001437749-19-015635   NaN 2018-03-31     1     USD  3.795732e+07
# 785716  0001437749-19-015635   NaN 2018-06-30     1     USD  9.929480e+08
# 785717  0001437749-19-015635   NaN 2019-03-31     1     USD  1.657133e+08
# 785718  0001437749-19-015635   NaN 2019-06-30     1     USD  9.769686e+08
# 785719  0001213900-19-017166   NaN 2019-06-30     0     USD  6.553009e+06
# 785720  0001714973-19-000038   NaN 2018-12-31     0  shares  3.494499e+07
# 785721  0001714973-19-000038   NaN 2019-06-30     0  shares  3.494499e+07
# 785722  0001714973-19-000038   NaN 2018-12-31     0  shares  3.494499e+07
# 785723  0001714973-19-000038   NaN 2019-06-30     0  shares  3.994499e+07
# 785724  0001714973-19-000038   NaN 2018-12-31     0  shares  8.135382e+07
# 785725  0001714973-19-000038   NaN 2019-06-30     0  shares  8.135382e+07
# 785726  0000899715-19-000127   NaN 2019-06-30     1     USD  1.245000e+06
# 785727  0000899715-19-000127   NaN 2018-06-30     1     USD  1.142000e+06
#
#         no_coreg  no_value      cik                          company_name  \
# 0           True     False  1326771  FEDERAL HOME LOAN BANK OF CINCINNATI
# 1           True     False  1326771  FEDERAL HOME LOAN BANK OF CINCINNATI
# 2           True     False  1392091      BLUEKNIGHT ENERGY PARTNERS, L.P.
# 3           True     False  1527590                    READY CAPITAL CORP
# 4           True     False  1527590                    READY CAPITAL CORP
# 5           True     False   877860         NATIONAL HEALTH INVESTORS INC
# 6           True     False  1254699                               QVC INC
# 7           True     False  1331465     FEDERAL HOME LOAN BANK OF ATLANTA
# 8           True     False  1331465     FEDERAL HOME LOAN BANK OF ATLANTA
# 9           True     False  1518715                      HOMESTREET, INC.
# 10          True     False  1518715                      HOMESTREET, INC.
# 11          True     False  1331463      FEDERAL HOME LOAN BANK OF BOSTON
# 12          True     False  1331463      FEDERAL HOME LOAN BANK OF BOSTON
# 13          True     False  1339947                           VIACOM INC.
# 14          True     False  1339947                           VIACOM INC.
# 15          True     False  1702750                  BYLINE BANCORP, INC.
# 16          True     False  1702750                  BYLINE BANCORP, INC.
# 17          True     False   937834        METROPOLITAN LIFE INSURANCE CO
# 18          True     False   937834        METROPOLITAN LIFE INSURANCE CO
# 19          True     False  1325878      FEDERAL HOME LOAN BANK OF TOPEKA
# 20          True     False  1325878      FEDERAL HOME LOAN BANK OF TOPEKA
# 21          True     False  1722287                   COVIA HOLDINGS CORP
# 22          True     False  1722287                   COVIA HOLDINGS CORP
# 23          True     False   850141       HORACE MANN EDUCATORS CORP /DE/
# 24          True     False   850141       HORACE MANN EDUCATORS CORP /DE/
# 25          True     False   930236                     REDWOOD TRUST INC
# 26          True     False   930236                     REDWOOD TRUST INC
# 27          True     False  1331451     FEDERAL HOME LOAN BANK OF CHICAGO
# 28          True     False  1331451     FEDERAL HOME LOAN BANK OF CHICAGO
# 29          True     False  1281761                REGIONS FINANCIAL CORP
# ...          ...       ...      ...                                   ...
# 785698      True     False  1330568                  ISHARES SILVER TRUST
# 785699      True     False  1330568                  ISHARES SILVER TRUST
# 785700      True     False  1330568                  ISHARES SILVER TRUST
# 785701      True     False  1330568                  ISHARES SILVER TRUST
# 785702      True     False  1330568                  ISHARES SILVER TRUST
# 785703      True     False  1330568                  ISHARES SILVER TRUST
# 785704      True     False  1330568                  ISHARES SILVER TRUST
# 785705      True     False  1330568                  ISHARES SILVER TRUST
# 785706      True     False  1330568                  ISHARES SILVER TRUST
# 785707      True     False  1278680                    ISHARES GOLD TRUST
# 785708      True     False  1278680                    ISHARES GOLD TRUST
# 785709      True     False  1278680                    ISHARES GOLD TRUST
# 785710      True     False  1278680                    ISHARES GOLD TRUST
# 785711      True     False  1278680                    ISHARES GOLD TRUST
# 785712      True     False  1278680                    ISHARES GOLD TRUST
# 785713      True     False  1278680                    ISHARES GOLD TRUST
# 785714      True     False  1278680                    ISHARES GOLD TRUST
# 785715      True     False  1278680                    ISHARES GOLD TRUST
# 785716      True     False  1278680                    ISHARES GOLD TRUST
# 785717      True     False  1278680                    ISHARES GOLD TRUST
# 785718      True     False  1278680                    ISHARES GOLD TRUST
# 785719      True     False  1098996                            ORANCO INC
# 785720      True     False  1714973              KINDER MORGAN CANADA LTD
# 785721      True     False  1714973              KINDER MORGAN CANADA LTD
# 785722      True     False  1714973              KINDER MORGAN CANADA LTD
# 785723      True     False  1714973              KINDER MORGAN CANADA LTD
# 785724      True     False  1714973              KINDER MORGAN CANADA LTD
# 785725      True     False  1714973              KINDER MORGAN CANADA LTD
# 785726      True     False   899715    TANGER FACTORY OUTLET CENTERS, INC
# 785727      True     False   899715    TANGER FACTORY OUTLET CENTERS, INC
#
#            sic country    period  form     fye               accepted  \
# 0       6111.0      US  20190630  10-Q  1231.0  2019-08-08 12:19:00.0
# 1       6111.0      US  20190630  10-Q  1231.0  2019-08-08 12:19:00.0
# 2       4610.0      US  20190630  10-Q  1231.0  2019-08-08 16:25:00.0
# 3       6798.0      US  20190630  10-Q  1231.0  2019-08-08 17:02:00.0
# 4       6798.0      US  20190630  10-Q  1231.0  2019-08-08 17:02:00.0
# 5       6798.0      US  20190630  10-Q  1231.0  2019-08-07 19:01:00.0
# 6       5961.0     NaN  20190630  10-Q  1231.0  2019-08-08 16:49:00.0
# 7       6111.0      US  20190630  10-Q  1231.0  2019-08-08 11:31:00.0
# 785715    iau20190630_10q_htm.xml
# 785716    iau20190630_10q_htm.xml
# 785717    iau20190630_10q_htm.xml
# 785718    iau20190630_10q_htm.xml
# 785719          ornc-20190630.xml
# 785720           kml-20190630.xml
# 785721           kml-20190630.xml
# 785722           kml-20190630.xml
# 785723           kml-20190630.xml
# 785724           kml-20190630.xml
# 785725           kml-20190630.xml
# 785726      skt10q6302019_htm.xml
# 785727      skt10q6302019_htm.xml
#
#                                                       doc
# 0       Aggregate notional amount specified by the der...
# 1       Aggregate notional amount specified by the der...
# 2       Aggregate notional amount specified by the der...
# 3       Aggregate notional amount specified by the der...
# 4       Aggregate notional amount specified by the der...
# 5       Aggregate notional amount specified by the der...
# 6       Aggregate notional amount specified by the der...
# 7       Aggregate notional amount specified by the der...
# 8       Aggregate notional amount specified by the der...
# 9       Aggregate notional amount specified by the der...
# 10      Aggregate notional amount specified by the der...
# 11      Aggregate notional amount specified by the der...
# 12      Aggregate notional amount specified by the der...
# 13      Aggregate notional amount specified by the der...
# 14      Aggregate notional amount specified by the der...
# 15      Aggregate notional amount specified by the der...
# 16      Aggregate notional amount specified by the der...
# 17      Aggregate notional amount specified by the der...
# 18      Aggregate notional amount specified by the der...
# 19      Aggregate notional amount specified by the der...
# 20      Aggregate notional amount specified by the der...
# 21      Aggregate notional amount specified by the der...
# 22      Aggregate notional amount specified by the der...
# 23      Aggregate notional amount specified by the der...
# 24      Aggregate notional amount specified by the der...
# 25      Aggregate notional amount specified by the der...
# 26      Aggregate notional amount specified by the der...
# 27      Aggregate notional amount specified by the der...
# 28      Aggregate notional amount specified by the der...
# 29      Aggregate notional amount specified by the der...
# ...                                                   ...
# 785698                 Increase (decrease) in net assets.
# 785699  The net realized gain (loss) from silver distr...
# 785700  The net realized gain (loss) from silver distr...
# 785701             Fees paid to the sponsor of the trust.
# 785702             Fees paid to the sponsor of the trust.
# 785703  Value of stock classified as temporary equity ...
# 785704  Value of stock classified as temporary equity ...
# 785705  Value of stock classified as temporary equity ...
# 785706  Value of stock classified as temporary equity ...
# 785707                 Increase (decrease) in net assets.
# 785708                 Increase (decrease) in net assets.
# 785709                 Increase (decrease) in net assets.
# 785710                 Increase (decrease) in net assets.
# 785711  The net realized gain (loss) from gold distrib...
# 785712  The net realized gain (loss) from gold distrib...
# 785713             Fees paid to the sponsor of the trust.
# 785714             Fees paid to the sponsor of the trust.
# 785715  Represents the value of stock classified as te...
# 785716  Represents the value of stock classified as te...
# 785717  Represents the value of stock classified as te...
# 785718  Represents the value of stock classified as te...
# 785719                                                NaN
# 785720                    Restricted voting shares issued
# 785721                    Restricted voting shares issued
# 785722               Restricted voting shares outstanding
# 785723               Restricted voting shares outstanding
# 785724      Special Voting Shares, Issued and Outstanding
# 785725      Special Voting Shares, Issued and Outstanding
# 785726  The net management, leasing and other services...
# 785727  The net management, leasing and other services...
#
# [785728 rows x 20 columns]

# %% [markdown]
# ## Save <a name="Save"></a>
# Create CSV versions in build/raw

# %%
sec_data.to_csv(data_root+'02-build/clean/2019q3/sec_data_long.csv', index = False)
