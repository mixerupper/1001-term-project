# %% [markdown]
# # Program Header

# %%
import pandas as pd
import numpy as np
import autoreload
import os
import sys
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
nb_dir = os.path.split(os.getcwd())[0]
if nb_dir not in sys.path:
    sys.path.append(nb_dir)
from header import *

# %%
data_root = initialize_data_root("AY")

# %% [markdown]
# # Table of contents
# 1. [Import](#Import)
# 2. [Data Understanding](#DataUnderstanding)
# 2. [Clean](#Clean)
# 3. [Merge](#Merge)
# 5. [Save](#Save)

# %% [markdown]
# ## Import <a name="Import"></a>

# %%
raw_num_data = pd.read_csv(data_root+'02-build/raw/2019q3/num.csv')
raw_pre_data = pd.read_csv(data_root+'02-build/raw/2019q3/pre.csv')
raw_sub_data = pd.read_csv(data_root+'02-build/raw/2019q3/sub.csv')
raw_tag_data = pd.read_csv(data_root+'02-build/raw/2019q3/tag.csv')

# %% [markdown]
# ## Data Understanding <a name="DataUnderstanding"></a>

# %% [markdown]
# Useful columns based on reading the readme.txt:
# * **num**: Numeric data and actual values associated to `adsh-ddate-tag-etc`. All columns are relevant
# * **pre**: Location of tags and a preferred label (`plabel`). `plabel` (and joining columns) seems relevant
# * **sub**: Summary information about submission. Business-specific information including industry and company name are relevant
# * **tag**: Tag-level dataset. `doc` seems to be a more descriptive `plabel` from **pre** dataset

# %% [markdown]
# ## Clean <a name="Clean"></a>
# Clean the individual datasets to prepare for the merge

# %%
raw_num_data.head()
# Out:
#                    adsh                                  tag      version  \
# 0  0001625376-19-000017                    EntityPublicFloat     dei/2014
# 1  0000034563-19-000064  DerivativeNonmonetaryNotionalAmount  invest/2013
# 2  0000034563-19-000064  DerivativeNonmonetaryNotionalAmount  invest/2013
# 3  0001370946-19-000033  DerivativeNonmonetaryNotionalAmount  invest/2013
# 4  0000225648-19-000108  DerivativeNonmonetaryNotionalAmount  invest/2013
#
#   coreg     ddate  qtrs    uom       value footnote
# 0   NaN  20180430     0    USD         0.0      NaN
# 1   NaN  20190630     0     lb  48183000.0      NaN
# 2   NaN  20180630     0     lb  43459000.0      NaN
# 3   NaN  20190630     0  MMBTU         2.0      NaN
# 4   NaN  20190630     0     MW   4300000.0      NaN

# %%
raw_pre_data.head()
# Out:
#                    adsh  report  line stmt  inpth rfile  \
# 0  0001625376-19-000017       1     9   CP      0     H
# 1  0001625376-19-000017       1    14   CP      0     H
# 2  0001625376-19-000019       1    11   CP      0     H
# 3  0001766016-19-000005       1    10   CP      0     H
# 4  0001047469-19-004442       1     6   CP      0     H
#
#                        tag   version                      plabel  negating
# 0        EntityPublicFloat  dei/2014         Entity Public Float         0
# 1  DocumentFiscalYearFocus  dei/2014  Document Fiscal Year Focus         0
# 2  DocumentFiscalYearFocus  dei/2014  Document Fiscal Year Focus         0
# 3  DocumentFiscalYearFocus  dei/2014  Document Fiscal Year Focus         0
# 4  DocumentFiscalYearFocus  dei/2014  Document Fiscal Year Focus         0

# %%
raw_sub_data.head()
# Out:
#                    adsh   cik                               name     sic  \
# 0  0000002178-19-000086  2178     ADAMS RESOURCES & ENERGY, INC.  5172.0
# 1  0000002488-19-000104  2488         ADVANCED MICRO DEVICES INC  3674.0
# 2  0000002488-19-000113  2488         ADVANCED MICRO DEVICES INC  3674.0
# 3  0000002488-19-000144  2488         ADVANCED MICRO DEVICES INC  3674.0
# 4  0000002969-19-000042  2969  AIR PRODUCTS & CHEMICALS INC /DE/  2810.0
#
#   countryba stprba       cityba       zipba                    bas1 bas2  ...  \
# 0        US     TX      HOUSTON       77027  17 S. BRIAR HOLLOW LN.  NaN  ...
# 1        US     CA  SANTA CLARA       95054    2485 AUGUSTINE DRIVE  NaN  ...
# 2        US     CA  SANTA CLARA       95054    2485 AUGUSTINE DRIVE  NaN  ...
# 3        US     CA  SANTA CLARA       95054    2485 AUGUSTINE DRIVE  NaN  ...
# 4        US     PA    ALLENTOWN  18195-1501      7201 HAMILTON BLVD  NaN  ...
#
#      period      fy  fp     filed               accepted prevrpt detail  \
# 0  20190630  2019.0  Q2  20190807  2019-08-07 17:21:00.0       0      1
# 1  20190630  2019.0  Q2  20190731  2019-07-31 16:27:00.0       0      1
# 2  20190731  2019.0  Q3  20190808  2019-08-08 16:10:00.0       0      0
# 3  20190831  2019.0  Q3  20190906  2019-09-06 16:11:00.0       0      0
# 4  20190630  2019.0  Q3  20190725  2019-07-25 13:02:00.0       0      1
#
#                          instance nciks  aciks
# 0             ae-20190630_htm.xml     1    NaN
# 1          amd0629201910q_htm.xml     1    NaN
# 2       amdform8k08082019_htm.xml     1    NaN
# 3  amdform8kequitysalesse_htm.xml     1    NaN
# 4       apd-10qx30jun2019_htm.xml     1    NaN
#
# [5 rows x 36 columns]

# %%
raw_tag_data.head()
# Out:
#                         tag      version  custom  abstract   datatype iord  \
# 0         EntityPublicFloat     dei/2014       0         0   monetary    I
# 1   DocumentFiscalYearFocus     dei/2014       0         0      gYear    D
# 2     DocumentPeriodEndDate     dei/2014       0         0       date    D
# 3  CurrentFiscalYearEndDate     dei/2014       0         0  gMonthDay    D
# 4            InvestmentAxis  invest/2013       0         1       axis  NaN
#
#   crdr                        tlabel  \
# 0    C           Entity Public Float
# 1  NaN    Document Fiscal Year Focus
# 2  NaN      Document Period End Date
# 3  NaN  Current Fiscal Year End Date
# 4  NaN             Investment [Axis]
#
#                                                  doc
# 0  State aggregate market value of voting and non...
# 1  This is focus fiscal year of the document repo...
# 2  The end date of the period reflected on the co...
# 3  End date of current fiscal year in the format ...
# 4  A categorization of investments (securities, d...

# %% [markdown]
# ## Clean <a name="Clean"></a>

# %%
pre_data = raw_num_data\
    .filter(['adsh', 'tag', 'version', 'plabel'], axis = 'columns')\
    .drop_duplicates()

# %%
sub_data = raw_sub_data\
    .filter(['adsh', 'cik', 'name', 'sic', 'countryba', 'period', 'form', 'fye', 'accepted', 'instance'], axis = 'columns')\
    .rename(mapper = {'name':'company_name', 'countryba':'country'}, axis = 'columns')\
    .query("form in ['10-Q', '10-K']") # Keep only the quarterly and annual filings

# %%
tag_data = raw_tag_data\
    .filter(['tag', 'version', 'doc'])\
    .drop_duplicates()

# %%
tag_data['doc'][0]
# Out:
# "State aggregate market value of voting and non-voting common equity held by non-affiliates computed by reference to price at which the common equity was last sold, or average bid and asked price of such common equity, as of the last business day of registrant's most recently completed second fiscal quarter. The public float should be reported on the cover page of the registrants form 10K."

# %%
# Get rid of coregister/parent company
# Keep only the balance sheet and single quarter flows

num_data = raw_num_data\
    .drop('footnote', axis = 'columns')\
    .assign(no_coreg = pd.isna(raw_num_data['coreg']))\
    .assign(no_value = pd.isna(raw_num_data['value']))\
    .assign(ddate = pd.to_datetime(raw_num_data['ddate'], format='%Y%m%d', errors = 'coerce'))\
    .query("(no_coreg == True) & (no_value == False) & (qtrs in (0,1)) & (ddate > '2018-01-01')")

# %%
num_data.shape
# Out:
# (1300874, 10)

# %% [markdown]
# See if we have **num_data** observations at the `adsh, tag, ddate` level

# %%
multiple_matches = num_data.groupby(['adsh', 'tag', 'ddate'], as_index = False)\
    .count()\
    .sort_values('value', ascending = False)\
    .query("value > 1")
duplicate_causing_tags = multiple_matches.tag.unique()

# %%
print("%.2f%% tags create duplicates"% round(len(duplicate_causing_tags)/len(num_data.tag.unique())*100,2))
# Out:
# 1.07% tags create duplicates

# %% [markdown]
# Since only a small percent of tags are trouble, we'll just remove them for now.

# %%
num_data = num_data.query("tag not in @duplicate_causing_tags")

# %% [markdown]
# Note for checking: These tags may just be variations of other important tags. Investigate if we're dropping anything important. Needs further investigation during checking process.

# %% [markdown]
# Now, we have unique rows for each `adsh, tag, ddate`.

# %%
multiple_matches = num_data.groupby(['adsh', 'tag', 'ddate'], as_index = False)\
    .count()\
    .sort_values('value', ascending = False)\
    .query("value > 1")
multiple_matches
# Out:
# Empty DataFrame
# Columns: [adsh, tag, ddate, version, coreg, qtrs, uom, value, no_coreg, no_value]
# Index: []

# %% [markdown]
# ## Merge <a name="Merge"></a>

# %%
num_data.columns
# Out:
# Index(['adsh', 'tag', 'version', 'coreg', 'ddate', 'qtrs', 'uom', 'value',
#        'no_coreg', 'no_value'],
#       dtype='object')

# %%
sec_data = num_data.merge(pre_data, on = ['adsh', 'tag', 'version'])\
    .merge(sub_data, on = ['adsh'])\
    .merge(tag_data, on = ['tag', 'version'])

# %%
sec_data
# Out:
#                         adsh  \
# 0       0001766016-19-000005
# 1       0001766016-19-000005
# 2       0001766016-19-000005
# 3       0001477932-19-004237
# 4       0001477932-19-004237
# 5       0001144204-19-038760
# 6       0001144204-19-038760
# 7       0001760965-19-000014
# 8       0001760965-19-000014
# 9       0001760965-19-000014
# 10      0000837465-19-000012
# 11      0000837465-19-000012
# 12      0001616318-19-000067
# 13      0001616318-19-000067
# 14      0000726513-19-000020
# 15      0000726513-19-000020
# 16      0001144204-19-041832
# 17      0001144204-19-041832
# 18      0001730168-19-000118
# 19      0001730168-19-000118
# 20      0001065088-19-000036
# 21      0001065088-19-000036
# 22      0000320193-19-000076
# 23      0000320193-19-000076
# 24      0000051434-19-000028
# 25      0000051434-19-000028
# 26      0000712515-19-000049
# 27      0000712515-19-000049
# 28      0000912463-19-000039
# 29      0000912463-19-000039
# ...                      ...
# 480059  0001493152-19-013158
# 480060  0001493152-19-013158
# 480061  0001493152-19-013158
# 480062  0001493152-19-013158
# 480063  0001493152-19-013161
# 480064  0001493152-19-013161
# 480065  0001493152-19-013161
# 480066  0001493152-19-013161
# 480067  0001493152-19-013161
# 480068  0001493152-19-013161
# 480069  0000899715-19-000127
# 480070  0000899715-19-000127
# 480071  0001214659-19-005855
# 480072  0001214659-19-005855
# 480073  0001214659-19-005855
# 480074  0001214659-19-005855
# 480075  0001214659-19-005855
# 480076  0001214659-19-005855
# 480077  0001214659-19-005855
# 480078  0001214659-19-005855
# 480079  0001214659-19-005855
# 480080  0001214659-19-005855
# 480081  0001214659-19-005855
# 480082  0001214659-19-005855
# 480083  0001214659-19-005855
# 480084  0001214659-19-005855
# 480085  0001214659-19-005855
# 480086  0001214659-19-005855
# 480087  0001214659-19-005855
# 480088  0001214659-19-005855
#
#                                                       tag  \
# 0                      EntityCommonStockSharesOutstanding
# 1                                      OtherAssetsCurrent
# 2                                      OtherAssetsCurrent
# 3                                      OtherAssetsCurrent
# 4                                      OtherAssetsCurrent
# 5                                      OtherAssetsCurrent
# 6                                      OtherAssetsCurrent
# 7                                      OtherAssetsCurrent
# 8                                      OtherAssetsCurrent
# 9                                      OtherAssetsCurrent
# 10                                     OtherAssetsCurrent
# 11                                     OtherAssetsCurrent
# 12                                     OtherAssetsCurrent
# 13                                     OtherAssetsCurrent
# 14                                     OtherAssetsCurrent
# 15                                     OtherAssetsCurrent
# 16                                     OtherAssetsCurrent
# 17                                     OtherAssetsCurrent
# 18                                     OtherAssetsCurrent
# 19                                     OtherAssetsCurrent
# 20                                     OtherAssetsCurrent
# 21                                     OtherAssetsCurrent
# 22                                     OtherAssetsCurrent
# 23                                     OtherAssetsCurrent
# 24                                     OtherAssetsCurrent
# 25                                     OtherAssetsCurrent
# 26                                     OtherAssetsCurrent
# 27                                     OtherAssetsCurrent
# 28                                     OtherAssetsCurrent
# 29                                     OtherAssetsCurrent
# ...                                                   ...
# 480059                     NetAssetsPercentageOfNetAssets
# 480060                     NetAssetsPercentageOfNetAssets
# 480061                            NetAssetsPerCommonShare
# 480062                            NetAssetsPerCommonShare
# 480063              CommonStockSharesIssuedAndOutstanding
# 480064              CommonStockSharesIssuedAndOutstanding
# 480065                     NetAssetsPercentageOfNetAssets
# 480066                     NetAssetsPercentageOfNetAssets
# 480067                            NetAssetsPerCommonShare
# 480068                            NetAssetsPerCommonShare
# 480069           Managementleasingandotherservicesrevenue
# 480070           Managementleasingandotherservicesrevenue
# 480071                    ChangeInNetAssetsFromOperations
# 480072                    ChangeInNetAssetsFromOperations
# 480073          ChangeInNetAssetsFromOperationsPerReceipt
# 480074          ChangeInNetAssetsFromOperationsPerReceipt
# 480075  InvestmentOwnedBalanceContractsIssuableAndOuts...
# 480076  InvestmentOwnedBalanceContractsIssuableAndOuts...
# 480077  InvestmentOwnedBalanceContractsIssuableAndOuts...
# 480078  InvestmentOwnedBalanceContractsIssuableAndOuts...
# 480079  InvestmentOwnedBalanceContractsIssuableAndOuts...
# 480080                     InvestmentOwnedContractsIssued
# 480081                     InvestmentOwnedContractsIssued
# 480082                           NetAssetValuePerContract
# 480083                           NetAssetValuePerContract
# 480084                           NetAssetValuePerContract
# 480085                           NetAssetValuePerContract
# 480086                           NetAssetValuePerContract
# 480087                WeightedAverageNumberOfGoldReceipts
# 480088                WeightedAverageNumberOfGoldReceipts
#
#                      version coreg      ddate  qtrs     uom         value  \
# 0                   dei/2014   NaN 2019-06-30     0  shares  2.071002e+06
# 1               us-gaap/2018   NaN 2019-06-30     0     USD  0.000000e+00
# 2               us-gaap/2018   NaN 2018-12-31     0     USD  0.000000e+00
# 3               us-gaap/2018   NaN 2018-08-31     0     USD  2.589010e+05
# 4               us-gaap/2018   NaN 2019-05-31     0     USD  2.271030e+05
# 5               us-gaap/2018   NaN 2018-12-31     0     USD  1.000000e+03
# 6               us-gaap/2018   NaN 2019-06-30     0     USD  1.000000e+03
# 7               us-gaap/2018   NaN 2019-06-30     0     USD  7.939700e+07
# 8               us-gaap/2018   NaN 2018-12-31     0     USD  5.201400e+07
# 9               us-gaap/2018   NaN 2018-06-30     0     USD  4.520200e+07
# 10              us-gaap/2018   NaN 2019-06-30     0     USD  6.495400e+07
# 11              us-gaap/2018   NaN 2018-12-31     0     USD  5.078100e+07
# 12              us-gaap/2018   NaN 2019-03-31     0     USD  2.118000e+07
# 13              us-gaap/2018   NaN 2019-06-30     0     USD  2.367800e+07
# 14              us-gaap/2018   NaN 2019-06-30     0     USD  8.865000e+06
# 15              us-gaap/2018   NaN 2018-12-31     0     USD  7.509000e+06
# 16              us-gaap/2018   NaN 2018-06-30     0     USD  2.238100e+07
# 17              us-gaap/2018   NaN 2019-06-30     0     USD  2.724500e+07
# 18              us-gaap/2018   NaN 2019-07-31     0     USD  8.060000e+08
# 19              us-gaap/2018   NaN 2018-10-31     0     USD  3.660000e+08
# 20              us-gaap/2018   NaN 2019-06-30     0     USD  1.570000e+09
# 21              us-gaap/2018   NaN 2018-12-31     0     USD  1.499000e+09
# 22              us-gaap/2018   NaN 2018-09-30     0     USD  1.208700e+10
# 23              us-gaap/2018   NaN 2019-06-30     0     USD  1.053000e+10
# 24              us-gaap/2018   NaN 2019-06-30     0     USD  2.150000e+08
# 25              us-gaap/2018   NaN 2018-12-31     0     USD  2.500000e+08
# 26              us-gaap/2018   NaN 2019-06-30     0     USD  2.840000e+08
# 27              us-gaap/2018   NaN 2019-03-31     0     USD  3.130000e+08
# 28              us-gaap/2018   NaN 2019-01-31     0     USD  8.734300e+07
# 29              us-gaap/2018   NaN 2019-07-31     0     USD  5.922600e+07
# ...                      ...   ...        ...   ...     ...           ...
# 480059  0001493152-19-013158   NaN 2018-06-30     0    pure  1.000000e+00
# 480060  0001493152-19-013158   NaN 2019-06-30     0    pure  1.000000e+00
# 480061  0001493152-19-013158   NaN 2018-06-30     0     USD  1.248000e+01
# 480062  0001493152-19-013158   NaN 2019-06-30     0     USD  1.404000e+01
# 480063  0001493152-19-013161   NaN 2018-06-30     0  shares  4.500000e+05
# 480064  0001493152-19-013161   NaN 2019-06-30     0  shares  4.500000e+05
# 480065  0001493152-19-013161   NaN 2018-06-30     0    pure  1.000000e+00
# 480066  0001493152-19-013161   NaN 2019-06-30     0    pure  1.000000e+00
# 480067  0001493152-19-013161   NaN 2018-06-30     0     USD  8.490000e+00
# 480068  0001493152-19-013161   NaN 2019-06-30     0     USD  8.120000e+00
# 480069  0000899715-19-000127   NaN 2019-06-30     1     USD  1.245000e+06
# 480070  0000899715-19-000127   NaN 2018-06-30     1     USD  1.142000e+06
# 480071  0001214659-19-005855   NaN 2018-07-31     1     USD -3.314476e+07
# 480072  0001214659-19-005855   NaN 2019-07-31     1     USD  2.227392e+07
# 480073  0001214659-19-005855   NaN 2018-07-31     1    pure -1.032900e+02
# 480074  0001214659-19-005855   NaN 2019-07-31     1    pure  1.452500e+02
# 480075  0001214659-19-005855   NaN 2018-04-30     0    pure  2.098480e+05
# 480076  0001214659-19-005855   NaN 2018-07-31     0    pure  3.425360e+05
# 480077  0001214659-19-005855   NaN 2018-10-31     0    pure  1.533040e+05
# 480078  0001214659-19-005855   NaN 2019-04-30     0    pure  1.533460e+05
# 480079  0001214659-19-005855   NaN 2019-07-31     0    pure  1.533560e+05
# 480080  0001214659-19-005855   NaN 2018-07-31     1    pure  1.326880e+05
# 480081  0001214659-19-005855   NaN 2019-07-31     1    pure  1.000000e+01
# 480082  0001214659-19-005855   NaN 2018-04-30     0    pure  1.313200e+03
# 480083  0001214659-19-005855   NaN 2018-07-31     0    pure  1.220950e+03
# 480084  0001214659-19-005855   NaN 2018-10-31     0    pure  1.214950e+03
# 480085  0001214659-19-005855   NaN 2019-04-30     0    pure  1.282300e+03
# 480086  0001214659-19-005855   NaN 2019-07-31     0    pure  1.427550e+03
# 480087  0001214659-19-005855   NaN 2018-07-31     1    pure  3.209020e+05
# 480088  0001214659-19-005855   NaN 2019-07-31     1    pure  1.533480e+05
#
#         no_coreg  no_value      cik                        company_name  \
# 0           True     False  1766016          CRUCIAL INNOVATIONS, CORP.
# 1           True     False  1766016          CRUCIAL INNOVATIONS, CORP.
# 2           True     False  1766016          CRUCIAL INNOVATIONS, CORP.
# 3           True     False  1675634                     SHIFTPIXY, INC.
# 4           True     False  1675634                     SHIFTPIXY, INC.
# 5           True     False  1211583         FENNEC PHARMACEUTICALS INC.
# 6           True     False  1211583         FENNEC PHARMACEUTICALS INC.
# 7           True     False  1760965                KONTOOR BRANDS, INC.
# 8           True     False  1760965                KONTOOR BRANDS, INC.
# 9           True     False  1760965                KONTOOR BRANDS, INC.
# 10          True     False   837465                    CALLAWAY GOLF CO
# 11          True     False   837465                    CALLAWAY GOLF CO
# 12          True     False  1616318                  VISTA OUTDOOR INC.
# 13          True     False  1616318                  VISTA OUTDOOR INC.
# 14          True     False   726513                    TRIBUNE MEDIA CO
# 15          True     False   726513                    TRIBUNE MEDIA CO
# 16          True     False  1069899           PHIBRO ANIMAL HEALTH CORP
# 17          True     False  1069899           PHIBRO ANIMAL HEALTH CORP
# 18          True     False  1730168                       BROADCOM INC.
# 19          True     False  1730168                       BROADCOM INC.
# 20          True     False  1065088                            EBAY INC
# 21          True     False  1065088                            EBAY INC
# 22          True     False   320193                           APPLE INC
# 23          True     False   320193                           APPLE INC
# 24          True     False    51434        INTERNATIONAL PAPER CO /NEW/
# 25          True     False    51434        INTERNATIONAL PAPER CO /NEW/
# 26          True     False   712515                ELECTRONIC ARTS INC.
# 27          True     False   712515                ELECTRONIC ARTS INC.
# 28          True     False   912463                           GUESS INC
# 29          True     False   912463                           GUESS INC
# ...          ...       ...      ...                                 ...
# 480059      True     False  1690437            GRANITESHARES GOLD TRUST
# 480060      True     False  1690437            GRANITESHARES GOLD TRUST
# 480061      True     False  1690437            GRANITESHARES GOLD TRUST
# 480062      True     False  1690437            GRANITESHARES GOLD TRUST
# 480063      True     False  1690842        GRANITESHARES PLATINUM TRUST
# 480064      True     False  1690842        GRANITESHARES PLATINUM TRUST
# 480065      True     False  1690842        GRANITESHARES PLATINUM TRUST
# 480066      True     False  1690842        GRANITESHARES PLATINUM TRUST
# 480067      True     False  1690842        GRANITESHARES PLATINUM TRUST
# 480068      True     False  1690842        GRANITESHARES PLATINUM TRUST
# 480069      True     False   899715  TANGER FACTORY OUTLET CENTERS, INC
# 480070      True     False   899715  TANGER FACTORY OUTLET CENTERS, INC
# 480071      True     False  1593812          VAULTED GOLD BULLION TRUST
# 480072      True     False  1593812          VAULTED GOLD BULLION TRUST
# 480073      True     False  1593812          VAULTED GOLD BULLION TRUST
# 480074      True     False  1593812          VAULTED GOLD BULLION TRUST
# 480075      True     False  1593812          VAULTED GOLD BULLION TRUST
# 480076      True     False  1593812          VAULTED GOLD BULLION TRUST
# 480077      True     False  1593812          VAULTED GOLD BULLION TRUST
# 480078      True     False  1593812          VAULTED GOLD BULLION TRUST
# 480079      True     False  1593812          VAULTED GOLD BULLION TRUST
# 480080      True     False  1593812          VAULTED GOLD BULLION TRUST
# 480081      True     False  1593812          VAULTED GOLD BULLION TRUST
# 480082      True     False  1593812          VAULTED GOLD BULLION TRUST
# 480083      True     False  1593812          VAULTED GOLD BULLION TRUST
# 480084      True     False  1593812          VAULTED GOLD BULLION TRUST
# 480085      True     False  1593812          VAULTED GOLD BULLION TRUST
# 480086      True     False  1593812          VAULTED GOLD BULLION TRUST
# 480087      True     False  1593812          VAULTED GOLD BULLION TRUST
# 480088      True     False  1593812          VAULTED GOLD BULLION TRUST
#
#            sic country    period  form     fye               accepted  \
# 0       8200.0      CN  20190630  10-Q  1231.0  2019-07-19 18:35:00.0
# 1       8200.0      CN  20190630  10-Q  1231.0  2019-07-19 18:35:00.0
# 2       8200.0      CN  20190630  10-Q  1231.0  2019-07-19 18:35:00.0
# 3       7361.0      US  20190531  10-Q   831.0  2019-07-22 14:13:00.0
# 4       7361.0      US  20190531  10-Q   831.0  2019-07-22 14:13:00.0
# 5       2836.0      US  20190630  10-Q  1231.0  2019-08-09 11:20:00.0
# 6       2836.0      US  20190630  10-Q  1231.0  2019-08-09 11:20:00.0
# 7       2320.0      US  20190630  10-Q  1231.0  2019-08-13 16:54:00.0
# 8       2320.0      US  20190630  10-Q  1231.0  2019-08-13 16:54:00.0
# 9       2320.0      US  20190630  10-Q  1231.0  2019-08-13 16:54:00.0
# 10      3949.0      US  20190630  10-Q  1231.0  2019-08-09 14:30:00.0
# 11      3949.0      US  20190630  10-Q  1231.0  2019-08-09 14:30:00.0
# 12      3480.0      US  20190630  10-Q   331.0  2019-08-08 16:11:00.0
# 13      3480.0      US  20190630  10-Q   331.0  2019-08-08 16:11:00.0
# 14      4833.0      US  20190630  10-Q  1231.0  2019-08-09 07:38:00.0
# 15      4833.0      US  20190630  10-Q  1231.0  2019-08-09 07:38:00.0
# 16      2834.0      US  20190630  10-K   630.0  2019-08-27 16:07:00.0
# 17      2834.0      US  20190630  10-K   630.0  2019-08-27 16:07:00.0
# 18      3674.0      US  20190731  10-Q  1031.0  2019-09-13 16:39:00.0
# 19      3674.0      US  20190731  10-Q  1031.0  2019-09-13 16:39:00.0
# 20      7389.0      US  20190630  10-Q  1231.0  2019-07-18 16:20:00.0
# 21      7389.0      US  20190630  10-Q  1231.0  2019-07-18 16:20:00.0
# 22      3571.0      US  20190630  10-Q   930.0  2019-07-31 16:32:00.0
# 23      3571.0      US  20190630  10-Q   930.0  2019-07-31 16:32:00.0
# 24      2621.0      US  20190630  10-Q  1231.0  2019-07-31 15:54:00.0
# 25      2621.0      US  20190630  10-Q  1231.0  2019-07-31 15:54:00.0
# 26      7372.0      US  20190630  10-Q   331.0  2019-08-06 16:18:00.0
# 27      7372.0      US  20190630  10-Q   331.0  2019-08-06 16:18:00.0
# 28      2340.0      US  20190731  10-Q   131.0  2019-09-05 16:27:00.0
# 29      2340.0      US  20190731  10-Q   131.0  2019-09-05 16:27:00.0
# ...        ...     ...       ...   ...     ...                    ...
# 480059  6799.0      US  20190630  10-K   630.0  2019-08-20 17:15:00.0
# 480060  6799.0      US  20190630  10-K   630.0  2019-08-20 17:15:00.0
# 480061  6799.0      US  20190630  10-K   630.0  2019-08-20 17:15:00.0
# 480062  6799.0      US  20190630  10-K   630.0  2019-08-20 17:15:00.0
# 480063  6221.0      US  20190630  10-K   630.0  2019-08-20 17:20:00.0
# 480064  6221.0      US  20190630  10-K   630.0  2019-08-20 17:20:00.0
# 480065  6221.0      US  20190630  10-K   630.0  2019-08-20 17:20:00.0
# 480066  6221.0      US  20190630  10-K   630.0  2019-08-20 17:20:00.0
# 480067  6221.0      US  20190630  10-K   630.0  2019-08-20 17:20:00.0
# 480068  6221.0      US  20190630  10-K   630.0  2019-08-20 17:20:00.0
# 480069  6798.0      US  20190630  10-Q  1231.0  2019-08-05 16:24:00.0
# 480070  6798.0      US  20190630  10-Q  1231.0  2019-08-05 16:24:00.0
# 480071  6221.0      CA  20190731  10-Q  1031.0  2019-09-13 16:16:00.0
# 480072  6221.0      CA  20190731  10-Q  1031.0  2019-09-13 16:16:00.0
# 480073  6221.0      CA  20190731  10-Q  1031.0  2019-09-13 16:16:00.0
# 480074  6221.0      CA  20190731  10-Q  1031.0  2019-09-13 16:16:00.0
# 480075  6221.0      CA  20190731  10-Q  1031.0  2019-09-13 16:16:00.0
# 480076  6221.0      CA  20190731  10-Q  1031.0  2019-09-13 16:16:00.0
# 480077  6221.0      CA  20190731  10-Q  1031.0  2019-09-13 16:16:00.0
# 480078  6221.0      CA  20190731  10-Q  1031.0  2019-09-13 16:16:00.0
# 480079  6221.0      CA  20190731  10-Q  1031.0  2019-09-13 16:16:00.0
# 480080  6221.0      CA  20190731  10-Q  1031.0  2019-09-13 16:16:00.0
# 480081  6221.0      CA  20190731  10-Q  1031.0  2019-09-13 16:16:00.0
# 480082  6221.0      CA  20190731  10-Q  1031.0  2019-09-13 16:16:00.0
# 480083  6221.0      CA  20190731  10-Q  1031.0  2019-09-13 16:16:00.0
# 480084  6221.0      CA  20190731  10-Q  1031.0  2019-09-13 16:16:00.0
# 480085  6221.0      CA  20190731  10-Q  1031.0  2019-09-13 16:16:00.0
# 480086  6221.0      CA  20190731  10-Q  1031.0  2019-09-13 16:16:00.0
# 480087  6221.0      CA  20190731  10-Q  1031.0  2019-09-13 16:16:00.0
# 480088  6221.0      CA  20190731  10-Q  1031.0  2019-09-13 16:16:00.0
#
#                               instance  \
# 0                    none-20190630.xml
# 1                    none-20190630.xml
# 2                    none-20190630.xml
# 3                    pixy-20190531.xml
# 4                    pixy-20190531.xml
# 5                   fencf-20190630.xml
# 6                   fencf-20190630.xml
# 7                ktbq2201910-q_htm.xml
# 8                ktbq2201910-q_htm.xml
# 9                ktbq2201910-q_htm.xml
# 10             ely-2019630x10q_htm.xml
# 11             ely-2019630x10q_htm.xml
# 12            vsto-0630201910q_htm.xml
# 13            vsto-0630201910q_htm.xml
# 14                 a10-qq22019_htm.xml
# 15                 a10-qq22019_htm.xml
# 16                   pahc-20190630.xml
# 17                   pahc-20190630.xml
# 18           avgo-08042019x10q_htm.xml
# 19           avgo-08042019x10q_htm.xml
# 20              ebay10-qq22019_htm.xml
# 21              ebay10-qq22019_htm.xml
# 22          a10-qq320196292019_htm.xml
# 23          a10-qq320196292019_htm.xml
# 24         ip-6302019xform10xq_htm.xml
# 25         ip-6302019xform10xq_htm.xml
# 26      ea6302019-q1fy2010qdoc_htm.xml
# 27      ea6302019-q1fy2010qdoc_htm.xml
# 28           a10q-20190803xges_htm.xml
# 29           a10q-20190803xges_htm.xml
# ...                                ...
# 480059                bar-20190630.xml
# 480060                bar-20190630.xml
# 480061                bar-20190630.xml
# 480062                bar-20190630.xml
# 480063               pltm-20190630.xml
# 480064               pltm-20190630.xml
# 480065               pltm-20190630.xml
# 480066               pltm-20190630.xml
# 480067               pltm-20190630.xml
# 480068               pltm-20190630.xml
# 480069           skt10q6302019_htm.xml
# 480070           skt10q6302019_htm.xml
# 480071               vgbt-20190731.xml
# 480072               vgbt-20190731.xml
# 480073               vgbt-20190731.xml
# 480074               vgbt-20190731.xml
# 480075               vgbt-20190731.xml
# 480076               vgbt-20190731.xml
# 480077               vgbt-20190731.xml
# 480078               vgbt-20190731.xml
# 480079               vgbt-20190731.xml
# 480080               vgbt-20190731.xml
# 480081               vgbt-20190731.xml
# 480082               vgbt-20190731.xml
# 480083               vgbt-20190731.xml
# 480084               vgbt-20190731.xml
# 480085               vgbt-20190731.xml
# 480086               vgbt-20190731.xml
# 480087               vgbt-20190731.xml
# 480088               vgbt-20190731.xml
#
#                                                       doc
# 0       Indicate number of shares or other units outst...
# 1           Amount of current assets classified as other.
# 2           Amount of current assets classified as other.
# 3           Amount of current assets classified as other.
# 4           Amount of current assets classified as other.
# 5           Amount of current assets classified as other.
# 6           Amount of current assets classified as other.
# 7           Amount of current assets classified as other.
# 8           Amount of current assets classified as other.
# 9           Amount of current assets classified as other.
# 10          Amount of current assets classified as other.
# 11          Amount of current assets classified as other.
# 12          Amount of current assets classified as other.
# 13          Amount of current assets classified as other.
# 14          Amount of current assets classified as other.
# 15          Amount of current assets classified as other.
# 16          Amount of current assets classified as other.
# 17          Amount of current assets classified as other.
# 18          Amount of current assets classified as other.
# 19          Amount of current assets classified as other.
# 20          Amount of current assets classified as other.
# 21          Amount of current assets classified as other.
# 22          Amount of current assets classified as other.
# 23          Amount of current assets classified as other.
# 24          Amount of current assets classified as other.
# 25          Amount of current assets classified as other.
# 26          Amount of current assets classified as other.
# 27          Amount of current assets classified as other.
# 28          Amount of current assets classified as other.
# 29          Amount of current assets classified as other.
# ...                                                   ...
# 480059        The percentage of net assets of net assets.
# 480060        The percentage of net assets of net assets.
# 480061  Carrying asset value per common unit ("share")...
# 480062  Carrying asset value per common unit ("share")...
# 480063  Total number of common shares of an entity tha...
# 480064  Total number of common shares of an entity tha...
# 480065        The percentage of net assets of net assets.
# 480066        The percentage of net assets of net assets.
# 480067  Carrying asset value per common unit ("share")...
# 480068  Carrying asset value per common unit ("share")...
# 480069  The net management, leasing and other services...
# 480070  The net management, leasing and other services...
# 480071  The change in net assets from operations durin...
# 480072  The change in net assets from operations durin...
# 480073  The change in net assets from operations per r...
# 480074  The change in net assets from operations per r...
# 480075  The sum of the balance held at close of period...
# 480076  The sum of the balance held at close of period...
# 480077  The sum of the balance held at close of period...
# 480078  The sum of the balance held at close of period...
# 480079  The sum of the balance held at close of period...
# 480080  For investment companies, the number of contra...
# 480081  For investment companies, the number of contra...
# 480082  The net asset value per contract (receipt) for...
# 480083  The net asset value per contract (receipt) for...
# 480084  The net asset value per contract (receipt) for...
# 480085  The net asset value per contract (receipt) for...
# 480086  The net asset value per contract (receipt) for...
# 480087          Weighted average number of gold receipts.
# 480088          Weighted average number of gold receipts.
#
# [480089 rows x 20 columns]

# %% [markdown]
# ## Save <a name="Save"></a>
# Create CSV versions in build/raw

# %%
sec_data.to_csv(data_root+'02-build/clean/2019q3/sec_data_long.csv')
