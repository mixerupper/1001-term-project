# %% [markdown]
# # Program Header

# %%
import pandas as pd
import os
import sys
nb_dir = os.path.split(os.getcwd())[0]
if nb_dir not in sys.path:
    sys.path.append(nb_dir)
from header import *
initialize_data_root("AY")
# Out:
# 'Initialized data root'

# %% [markdown]
# # Table of contents
# 1. [Import](#Import)
# 2. [Inspect](#Inspect)
# 3. [Save](#Save)

# %% [markdown]
# ## Import <a name="Import"></a>

# %%
raw_num_data = pd.read_csv(header.data_root+'02-build/raw/2019q3/num.csv')
raw_pre_data = pd.read_csv(header.data_root+'02-build/raw/2019q3/pre.csv')
raw_sub_data = pd.read_csv(header.data_root+'02-build/raw/2019q3/sub.csv')
raw_tag_data = pd.read_csv(header.data_root+'02-build/raw/2019q3/tag.csv')

# %% [markdown]
# ## Data Understanding <a name="Data Understanding"></a>

# %% [markdown]
# Given in readme.txt:
# * **num**: Numeric data and actual values associated to `adsh-ddate-tag-etc`. All columns are relevant
# * **pre**: Location of tags and a preferred label (`plabel`). `plabel` (and joining columns) seems relevant
# * **sub**: Summary information about submission. Business-specific information including industry and company name are relevant
# * **tag**: Tag-level dataset. `doc` seems to be a more descriptive `plabel` from **pre** dataset

# %%
raw_num_data.head()
# Out:
#    Unnamed: 0                  adsh                                  tag  \
# 0           0  0001625376-19-000017                    EntityPublicFloat
# 1           1  0000034563-19-000064  DerivativeNonmonetaryNotionalAmount
# 2           2  0000034563-19-000064  DerivativeNonmonetaryNotionalAmount
# 3           3  0001370946-19-000033  DerivativeNonmonetaryNotionalAmount
# 4           4  0000225648-19-000108  DerivativeNonmonetaryNotionalAmount
#
#        version coreg     ddate  qtrs    uom       value footnote
# 0     dei/2014   NaN  20180430     0    USD         0.0      NaN
# 1  invest/2013   NaN  20190630     0     lb  48183000.0      NaN
# 2  invest/2013   NaN  20180630     0     lb  43459000.0      NaN
# 3  invest/2013   NaN  20190630     0  MMBTU         2.0      NaN
# 4  invest/2013   NaN  20190630     0     MW   4300000.0      NaN

# %%
raw_pre_data.head()
# Out:
#    Unnamed: 0                  adsh  report  line stmt  inpth rfile  \
# 0           0  0001625376-19-000017       1     9   CP      0     H
# 1           1  0001625376-19-000017       1    14   CP      0     H
# 2           2  0001625376-19-000019       1    11   CP      0     H
# 3           3  0001766016-19-000005       1    10   CP      0     H
# 4           4  0001047469-19-004442       1     6   CP      0     H
#
#                        tag   version                      plabel  negating
# 0        EntityPublicFloat  dei/2014         Entity Public Float         0
# 1  DocumentFiscalYearFocus  dei/2014  Document Fiscal Year Focus         0
# 2  DocumentFiscalYearFocus  dei/2014  Document Fiscal Year Focus         0
# 3  DocumentFiscalYearFocus  dei/2014  Document Fiscal Year Focus         0
# 4  DocumentFiscalYearFocus  dei/2014  Document Fiscal Year Focus         0

# %%
raw_sub_data.head()
# Out:
#    Unnamed: 0                  adsh   cik                               name  \
# 0           0  0000002178-19-000086  2178     ADAMS RESOURCES & ENERGY, INC.
# 1           1  0000002488-19-000104  2488         ADVANCED MICRO DEVICES INC
# 2           2  0000002488-19-000113  2488         ADVANCED MICRO DEVICES INC
# 3           3  0000002488-19-000144  2488         ADVANCED MICRO DEVICES INC
# 4           4  0000002969-19-000042  2969  AIR PRODUCTS & CHEMICALS INC /DE/
#
#       sic countryba stprba       cityba       zipba                    bas1  \
# 0  5172.0        US     TX      HOUSTON       77027  17 S. BRIAR HOLLOW LN.
# 1  3674.0        US     CA  SANTA CLARA       95054    2485 AUGUSTINE DRIVE
# 2  3674.0        US     CA  SANTA CLARA       95054    2485 AUGUSTINE DRIVE
# 3  3674.0        US     CA  SANTA CLARA       95054    2485 AUGUSTINE DRIVE
# 4  2810.0        US     PA    ALLENTOWN  18195-1501      7201 HAMILTON BLVD
#
# ...

# %%
raw_tag_data.head()
# Out:
#    Unnamed: 0                       tag      version  custom  abstract  \
# 0           0         EntityPublicFloat     dei/2014       0         0
# 1           1   DocumentFiscalYearFocus     dei/2014       0         0
# 2           2     DocumentPeriodEndDate     dei/2014       0         0
# 3           3  CurrentFiscalYearEndDate     dei/2014       0         0
# 4           4            InvestmentAxis  invest/2013       0         1
#
#     datatype iord crdr                        tlabel  \
# 0   monetary    I    C           Entity Public Float
# 1      gYear    D  NaN    Document Fiscal Year Focus
# 2       date    D  NaN      Document Period End Date
# 3  gMonthDay    D  NaN  Current Fiscal Year End Date
# 4       axis  NaN  NaN             Investment [Axis]
#
#                                                  doc
# 0  State aggregate market value of voting and non...
# 1  This is focus fiscal year of the document repo...
# 2  The end date of the period reflected on the co...
# ...

# %% [markdown]
# ## Clean <a name="Clean"></a>

# %%
num_data = raw_num_data.copy()\
    .drop()

# %% [markdown]
# ## Merge <a name="Merge"></a>

# %%
sec_data = pd.merge(num_data, pre_data)

# %% [markdown]
# ## Save <a name="Save"></a>
# Create CSV versions in build/raw

# %%
num_data.to_csv(data_root+'/02-build/raw/201903/num_data.csv')
pre_data.to_csv(data_root+'/02-build/raw/201903/pre_data.csv')
sub_data.to_csv(data_root+'/02-build/raw/201903/sub_data.csv')
tag_data.to_csv(data_root+'/02-build/raw/201903/tag_data.csv')
