# %%
import pandas as pd
import numpy as np
import os
import sys
nb_dir = os.path.split(os.getcwd())[0]
if nb_dir not in sys.path:
    sys.path.append(nb_dir)
from header import *

# %%
data_root = initialize_data_root("AH")

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn import preprocessing
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import linear_model
from sklearn.neural_network import MLPClassifier

from sklearn.metrics import mean_squared_error, r2_score


from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold

from sklearn.metrics import roc_curve, auc

import matplotlib.pyplot as plt

# %% [markdown]
# ## Import

# %%
q3mergeddata = pd.read_csv(data_root + '02-build/clean/2019q3/q32019imputeddata.csv')

# %% [markdown]
# ## Interaction Term

# %%
q3mergeddata['Clean_Number_of_Shares'] =q3mergeddata[['WeightedAverageNumberOfDilutedSharesOutstanding',
       'WeightedAverageNumberOfSharesOutstandingBasic']].max(axis = 1)

q3mergeddata['Clean_Number_of_Shares'] = q3mergeddata[['Clean_Number_of_Shares',
                                                       'CommonStockSharesOutstanding']].max(axis = 1)

q3mergeddata['Company_Value'] = q3mergeddata['Clean_Number_of_Shares'] * q3mergeddata['7_after']
q3mergeddata = q3mergeddata.drop(q3mergeddata[q3mergeddata.Company_Value == 0].index)
q3mergeddata = q3mergeddata.drop(['CommonStockSharesOutstanding','WeightedAverageNumberOfDilutedSharesOutstanding','WeightedAverageNumberOfSharesOutstandingBasic' ], axis = 1)
q3mergeddata['Company_Size'] = np.where(q3mergeddata['Company_Value'] > 5000000000, 1, 0)


q3mergeddata_it = q3mergeddata.copy().loc[q3mergeddata.StockholdersEquity != 0 ]



for i in q3mergeddata_it.columns[11:len(q3mergeddata_it.columns) - 17]:
    q3mergeddata_it[i + '_it'] = q3mergeddata_it[i]/q3mergeddata_it.StockholdersEquity

q3mergeddata_it = q3mergeddata_it.drop(['7_before', '7_after', 'difference', 'per', 'Clean_Number_of_Shares', 'Company_Value', 'Company_Size'], axis = 1)

q3mergeddata_it.reset_index()
interaction_term_processed = pd.DataFrame(preprocessing.scale(q3mergeddata_it[q3mergeddata_it.columns[11:]]), columns = q3mergeddata_it.columns[11:])
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:172: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn("Numerical issues were encountered "

# %%
X = pd.DataFrame(interaction_term_processed.copy())
Y = pd.DataFrame(q3mergeddata.loc[q3mergeddata.StockholdersEquity != 0 ]['Company_Size'].copy())

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.30)

logreg = LogisticRegression()
logreg.fit(X_train, np.ravel(Y_train))

log_decision = logreg.decision_function(X_test)
log_fpr, log_tpr, _  = roc_curve(Y_test, log_decision)

log_auc = auc(log_fpr, log_tpr)

lin_svm = SVC(kernel = 'linear')
lin_svm.fit(X_train, np.ravel(Y_train))

svm_decision = lin_svm.decision_function(X_test)
svm_fpr, svm_tpr, _  = roc_curve(Y_test, svm_decision)

svm_auc = auc(svm_fpr, svm_tpr)

plt.figure(figsize = (7, 7))
plt.plot(log_fpr, log_tpr, label = 'Logistic AUC for Imputed Data:'+"{0:.4f}".format(log_auc))
plt.plot(svm_fpr, svm_tpr, label = 'SVM AUC for Imputed Data:'+"{0:.4f}".format(svm_auc))
plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Imputed Data')
plt.legend(loc="lower right")
plt.savefig(data_root+'Imputed Data Logistic SVM ROC.png')
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
X_dt = pd.DataFrame(interaction_term_processed.copy())
Y_dt = pd.DataFrame(q3mergeddata.copy().loc[q3mergeddata.StockholdersEquity != 0 ]['Company_Size'].copy())

X_train, X_test, Y_train, Y_test = train_test_split(X_dt,Y_dt, test_size = 0.30)

dt = DecisionTreeClassifier(criterion = 'entropy')
dt.fit(X_train, Y_train)

importance = dt.feature_importances_
indices = np.argsort(importance)

plt.figure(figsize=(10,5))
plt.title("Feature Importance for Imputed Data")
plt.bar(X_train.columns[indices][- 10:], importance[indices][- 10:], 
        color = 'b', align = 'center')
plt.xticks(range(10), X.columns[indices][-10:], rotation = 90)
plt.xlim([-1, 10])
plt.savefig(data_root + 'Imputed Data Decision Tree Feature Importance.png')

# %%
dt.score(X_test, Y_test)
# Out:
# 0.9535315985130112

# %% [markdown]
# ## No Interaction terms rerun import before doing any of this

# %%
q3mergeddata['Clean_Number_of_Shares'] = q3mergeddata[['WeightedAverageNumberOfDilutedSharesOutstanding',
       'WeightedAverageNumberOfSharesOutstandingBasic']].max(axis = 1)

q3mergeddata['Clean_Number_of_Shares'] = q3mergeddata[['Clean_Number_of_Shares',
                                                       'CommonStockSharesOutstanding']].max(axis = 1)

q3mergeddata['Company_Value'] = q3mergeddata['Clean_Number_of_Shares'] * q3mergeddata['7_after']
q3mergeddata = q3mergeddata.drop(q3mergeddata[q3mergeddata.Company_Value == 0].index)
q3mergeddata = q3mergeddata.drop(['CommonStockSharesOutstanding','WeightedAverageNumberOfDilutedSharesOutstanding','WeightedAverageNumberOfSharesOutstandingBasic' ], axis = 1)
q3mergeddata['Company_Size'] = np.where(q3mergeddata['Company_Value'] > 5000000000, 1, 0)

# %%
q3mergeddata_processed  = pd.DataFrame(preprocessing.scale(q3mergeddata[q3mergeddata.columns[11:len(q3mergeddata.columns) - 7]]), columns =q3mergeddata.columns[11:len(q3mergeddata.columns) - 7] )
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:172: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn("Numerical issues were encountered "

# %%
X = pd.DataFrame(q3mergeddata_processed.copy())
Y = pd.DataFrame(q3mergeddata['Company_Size'].copy())

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.30)

# %%
logreg = LogisticRegression()
logreg.fit(X_train, np.ravel(Y_train))

log_decision = logreg.decision_function(X_test)
log_fpr, log_tpr, _  = roc_curve(Y_test, log_decision)

log_auc = auc(log_fpr, log_tpr)

lin_svm = SVC(kernel = 'linear')
lin_svm.fit(X_train, np.ravel(Y_train))

svm_decision = lin_svm.decision_function(X_test)
svm_fpr, svm_tpr, _  = roc_curve(Y_test, svm_decision)

svm_auc = auc(svm_fpr, svm_tpr)
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
plt.figure(figsize = (10, 10))
plt.plot(log_fpr, log_tpr, label = 'Logistic AUC for Imputed Data:'+"{0:.4f}".format(log_auc))
plt.plot(svm_fpr, svm_tpr, label = 'SVM AUC for Imputed Data:'+"{0:.4f}".format(svm_auc))
plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Imputed Data Logistic SVM ROC')
plt.legend(loc="lower right")
plt.savefig(data_root+'Imputed Data Logistic SVM ROC.png')

# %%
X_dt = pd.DataFrame(q3mergeddata_processed.copy())
Y_dt = pd.DataFrame(q3mergeddata['Company_Size'].copy())

X_train, X_test, Y_train, Y_test = train_test_split(X_dt,Y_dt, test_size = 0.30)

dt = DecisionTreeClassifier(criterion = 'entropy')
dt.fit(X_train, Y_train)

importance = dt.feature_importances_
indices = np.argsort(importance)

plt.figure(figsize=(10,10))
plt.title("Feature Importance")
plt.bar(X_train.columns[indices][- 10:], importance[indices][- 10:], 
        color = 'b', align = 'center')
plt.xticks(range(10), X.columns[indices][-10:], rotation = 90)
plt.xlim([-1, 10])
plt.tight_layout()
plt.savefig(data_root + 'Imputed Data Decision Tree Feature Importance.png')

# %% [markdown]
# ## Nonbinary Company Size

# %%
q3mergeddata['Clean_Number_of_Shares'] = q3mergeddata[['WeightedAverageNumberOfDilutedSharesOutstanding',
       'WeightedAverageNumberOfSharesOutstandingBasic']].max(axis = 1)

q3mergeddata['Clean_Number_of_Shares'] = q3mergeddata[['Clean_Number_of_Shares',
                                                       'CommonStockSharesOutstanding']].max(axis = 1)

q3mergeddata['Company_Value'] = q3mergeddata['Clean_Number_of_Shares'] * q3mergeddata['7_after']
q3mergeddata = q3mergeddata.drop(q3mergeddata[q3mergeddata.Company_Value == 0].index)
q3mergeddata = q3mergeddata.drop(['CommonStockSharesOutstanding','WeightedAverageNumberOfDilutedSharesOutstanding','WeightedAverageNumberOfSharesOutstandingBasic' ], axis = 1)
q3mergeddata['Company_Size_1'] = np.where(q3mergeddata['Company_Value'] <= 2000000000, 1, 0)
q3mergeddata['Company_Size_2'] = np.where(q3mergeddata['Company_Value'] >= 5000000000, 2, 1)
q3mergeddata['Company_Size'] = q3mergeddata['Company_Size_2'] - q3mergeddata['Company_Size_1']

q3mergeddata = q3mergeddata.drop(['Company_Size_1','Company_Size_2'], axis = 1)

q3mergeddata_processed  = pd.DataFrame(preprocessing.scale(q3mergeddata[q3mergeddata.columns[11:len(q3mergeddata.columns) - 7]]), columns =q3mergeddata.columns[11:len(q3mergeddata.columns) - 7] )
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:172: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn("Numerical issues were encountered "

# %%
X_dt = pd.DataFrame(q3mergeddata_processed.copy())
Y_dt = pd.DataFrame(q3mergeddata['Company_Size'].copy())

X_train, X_test, Y_train, Y_test = train_test_split(X_dt,Y_dt, test_size = 0.30)

dt = DecisionTreeClassifier(criterion = 'entropy')
dt.fit(X_train, Y_train)

importance = dt.feature_importances_
indices = np.argsort(importance)

plt.figure(figsize=(10,10))
plt.tight_layout()
plt.title("Feature Importance in Classifying between Small/Medium/Large Companies with Imputed Data")
plt.bar(X_train.columns[indices][- 10:], importance[indices][- 10:], 
        color = 'b', align = 'center')
plt.xticks(range(10), X.columns[indices][-10:], rotation = 90)
plt.xlim([-1, 10])
plt.tight_layout()
plt.savefig(data_root + 'Nonbinary Decision Tree Classification Imputed Data.png')

# %%
dt.score(X_test, Y_test)
# Out:
# 0.7082953509571559

# %% [markdown]
# ## Random Forest

# %%
clf = RandomForestClassifier(criterion = 'entropy')
clf.fit(X_train, np.ravel(Y_train))
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
importance = clf.feature_importances_
indices = np.argsort(importance)

plt.figure(figsize=(10,10))
plt.title("Random Forest Feature Importance in Classifying between Small/Medium/Large Companies with Imputed Data")
plt.bar(X_train.columns[indices][- 10:], importance[indices][- 10:], 
        color = 'b', align = 'center')
plt.xticks(range(10), X.columns[indices][-10:], rotation = 90)
plt.xlim([-1, 10])
plt.tight_layout()
plt.savefig(data_root + 'Random Forest Nonbinary Feature Importance.png')

# %%
clf.score(X_test, Y_test)
# Out:
# 0.7465815861440291

# %% [markdown]
# ## Linear Regression Redeux

# %%
q3mergeddata['Clean_Number_of_Shares'] =q3mergeddata[['WeightedAverageNumberOfDilutedSharesOutstanding',
       'WeightedAverageNumberOfSharesOutstandingBasic']].max(axis = 1)

q3mergeddata['Clean_Number_of_Shares'] = q3mergeddata[['Clean_Number_of_Shares',
                                                       'CommonStockSharesOutstanding']].max(axis = 1)

q3mergeddata['Company_Value'] = q3mergeddata['Clean_Number_of_Shares'] * q3mergeddata['7_after']
q3mergeddata = q3mergeddata.drop(q3mergeddata[q3mergeddata.Company_Value == 0].index)
q3mergeddata = q3mergeddata.drop(['CommonStockSharesOutstanding','WeightedAverageNumberOfDilutedSharesOutstanding','WeightedAverageNumberOfSharesOutstandingBasic' ], axis = 1)
q3mergeddata['Company_Size'] = np.where(q3mergeddata['Company_Value'] > 5000000000, 1, 0)

# %%
X = pd.DataFrame(q3mergeddata[q3mergeddata.columns[11:len(q3mergeddata.columns) - 7]].copy())
Y = pd.DataFrame(q3mergeddata['Company_Value'].copy())

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.50)

lin_reg = LinearRegression()
lin_reg.fit(X_train, Y_train)

y_pred = lin_reg.predict(X_test)

# %%
mean_squared_error(Y_test, y_pred)
# Out:
# 2.611851507480231e+28

# %%
r2_score(Y_test, y_pred)
# Out:
# -115770.49172716122

# %% [markdown]
# Stock Price Redeux

# %%
labels = list(q3mergeddata.columns[10:99])
q3mergeddata['movement'] = np.where(q3mergeddata['difference'] >= 0 , int(1.00), int(0.00))
q3mergeddata_processed  = pd.DataFrame(preprocessing.scale(q3mergeddata[q3mergeddata.columns[11:len(q3mergeddata.columns) - 7]]), columns =q3mergeddata.columns[11:len(q3mergeddata.columns) - 7] )
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:172: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn("Numerical issues were encountered "

# %%
X = pd.DataFrame(q3mergeddata_processed.copy())
Y = pd.DataFrame(q3mergeddata['movement'].copy())

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.30)

# %%
logreg = LogisticRegression()
logreg.fit(X_train, np.ravel(Y_train))

log_decision = logreg.decision_function(X_test)
log_fpr, log_tpr, _  = roc_curve(Y_test, log_decision)

log_auc = auc(log_fpr, log_tpr)

plt.figure(figsize = (10,10))
plt.plot(log_fpr, log_tpr, label = 'AUC for Logistic:'+"{0:.4f}".format(log_auc))
plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Stock Price Movement a Week after Filing for Imputed Data')
plt.legend(loc="lower right")
plt.savefig(data_root + 'ROC for Stock Movement a Week after Filing IMputed.png')
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %% [markdown]
# ## Neural Net

# %%
mlp = MLPClassifier(hidden_layer_sizes=(50,), max_iter=100, alpha=1e-4,
                    solver='sgd', verbose=10, random_state=1,
                    learning_rate_init=.1)
mlp.fit(X_train, Y_train)

print("Training set score: %f" % mlp.score(X_train, np.ravel(Y_train)))
print("Test set score: %f" % mlp.score(X_test, np.ravel(Y_test)))
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:921: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Iteration 1, loss = 0.55634209
# Iteration 2, loss = 0.42975906
# Iteration 3, loss = 0.39535535
# Iteration 4, loss = 0.38120769
# Iteration 5, loss = 0.37231260
# Iteration 6, loss = 0.36314959
# Iteration 7, loss = 0.35805199
# Iteration 8, loss = 0.35334000
# Iteration 9, loss = 0.35050229
# Iteration 10, loss = 0.34483280
# Iteration 11, loss = 0.34258616
# Iteration 12, loss = 0.33681275
# Iteration 13, loss = 0.33383343
# Iteration 14, loss = 0.32927019
# Iteration 15, loss = 0.32481006
# Iteration 16, loss = 0.32210794
# Iteration 17, loss = 0.31824815
# Iteration 18, loss = 0.31439267
# Iteration 19, loss = 0.31294852
# Iteration 20, loss = 0.31106660
# Iteration 21, loss = 0.30522764
# Iteration 22, loss = 0.30560310
# Iteration 23, loss = 0.30281929
# Iteration 24, loss = 0.30140476
# Iteration 25, loss = 0.29733595
# Iteration 26, loss = 0.29272246
# Iteration 27, loss = 0.29359655
# Iteration 28, loss = 0.28867596
# Iteration 29, loss = 0.28958084
# Iteration 30, loss = 0.28328645
# Iteration 31, loss = 0.28634585
# Iteration 32, loss = 0.28664204
# Iteration 33, loss = 0.28211522
# Iteration 34, loss = 0.27959138
# Iteration 35, loss = 0.27345969
# Iteration 36, loss = 0.27465759
# Iteration 37, loss = 0.27144052
# Iteration 38, loss = 0.27178773
# Iteration 39, loss = 0.27393346
# Iteration 40, loss = 0.26533623
# Iteration 41, loss = 0.26705188
# Iteration 42, loss = 0.26532632
# Iteration 43, loss = 0.26940592
# Iteration 44, loss = 0.25812848
# Iteration 45, loss = 0.25450120
# Iteration 46, loss = 0.25592543
# Iteration 47, loss = 0.25673823
# Iteration 48, loss = 0.25608069
# Iteration 49, loss = 0.25441271
# Iteration 50, loss = 0.25347358
# Iteration 51, loss = 0.25557823
# Iteration 52, loss = 0.25350626
# Iteration 53, loss = 0.24742209
# Iteration 54, loss = 0.24883937
# Iteration 55, loss = 0.24762413
# Iteration 56, loss = 0.24400280
# Iteration 57, loss = 0.24861786
# Iteration 58, loss = 0.24309080
# Iteration 59, loss = 0.25226165
# Iteration 60, loss = 0.24636115
# Iteration 61, loss = 0.23803205
# Iteration 62, loss = 0.23726790
# Iteration 63, loss = 0.23838384
# Iteration 64, loss = 0.23809677
# Iteration 65, loss = 0.23189861
# Iteration 66, loss = 0.23452855
# Iteration 67, loss = 0.22976603
# Iteration 68, loss = 0.22793817
# Iteration 69, loss = 0.22411724
# Iteration 70, loss = 0.22744807
# Iteration 71, loss = 0.22462850
# Iteration 72, loss = 0.22900317
# Iteration 73, loss = 0.22230522
# Iteration 74, loss = 0.22687117
# Iteration 75, loss = 0.23217389
# Iteration 76, loss = 0.22563576
# Iteration 77, loss = 0.21634130
# Iteration 78, loss = 0.22140886
# Iteration 79, loss = 0.21905531
# Iteration 80, loss = 0.22156935
# Iteration 81, loss = 0.21690270
# Iteration 82, loss = 0.21325473
# Iteration 83, loss = 0.21127502
# Iteration 84, loss = 0.21518913
# Iteration 85, loss = 0.21499170
# Iteration 86, loss = 0.20485761
# Iteration 87, loss = 0.20433296
# Iteration 88, loss = 0.21714821
# Iteration 89, loss = 0.20371816
# Iteration 90, loss = 0.21497720
# Iteration 91, loss = 0.21827644
# Iteration 92, loss = 0.21161037
# Iteration 93, loss = 0.20905068
# Iteration 94, loss = 0.20298319
# Iteration 95, loss = 0.21444271
# Iteration 96, loss = 0.21985763
# Iteration 97, loss = 0.21906777
# Iteration 98, loss = 0.20780642
# Iteration 99, loss = 0.19870802
# Iteration 100, loss = 0.20111779
# Training set score: 0.925694
# Test set score: 0.852325
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
mlp = MLPClassifier()
parameters = {'solver':('lbfgs', 'sgd', 'adam'), 'max_iter': [100,200,500]}
model = GridSearchCV(mlp, parameters, cv = 10)

# %%
model.fit(X, np.ravel(Y))
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# GridSearchCV(cv=10, error_score='raise-deprecating',
#              estimator=MLPClassifier(activation='relu', alpha=0.0001,
#                                      batch_size='auto', beta_1=0.9,
#                                      beta_2=0.999, early_stopping=False,
#                                      epsilon=1e-08, hidden_layer_sizes=(100,),
#                                      learning_rate='constant',
#                                      learning_rate_init=0.001, max_iter=200,
#                                      momentum=0.9, n_iter_no_change=10,
#                                      nesterovs_momentum=True, power_t=0.5,
#                                      random_state=None, shuffle=True,
#                                      solver='adam', tol=0.0001,
#                                      validation_fraction=0.1, verbose=False,
#                                      warm_start=False),
#              iid='warn', n_jobs=None,
#              param_grid={'max_iter': [100, 200, 500],
#                          'solver': ('lbfgs', 'sgd', 'adam')},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)
